# %% [markdown]
# # Векторизация текста и измерение семантического сходства
#
# <b>Цель</b>: В данном ноутбуке я тестирую программные методы представления текстов в виде векторов и их семнтического (по смыслу) сравнения.
#
# <b>Задачи:</b>
# - векторизаия абстрактов статей в вектора;
# - вычисление косинусного сходства между этими векторами;
# - визуализация смысловой «похожести» текстов

# %%
# ипортируем нужные библиотеки
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

# %%
pip install ipywidgets tqdm --upgrade
# Out:
# Requirement already satisfied: ipywidgets in ./env/lib/python3.12/site-packages (8.1.7)
# Requirement already satisfied: tqdm in ./env/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: comm>=0.1.3 in ./env/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./env/lib/python3.12/site-packages (from ipywidgets) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./env/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./env/lib/python3.12/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./env/lib/python3.12/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in ./env/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./env/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./env/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in ./env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Считывание данных
#
# Результаты прошлого этапа работы (препроцессинг) у нас сохранены в `"preprocessed_abstracts.csv"`. Нам в этом файле особенно интересны следующие столбцы:
#
# - `title` - оригинальные заголовки cтатей;
# - `summary` - оригинальные абстракты статей;
# - `summary_tokens` - очищенные от лишних знаков, стоп-слов и лемматизированные абстракты статей;
# - `title_tokens` -  - очищенные от лишних знаков, стоп-слов и лемматизированные заголовки cтатей;
# - `tokens_combined` - склеенные очищенные и лемматизированные заголовки и абстракты статей.
#
# Поскольку мы пока что работаем с малыми данными, файл содержит первую 1000 записей метаданных в категории arxiv.org `astro-ph.IM`.

# %%
df = pd.read_csv('preprocessed_abstracts.csv')

# %%
df.head()
# Out:
#                                         id               updated  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1  2004-07-02T10:17:39Z
# 1  http://arxiv.org/abs/astro-ph/0410439v1  2004-10-19T14:47:51Z
# 2  http://arxiv.org/abs/astro-ph/0411574v3  2011-01-05T18:55:32Z
# 3  http://arxiv.org/abs/astro-ph/0504497v1  2005-04-22T12:39:07Z
# 4   http://arxiv.org/abs/physics/0510224v1  2005-10-25T15:36:07Z
#
#               published                                              title  \
# 0  2004-07-02T10:17:39Z  Muon Track Reconstruction and Data Selection T...
# 1  2004-10-19T14:47:51Z                   An update on the SCUBA-2 project
# 2  2004-11-19T15:00:42Z  Feasibility study of a Laue lens for hard X-ra...
# 3  2005-04-22T12:39:07Z  Search for Extra-Terrestrial planets: The DARW...
# 4  2005-10-25T15:36:07Z  Wavefront sensor based on varying transmission...
#
#                                              summary  \
# 0  The Antarctic Muon And Neutrino Detector Array...
# 1  SCUBA-2, which replaces SCUBA (the Submillimet...
# 2  We report on the feasibility study of a Laue l...
# 3  The DARWIN mission is an Infrared free flying ...
# 4  The use of Wavefront Sensors (WFS) is nowadays...
#
#                                               author  \
# 0  [{'name': 'The AMANDA Collaboration'}, {'name'...
# 1  [{'name': 'Michael Audley', 'affiliation': 'UK...
# 2  [{'name': 'A. Pisa', 'affiliation': 'Universit...
# 3                                                NaN
# 4                                                NaN
#
#                           doi  \
# 0  10.1016/j.nima.2004.01.065
# 1           10.1117/12.551259
# 2           10.1117/12.563052
# 3                         NaN
# 4   10.1080/09500340500073495
#
#                                         link_related  \
# 0  ['http://dx.doi.org/10.1016/j.nima.2004.01.065...
# 1  ['http://dx.doi.org/10.1117/12.551259', 'http:...
# 2  ['http://dx.doi.org/10.1117/12.563052', 'http:...
# 3            http://arxiv.org/pdf/astro-ph/0504497v1
# 4  ['http://dx.doi.org/10.1080/09500340500073495'...
#
#                                              comment  \
# 0   40 pages, 16 Postscript figures, uses elsart.sty
# 1  16 pages, 14 figures, Invited talk at SPIE Gla...
# 2  10 pages, corrected Fig. 1b and Fig. 2, which ...
# 3  PhD thesis 2004, Karl Franzens Univ. Graz, 177...
# 4                                2 tables, 6 figures
#
#                            journal_ref  \
# 0  Nucl.Instrum.Meth.A524:169-194,2004
# 1                                  NaN
# 2          SPIE Proc., 5536, 39 (2004)
# 3                                  NaN
# 4         J.Mod.Opt. 52:1917-1931,2005
#
#                             link_alternate primary_category  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1         astro-ph
# 1  http://arxiv.org/abs/astro-ph/0410439v1         astro-ph
# 2  http://arxiv.org/abs/astro-ph/0411574v3         astro-ph
# 3  http://arxiv.org/abs/astro-ph/0504497v1         astro-ph
# 4   http://arxiv.org/abs/physics/0510224v1   physics.optics
#
#                                         category       author.name  \
# 0                    ['astro-ph', 'astro-ph.IM']               NaN
# 1                    ['astro-ph', 'astro-ph.IM']               NaN
# 2                    ['astro-ph', 'astro-ph.IM']               NaN
# 3     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']  Lisa Kaltenegger
# 4  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
#
#   author.affiliation                                     summary_tokens  \
# 0                NaN  ['Antarctic', 'Muon', 'Neutrino', 'Detector', ...
# 1                NaN  ['replace', 'SCUBA', 'Submillimeter', 'Common'...
# 2                NaN  ['report', 'feasibility', 'study', 'Laue', 'le...
# 3                NaN  ['DARWIN', 'mission', 'Infrared', 'free', 'fly...
# 4                NaN  ['use', 'Wavefront', 'Sensors', 'WFS', 'nowada...
#
#                                         title_tokens  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1                              ['update', 'project']
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
#
#                                      tokens_combined
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1  ['update', 'project', 'replace', 'SCUBA', 'Sub...
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...

# %% [markdown]
# ## 2. Методология: факторы, которые я учитываю при работе с данными
#
# ### Выходные данные для используемых методов
#
# В рамках этого ноутбука я пробую работать как с классическими методами, такими как TF-IDF, BoW, так и с эмбеддингами. Эти подходы могут быть по-разному чувствительны к форме данных, подаваемых на вход:
#
# 1. "Классические" методы TF-IDF, BoW чувствительны к частоте и форме слов, поэтому важно подавать им предобработанные данные, чтобы модели не сбились;
# 2. Эмбеддинги (такие как SentenceTransformer) могут (но не обязательно будут) лучше работать на оригинальных текстах, в которых:
# - данные не лемматизированы до потери контекста;
# - оставлены знаки пунктуации, помогающие модели понять структуру предложений
# - оставлены важные для контекста единицы измерения, например `10^15 eV`.
#
# Поэтому методам из 1 мы будем подавать на вход "чистые данные", а методам из 2. попробуем подать и чистые и сырые и сравним, что будет лучше работать.

# %% [markdown]
# ### Комбинирование данных в разных столбцах
#
# Для нашего исследования имеет смысл использовать и заголовки статей (отражают тематику и тип исследования), и их абстракты (содержат методы, данные, результаты и проч. детальный контекст). При этом возниает вопрос: векторизовать и семантически сравнивать это данные по отдельности и потом как-то вычислять общую оценку или склеивать всё вместе и производить все вычисления только один раз? Рассмотрим следующие
#
# #### Возможные подходы к объединению заголовков и аннотаций
#
# Введём <b>Определение.</b>
#
# Embedding, он же "векторное представление" — это способ представить смысл текста в виде чисел.
# То есть мы превращаем слова, предложения или документы в векторы — точки в многомерном пространстве, где смысловые сходства превращаются в геометрические расстояния.
#
# Embedding — это результат работы обученной модели (например, SentenceTransformer), которая отображает текст в векторное пространство признаков.
# В этом пространстве:
# - близкие тексты (например, “proton flux” и “cosmic ray spectrum”) имеют маленькое косинусное расстояние (угол между векторами маленький);
# - разные тексты (например, “neural network training” и “gamma-ray observatory”) — находятся далеко друг от друга.
#
# Когда у нас есть как заголовки статей, так и аннотации, существует несколько способов вычисления семантического сходства:
#
# 1. **Конкатенация**
# - Объединить заголовок и аннотацию в один текст перед векторизацией (эмбеддингом)
# - Это простой способ, позволяющий модели автоматически сбалансировать значение.
#
# 2. **Взвешенное среднее эмбеддингов (векторных представлений)**
# - Вычислить отдельно эмбеддинги для заголовка и аннотации, затем взять взвешенное среднее:
# `combined_emb = w_title * title_emb + w_abstract * abstract_emb`
# - Позволяет контролировать влияние заголовка по сравнению с аннотацией.
# - Приводит нас к вопросу того, какие веса `w_title` и `w_abstract` имеют смысл в нашей задаче.
#
# 3. **Взвешенные оценки схожести**
# - Производится отдельно не только векторизация, но вычисление косинуснуой схожести для названий и аннотаций:
# `sim_title = cosine_similarity(title_emb)`
# `sim_abstract = cosine_similarity(abstract_emb)`
# - Далее вычисляется взвешенная косинусная схожесть:
# `combined_sim = alpha * sim_title + (1-alpha) * sim_abstract`
# - Гибкий подход, позволяет по необходимости уделять больше внимания заголовку или аннотации
# - Нужно пробовать разные параметры `alpha`.
#
# 4. **Двухэтапный поиск (для RAG / классификаторов)**
# - Использование схожести заголовков для быстрой фильтрации.
# - Использование схожести аннотаций для более точного ранжирования.
# - Может пригодиться нам на более поздних этапах проекта.

# %% [markdown]
# ### Используемые методы
#
# В этом ноутбуке я рассматриваю альтернативные методы решения одной задачи:
# - <b>TF-IDF</b> - “bag-of-words” с весами для слов.
# - <b>Sentence Transformers</b> - “умный” вектор всего текста, учитывающий смысл.
#
# Цель: сравнить, как они работают. Ожидаем, что TF-IDF покажет “поверхностное” сходство по ключевым словам, а эмбеддинги — глубокое, семантическое сходство.
#
# #### Общее у этих методов
# И TF-IDF, и Sentence Transformers создают векторное представление текста — то есть превращают текст в числовой вектор, который можно использовать для:
# - измерения сходства между документами,
# - кластеризации,
# - поиска похожих текстов,
# - машинного обучения.
#
# #### Особенности TF-IDF
# - Простой, быстрый, хорошо работает на небольших корпусах.
# - Показывает, какие слова важны для документа, но не улавливает семантический смысл (например, “car” и “automobile” будут считаться разными словами).
# - В выходных данных длина ветора для текста будет равна числу уникальных слов в тексте (т.е., мб разная для каждого слова в тексте)
# - Принцип работы
# <ul>
#     <li>Каждое слово - отдельное измерение в векторе.</li>
# <li>Вес слова = TF × IDF.</li>
# <li> Игнорируется порядок слов, контекст слова в предложении почти не учитывается.</li>
#     </ul>
#
# #### Особенности Семантических эмбеддингов (Sentence Transformers)
# - Нейросетевой метод,использующий предобученные модели (например, `all-MiniLM-L6-v2`).
# - Превращает весь текст (фразу, предложение, абстракт) в компактный вектор фиксированной размерности (например, 384 или 768)
# - Вектор документа на выходе всегда фиксированной длины, независимой от числа слов в корпусе - можно сравнивать тексты разной длины
# - Даёт более точную оценку смыслового сходства.
# - Требует больше ресурсов для вычислений

# %% [markdown]
# ## Векторизация через TF-IDF

# %% [markdown]
# ###  Теория
#
# <b>Определение.</b> TF-IDF расшифровывается как Term Frequency – Inverse Document Frequency. Этот параметр показывает, насколько слово важно в конкретном документе по сравнению со всей коллекцией текстов.
#
# Он вычисляется по следующей формуле:
# **TF-IDF:**
# $$
# \text{TF-IDF}(t, d) = \text{TF}(t, d) \times \text{IDF}(t)
# $$
#
# где:
# - $t$ — термин (слово или токен)
# - $d$ — документ (абстракт)
# - $N$ — общее количество документов (в нашем сэмпле их 1000)
# - $n_t$ — количество документов, в которых встречается термин $t$ (например, слово `CORSIKA`)
# - $\text{TF}(t, d)$ — частота слова $t$ в документе $d$,
# - $\text{IDF}(t)$ — обратная частота документа для слова $t$.
#
# Член $\text{TF}(t, d)$ называется `Term Frequency` и показывает, насколько часто слово встречается в документе. его рассчитывают вот так:
#
# $$
# \text{TF}(t, d) = \frac{f_{t,d}}{\sum_{k} f_{k,d}}
# $$
#
# где:
# - $f_{t,d}$ - это частота (frequency) того, сколько раз термин $t$ встречается в документе \(d\)
# - знаменатель $\sum_{k} f_{k,d}$ это сумма по всем токенам текста сколько раз тот или иной токен встречается в тексте, т.е. общее количество всех слов в документе
#
# Член $$\text{IDF}(t) = \log \frac{N}{n_t}$$
#
# где:
# - $N$ — общее число документов
# - $n_t$ — количество документов, содержащих термин $t$
#
# называется `Inverse Document Frequency`, aka `обратная частота документа` и показывает, насколько редким является токен $t$ в документе $d$. Как именно это работает:
#
# - Если слово встречается почти в каждом документе,
# $$
# \frac{N}{n_t} \approx 1
# $$
# и тогда
# $$
# \log(1) = 0
# $$
# -> значение IDF близко к нулю.
#
# - Если слово встречается редко (например, только в одном документе),
# $$
# \frac{N}{n_t}
# $$
# будет большим,
# и, следовательно, IDF также будет высоким:
# $$
# \text{IDF}(t) = \log \frac{N}{n_t}
# $$
#
# Моя интуиция мне подсказывает, что не обязательно все редкие слова будут прямо такими значимыми в тексте, какие-то из них там могут оказаться по ошибке, из-за того, что текст писал нэтивспикер, прихвастнувший богатыми познаниями в языке и т.д. И именно эту проблему адресует использование общей формулы $TF-IDF$.

# %% [markdown]
# #### Интерпретация $TF-IDF$
#
# - Если слово часто встречается **внутри конкретного документа**, то $\text{TF}(t, d)$ большое.
# - Если слово встречается **во многих документах корпуса**, то $\text{IDF}(t)$ маленькое.
# - Если слово встречается **редко в корпусе**, то $\text{IDF}(t)$ большое.
# - Таким образом, высокий вес TF-IDF получают слова, которые: 1) часто встречаются в данном документе; 2) редки в остальных документах корпуса. Т.е., часть IDF определяет уникальность слова в корпусе, а часть TF позволяет понять, случайно оно оказалось в конкретном тексте, или это паттерн и это слово действительно важно и глубоко этот текст характеризует.

# %% [markdown]
# ### Практика

# %%
vectorizer = TfidfVectorizer() 
data1 = df['tokens_combined'] #подаём модели на вход "чистые" данные, загловки и абстракты вместе
X_tfidf = vectorizer.fit_transform(data1) 
similarity_tfidf = cosine_similarity(X_tfidf) 
print(similarity_tfidf)
# Out:
# [[1.         0.05093006 0.01810029 ... 0.03435735 0.03578445 0.00861096]
#  [0.05093006 1.         0.00877696 ... 0.06212513 0.03667298 0.03183584]
#  [0.01810029 0.00877696 1.         ... 0.01824259 0.02726266 0.00342599]
#  ...
#  [0.03435735 0.06212513 0.01824259 ... 1.         0.06269931 0.00315914]
#  [0.03578445 0.03667298 0.02726266 ... 0.06269931 1.         0.0157325 ]
#  [0.00861096 0.03183584 0.00342599 ... 0.00315914 0.0157325  1.        ]]

# %%
plt.imshow(similarity_tfidf, cmap='Blues')  # с визуализацией не задалось, ведь вектора у нас разной длины. 
#вернусь к этому, если оно в будущем будет полезно
plt.title("TF-IDF similarity between abstracts") 
plt.colorbar() 
plt.show()

# %% [markdown]
# Поскольку график выглядит пустым, попробуем раздебажить визуализацию.
#
# Моя первая гипотеза была, что матрицу сходства вообще нельзя нарисовать, потому что TF-IDF для каждого текста генерирует вектора разной длины. Но это не так, потому что выход из функции `cosine_similarity(X_tfidf)` уже квадратный и должен нормально рисоваться.
#
# Другие возможные причины:
# - Все значения сходства слишком малы (например, < 0.05).
# - Цветовая шкала cmap='Blues' недостаточно контрастная.

# %%
# проверим распределение значений в матрице:
threshold=0.1
plt.hist(similarity_tfidf.flatten(), bins=30, color='skyblue')
plt.axvline(threshold, color='red', linestyle='--')
plt.title("Распределение значений cosine similarity (TF-IDF)")
plt.xlabel("Cosine similarity")
plt.ylabel("Количество пар")
plt.show()

# %% [markdown]
# Т.е., действительно значения косинусного сходства очень маленькие. Почему?
# #### Возможные причины низкого сходства TF-IDF
#
# 1. Очень разные словари текстов: у текстов почти нет общих лемм, даже после очистки. Особенно актуально, если тексты из разных тематик или доменов.
# 2. Короткие тексты. Мало слов → слабое пересечение → малая косинусная схожесть.
# 3. Сильная лемматизация или очистка. Агрессивная фильтрация (удалены редкие/служебные слова, числительные, сокращения) может стереть контекст.
# 4. Проблема синонимов в TF-IDF: метод думает, что это разные слова. Что приводит к разраженности итоговой матрицы сходства
# 5. Большой корпус. Если N (число документов) велико, IDF для многих слов мал, а веса становятся близкими к нулю.
#
# 5 точно не наш случай, остальное будет проверять.

# %%
# проверим гипотезу 4
nonzero_per_doc = (X_tfidf > 0).sum(axis=1).A1  # количество ненулевых элементов на документ
avg_nonzero = np.mean(nonzero_per_doc)
total_elements = X_tfidf.shape[0] * X_tfidf.shape[1]
nonzero_total = X_tfidf.nnz
sparsity = 1 - (nonzero_total / total_elements)

print(f"Среднее число ненулевых элементов на документ: {avg_nonzero:.1f}")
print(f"Всего элементов: {total_elements:,}")
print(f"Ненулевых элементов: {nonzero_total:,}")
print(f"Разреженность: {sparsity:.3%}")
# Out:
# Среднее число ненулевых элементов на документ: 67.5
# Всего элементов: 7,695,000
# Ненулевых элементов: 67,544
# Разреженность: 99.122%

# %% [markdown]
# Как можно видеть, разреженность у нас просто катастрофическая. Её можно чинить через:
# - выкидвание стоп-слов (уже сделано)
# - ограничение размера словаря (`vectorizer = TfidfVectorizer(max_features=5000)`)
# - биграммы или триграммы   <span style="color:blue">(а что это вообще такое?)</span>

# %%
# проверим корректность обработки токенов при передаче в TfidfVectorizer
print(data1[0][:200])
# Out:
# ['Muon', 'Track', 'Reconstruction', 'Data', 'Selection', 'Techniques', 'AMANDA', 'Antarctic', 'Muon', 'Neutrino', 'Detector', 'Array', 'AMANDA', 'high', 'energy', 'neutrino', 'telescope', 'operate', '

# %%
vectorizer.get_feature_names_out()[:100]
# Out:
# array(['aaac', 'aachen', 'aal', 'aao', 'aaomega', 'aapf', 'aas', 'ab',
#        'abcd', 'abell', 'aberrated', 'aberration', 'ability', 'able',
#        'aboard', 'abolish', 'abridge', 'abridged', 'abroad', 'abruptly',
#        'abs', 'abscissa', 'absence', 'absent', 'absolute', 'absolutely',
#        'absorb', 'absorbance', 'absorber', 'absorption', 'abstract',
#        'abu', 'abundance', 'abundances', 'abundant', 'abyss', 'academic',
#        'academy', 'acbar', 'acc', 'accelerate', 'accelerated',
#        'accelerateur', 'acceleration', 'accelerator', 'accelerators',
#        'accelerometer', 'accept', 'acceptable', 'acceptance', 'access',
#        'accessibility', 'accessible', 'accidental', 'accidentally',
#        'accommodate', 'accompany', 'accomplish', 'accord', 'accordance',
#        'accordingly', 'account', 'accounting', 'accrete', 'accretion',
#        'accrue', 'accumulate', 'accuracy', 'accurate', 'accurately',
#        'acd', 'achievable', 'achieve', 'achievement', 'achievment',
#        'achromatic', 'acknowledge', 'acount', 'acoustic', 'acoustically',
#        'acquire', 'acquisition', 'acrim', 'acs', 'acsis', 'act', 'action',
#        'activate', 'activation', 'active', 'actively', 'activity',
#        'actual', 'actually', 'actuator', 'acute', 'ad', 'adapt',
#        'adaptable', 'adaptation'], dtype=object)

# %%
# попробуем сделать то же самое, но с ограниченным размером словаря (max_features=100)
vectorizer_1 = TfidfVectorizer(max_features=100) 
data1 = df['tokens_combined'] #подаём модели на вход "чистые" данные, загловки и абстракты вместе
X_tfidf_1 = vectorizer_1.fit_transform(data1) 
similarity_tfidf_1 = cosine_similarity(X_tfidf_1) 
print(similarity_tfidf_1)
plt.imshow(similarity_tfidf_1, cmap='Blues')  # с визуализацией не задалось, ведь вектора у нас разной длины. 
#вернусь к этому, если оно в будущем будет полезно
plt.title("TF-IDF similarity between abstracts") 
plt.colorbar() 
plt.show()
# Out:
# [[1.         0.30713356 0.03011855 ... 0.13073654 0.22652    0.05464508]
#  [0.30713356 1.         0.10944507 ... 0.43335922 0.11438032 0.06211314]
#  [0.03011855 0.10944507 1.         ... 0.12203245 0.21218473 0.        ]
#  ...
#  [0.13073654 0.43335922 0.12203245 ... 1.         0.24555472 0.03954395]
#  [0.22652    0.11438032 0.21218473 ... 0.24555472 1.         0.03574637]
#  [0.05464508 0.06211314 0.         ... 0.03954395 0.03574637 1.        ]]

# %%
# проверим распределение значений в матрице:
threshold=0.1
plt.hist(similarity_tfidf_1.flatten(), bins=30, color='skyblue')
plt.axvline(threshold, color='red', linestyle='--')
plt.title("Распределение значений cosine similarity (TF-IDF)")
plt.xlabel("Cosine similarity")
plt.ylabel("Количество пар")
plt.show()

# %% [markdown]
# Как можно видеть, графики стали более интересными. Посмотрим, как меняются плотность и среднее сходство при разных размерах словаря, чтобы оценить его оптимальный размер

# %%
for size in [50, 100, 500, 1000, 5000]:
    vec = TfidfVectorizer(max_features=size)
    X = vec.fit_transform(df['tokens_combined'])
    sparsity = 1.0 - (X.nnz / (X.shape[0] * X.shape[1]))
    sim = cosine_similarity(X)
    mean_sim = np.mean(sim[np.triu_indices_from(sim, k=1)])
    print(f"max_features={size:<5} | sparsity={sparsity:.3f} | mean_similarity={mean_sim:.3f}")
# Out:
# max_features=50    | sparsity=0.804 | mean_similarity=0.146
# max_features=100   | sparsity=0.844 | mean_similarity=0.116
# max_features=500   | sparsity=0.926 | mean_similarity=0.064
# max_features=1000  | sparsity=0.952 | mean_similarity=0.049
# max_features=5000  | sparsity=0.987 | mean_similarity=0.029

# %% [markdown]
# ### Интерпретация
#
# 1. Разреженность растёт: чем больше словарь, тем больше уникальных токенов и тем меньше пересечений между документами.
# 2. Падение среднего сходства: косинусное сходство падает, потому что у векторов меньше общих ненулевых координат, TF-IDF перестаёт отражать общие темы, а начинает ловить случайные редкости.
# 3. Оптимум в районе 50–100 признаков: наши абстракты достаточно специализированные, и небольшой словарь отражает общие термины ("cosmic", "ray", "energy", "detector", "particle" и т.п.) без шума.

# %% [markdown]
# ## Семантические эмбеддинги

# %%
data2 = df['summary'] #подаём модели на вход оригинальные тексты абстрактов
model = SentenceTransformer('all-MiniLM-L6-v2') 
embeddings = model.encode(data2) 
similarity_embed = cosine_similarity(embeddings) 
print(similarity_embed)
# Out:
# [[0.9999999  0.28239527 0.23793042 ... 0.4225296  0.38511777 0.31271136]
#  [0.28239527 1.0000002  0.24597079 ... 0.40697962 0.35288405 0.18425159]
#  [0.23793042 0.24597079 1.         ... 0.36644864 0.3034075  0.22605896]
#  ...
#  [0.4225296  0.40697962 0.36644864 ... 1.         0.5057824  0.30461377]
#  [0.38511777 0.35288405 0.3034075  ... 0.5057824  1.         0.37405992]
#  [0.31271136 0.18425159 0.22605896 ... 0.30461377 0.37405992 0.9999999 ]]

# %%
plt.imshow(similarity_embed, cmap='Blues') 
plt.title("Semantic similarity between abstracts") 
plt.colorbar() 
plt.show()
#картинка уже интересная и выглядит так, как будто имеет какой-то смысл

# %% [markdown]
# ## Сравнение результатов
#
# Пропробуем сравнить результаты TF-IDF и эмбеддиргов.

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.imshow(similarity_tfidf_1, cmap='Reds')
plt.title("TF-IDF similarity")
plt.colorbar()

plt.subplot(1,2,2)
plt.imshow(similarity_embed, cmap='Blues')
plt.title("Embeddings similarity")
plt.colorbar()
plt.show()

# %% [markdown]
# Интересно, видно, что есть какие-то различия, но толком ничего непонятно.
# Сравним топ-1 или топ-3 самых похожих текстов:

# %%
top_n = 1
n_texts = 1000
for i in range(n_texts):
    tfidf_top = similarity_tfidf_1[i].argsort()[-top_n-1:-1][::-1]  # исключаем сам текст
    embed_top = similarity_embed[i].argsort()[-top_n-1:-1][::-1]
    print(f"Text {i}:")
    print(f"  TF-IDF top {top_n}: {tfidf_top}")
    print(f"  Embeddings top {top_n}: {embed_top}")
# Out:
# Text 0:
#   TF-IDF top 1: [852]
#   Embeddings top 1: [324]
# Text 1:
#   TF-IDF top 1: [844]
#   Embeddings top 1: [184]
# Text 2:
#   TF-IDF top 1: [561]
#   Embeddings top 1: [797]
# Text 3:
#   TF-IDF top 1: [8]
#   Embeddings top 1: [8]
# Text 4:
#   TF-IDF top 1: [481]
#   Embeddings top 1: [20]
# Text 5:
#   TF-IDF top 1: [6]
#   Embeddings top 1: [6]
# Text 6:
#   TF-IDF top 1: [5]
#   Embeddings top 1: [5]
# Text 7:
#   TF-IDF top 1: [420]
#   Embeddings top 1: [420]
# Text 8:
#   TF-IDF top 1: [3]
#   Embeddings top 1: [3]
# Text 9:
#   TF-IDF top 1: [3]
#   Embeddings top 1: [3]
# Text 10:
#   TF-IDF top 1: [757]
#   Embeddings top 1: [492]
# Text 11:
#   TF-IDF top 1: [838]
#   Embeddings top 1: [456]
# Text 12:
#   TF-IDF top 1: [304]
#   Embeddings top 1: [430]
# Text 13:
#   TF-IDF top 1: [364]
#   Embeddings top 1: [199]
# Text 14:
#   TF-IDF top 1: [458]
#   Embeddings top 1: [7]
# Text 15:
#   TF-IDF top 1: [451]
#   Embeddings top 1: [894]
# Text 16:
#   TF-IDF top 1: [20]
#   Embeddings top 1: [20]
# Text 17:
#   TF-IDF top 1: [19]
#   Embeddings top 1: [327]
# Text 18:
#   TF-IDF top 1: [260]
#   Embeddings top 1: [171]
# Text 19:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [152]
# Text 20:
#   TF-IDF top 1: [16]
#   Embeddings top 1: [16]
# Text 21:
#   TF-IDF top 1: [14]
#   Embeddings top 1: [11]
# Text 22:
#   TF-IDF top 1: [917]
#   Embeddings top 1: [420]
# Text 23:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [506]
# Text 24:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [3]
# Text 25:
#   TF-IDF top 1: [27]
#   Embeddings top 1: [27]
# Text 26:
#   TF-IDF top 1: [900]
#   Embeddings top 1: [691]
# Text 27:
#   TF-IDF top 1: [842]
#   Embeddings top 1: [25]
# Text 28:
#   TF-IDF top 1: [638]
#   Embeddings top 1: [638]
# Text 29:
#   TF-IDF top 1: [543]
#   Embeddings top 1: [638]
# Text 30:
#   TF-IDF top 1: [198]
#   Embeddings top 1: [116]
# Text 31:
#   TF-IDF top 1: [347]
#   Embeddings top 1: [885]
# Text 32:
#   TF-IDF top 1: [719]
#   Embeddings top 1: [714]
# Text 33:
#   TF-IDF top 1: [245]
#   Embeddings top 1: [761]
# Text 34:
#   TF-IDF top 1: [3]
#   Embeddings top 1: [779]
# Text 35:
#   TF-IDF top 1: [754]
#   Embeddings top 1: [156]
# Text 36:
#   TF-IDF top 1: [642]
#   Embeddings top 1: [53]
# Text 37:
#   TF-IDF top 1: [809]
#   Embeddings top 1: [809]
# Text 38:
#   TF-IDF top 1: [775]
#   Embeddings top 1: [820]
# Text 39:
#   TF-IDF top 1: [498]
#   Embeddings top 1: [167]
# Text 40:
#   TF-IDF top 1: [285]
#   Embeddings top 1: [976]
# Text 41:
#   TF-IDF top 1: [916]
#   Embeddings top 1: [52]
# Text 42:
#   TF-IDF top 1: [320]
#   Embeddings top 1: [656]
# Text 43:
#   TF-IDF top 1: [524]
#   Embeddings top 1: [353]
# Text 44:
#   TF-IDF top 1: [603]
#   Embeddings top 1: [5]
# Text 45:
#   TF-IDF top 1: [666]
#   Embeddings top 1: [994]
# Text 46:
#   TF-IDF top 1: [272]
#   Embeddings top 1: [566]
# Text 47:
#   TF-IDF top 1: [46]
#   Embeddings top 1: [371]
# Text 48:
#   TF-IDF top 1: [329]
#   Embeddings top 1: [486]
# Text 49:
#   TF-IDF top 1: [154]
#   Embeddings top 1: [299]
# Text 50:
#   TF-IDF top 1: [56]
#   Embeddings top 1: [56]
# Text 51:
#   TF-IDF top 1: [145]
#   Embeddings top 1: [739]
# Text 52:
#   TF-IDF top 1: [41]
#   Embeddings top 1: [12]
# Text 53:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [77]
# Text 54:
#   TF-IDF top 1: [28]
#   Embeddings top 1: [283]
# Text 55:
#   TF-IDF top 1: [385]
#   Embeddings top 1: [453]
# Text 56:
#   TF-IDF top 1: [777]
#   Embeddings top 1: [777]
# Text 57:
#   TF-IDF top 1: [386]
#   Embeddings top 1: [747]
# Text 58:
#   TF-IDF top 1: [662]
#   Embeddings top 1: [662]
# Text 59:
#   TF-IDF top 1: [798]
#   Embeddings top 1: [628]
# Text 60:
#   TF-IDF top 1: [527]
#   Embeddings top 1: [980]
# Text 61:
#   TF-IDF top 1: [270]
#   Embeddings top 1: [56]
# Text 62:
#   TF-IDF top 1: [775]
#   Embeddings top 1: [949]
# Text 63:
#   TF-IDF top 1: [170]
#   Embeddings top 1: [433]
# Text 64:
#   TF-IDF top 1: [381]
#   Embeddings top 1: [280]
# Text 65:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [902]
# Text 66:
#   TF-IDF top 1: [910]
#   Embeddings top 1: [739]
# Text 67:
#   TF-IDF top 1: [386]
#   Embeddings top 1: [361]
# Text 68:
#   TF-IDF top 1: [696]
#   Embeddings top 1: [511]
# Text 69:
#   TF-IDF top 1: [313]
#   Embeddings top 1: [84]
# Text 70:
#   TF-IDF top 1: [388]
#   Embeddings top 1: [388]
# Text 71:
#   TF-IDF top 1: [304]
#   Embeddings top 1: [171]
# Text 72:
#   TF-IDF top 1: [145]
#   Embeddings top 1: [185]
# Text 73:
#   TF-IDF top 1: [665]
#   Embeddings top 1: [225]
# Text 74:
#   TF-IDF top 1: [525]
#   Embeddings top 1: [623]
# Text 75:
#   TF-IDF top 1: [399]
#   Embeddings top 1: [923]
# Text 76:
#   TF-IDF top 1: [521]
#   Embeddings top 1: [750]
# Text 77:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [565]
# Text 78:
#   TF-IDF top 1: [776]
#   Embeddings top 1: [445]
# Text 79:
#   TF-IDF top 1: [263]
#   Embeddings top 1: [216]
# Text 80:
#   TF-IDF top 1: [595]
#   Embeddings top 1: [168]
# Text 81:
#   TF-IDF top 1: [82]
#   Embeddings top 1: [82]
# Text 82:
#   TF-IDF top 1: [81]
#   Embeddings top 1: [81]
# Text 83:
#   TF-IDF top 1: [330]
#   Embeddings top 1: [82]
# Text 84:
#   TF-IDF top 1: [706]
#   Embeddings top 1: [69]
# Text 85:
#   TF-IDF top 1: [269]
#   Embeddings top 1: [422]
# Text 86:
#   TF-IDF top 1: [925]
#   Embeddings top 1: [614]
# Text 87:
#   TF-IDF top 1: [830]
#   Embeddings top 1: [354]
# Text 88:
#   TF-IDF top 1: [326]
#   Embeddings top 1: [561]
# Text 89:
#   TF-IDF top 1: [653]
#   Embeddings top 1: [848]
# Text 90:
#   TF-IDF top 1: [792]
#   Embeddings top 1: [345]
# Text 91:
#   TF-IDF top 1: [598]
#   Embeddings top 1: [113]
# Text 92:
#   TF-IDF top 1: [972]
#   Embeddings top 1: [230]
# Text 93:
#   TF-IDF top 1: [989]
#   Embeddings top 1: [696]
# Text 94:
#   TF-IDF top 1: [253]
#   Embeddings top 1: [43]
# Text 95:
#   TF-IDF top 1: [873]
#   Embeddings top 1: [966]
# Text 96:
#   TF-IDF top 1: [194]
#   Embeddings top 1: [825]
# Text 97:
#   TF-IDF top 1: [988]
#   Embeddings top 1: [663]
# Text 98:
#   TF-IDF top 1: [784]
#   Embeddings top 1: [645]
# Text 99:
#   TF-IDF top 1: [594]
#   Embeddings top 1: [701]
# Text 100:
#   TF-IDF top 1: [760]
#   Embeddings top 1: [364]
# Text 101:
#   TF-IDF top 1: [185]
#   Embeddings top 1: [943]
# Text 102:
#   TF-IDF top 1: [438]
#   Embeddings top 1: [223]
# Text 103:
#   TF-IDF top 1: [118]
#   Embeddings top 1: [823]
# Text 104:
#   TF-IDF top 1: [326]
#   Embeddings top 1: [138]
# Text 105:
#   TF-IDF top 1: [232]
#   Embeddings top 1: [201]
# Text 106:
#   TF-IDF top 1: [312]
#   Embeddings top 1: [895]
# Text 107:
#   TF-IDF top 1: [627]
#   Embeddings top 1: [878]
# Text 108:
#   TF-IDF top 1: [683]
#   Embeddings top 1: [884]
# Text 109:
#   TF-IDF top 1: [926]
#   Embeddings top 1: [733]
# Text 110:
#   TF-IDF top 1: [118]
#   Embeddings top 1: [814]
# Text 111:
#   TF-IDF top 1: [941]
#   Embeddings top 1: [556]
# Text 112:
#   TF-IDF top 1: [656]
#   Embeddings top 1: [921]
# Text 113:
#   TF-IDF top 1: [532]
#   Embeddings top 1: [696]
# Text 114:
#   TF-IDF top 1: [396]
#   Embeddings top 1: [564]
# Text 115:
#   TF-IDF top 1: [125]
#   Embeddings top 1: [485]
# Text 116:
#   TF-IDF top 1: [30]
#   Embeddings top 1: [492]
# Text 117:
#   TF-IDF top 1: [310]
#   Embeddings top 1: [532]
# Text 118:
#   TF-IDF top 1: [541]
#   Embeddings top 1: [475]
# Text 119:
#   TF-IDF top 1: [483]
#   Embeddings top 1: [663]
# Text 120:
#   TF-IDF top 1: [414]
#   Embeddings top 1: [132]
# Text 121:
#   TF-IDF top 1: [597]
#   Embeddings top 1: [167]
# Text 122:
#   TF-IDF top 1: [196]
#   Embeddings top 1: [824]
# Text 123:
#   TF-IDF top 1: [132]
#   Embeddings top 1: [754]
# Text 124:
#   TF-IDF top 1: [964]
#   Embeddings top 1: [886]
# Text 125:
#   TF-IDF top 1: [115]
#   Embeddings top 1: [845]
# Text 126:
#   TF-IDF top 1: [626]
#   Embeddings top 1: [919]
# Text 127:
#   TF-IDF top 1: [877]
#   Embeddings top 1: [877]
# Text 128:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [819]
# Text 129:
#   TF-IDF top 1: [113]
#   Embeddings top 1: [761]
# Text 130:
#   TF-IDF top 1: [502]
#   Embeddings top 1: [884]
# Text 131:
#   TF-IDF top 1: [628]
#   Embeddings top 1: [620]
# Text 132:
#   TF-IDF top 1: [720]
#   Embeddings top 1: [306]
# Text 133:
#   TF-IDF top 1: [994]
#   Embeddings top 1: [661]
# Text 134:
#   TF-IDF top 1: [805]
#   Embeddings top 1: [903]
# Text 135:
#   TF-IDF top 1: [771]
#   Embeddings top 1: [207]
# Text 136:
#   TF-IDF top 1: [347]
#   Embeddings top 1: [870]
# Text 137:
#   TF-IDF top 1: [764]
#   Embeddings top 1: [196]
# Text 138:
#   TF-IDF top 1: [363]
#   Embeddings top 1: [712]
# Text 139:
#   TF-IDF top 1: [759]
#   Embeddings top 1: [183]
# Text 140:
#   TF-IDF top 1: [409]
#   Embeddings top 1: [885]
# Text 141:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [183]
# Text 142:
#   TF-IDF top 1: [667]
#   Embeddings top 1: [667]
# Text 143:
#   TF-IDF top 1: [301]
#   Embeddings top 1: [385]
# Text 144:
#   TF-IDF top 1: [19]
#   Embeddings top 1: [512]
# Text 145:
#   TF-IDF top 1: [72]
#   Embeddings top 1: [51]
# Text 146:
#   TF-IDF top 1: [850]
#   Embeddings top 1: [655]
# Text 147:
#   TF-IDF top 1: [660]
#   Embeddings top 1: [428]
# Text 148:
#   TF-IDF top 1: [660]
#   Embeddings top 1: [147]
# Text 149:
#   TF-IDF top 1: [167]
#   Embeddings top 1: [158]
# Text 150:
#   TF-IDF top 1: [453]
#   Embeddings top 1: [949]
# Text 151:
#   TF-IDF top 1: [595]
#   Embeddings top 1: [318]
# Text 152:
#   TF-IDF top 1: [249]
#   Embeddings top 1: [19]
# Text 153:
#   TF-IDF top 1: [405]
#   Embeddings top 1: [622]
# Text 154:
#   TF-IDF top 1: [49]
#   Embeddings top 1: [378]
# Text 155:
#   TF-IDF top 1: [815]
#   Embeddings top 1: [735]
# Text 156:
#   TF-IDF top 1: [277]
#   Embeddings top 1: [364]
# Text 157:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [158]
# Text 158:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [157]
# Text 159:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [166]
# Text 160:
#   TF-IDF top 1: [845]
#   Embeddings top 1: [485]
# Text 161:
#   TF-IDF top 1: [158]
#   Embeddings top 1: [158]
# Text 162:
#   TF-IDF top 1: [401]
#   Embeddings top 1: [741]
# Text 163:
#   TF-IDF top 1: [538]
#   Embeddings top 1: [896]
# Text 164:
#   TF-IDF top 1: [742]
#   Embeddings top 1: [667]
# Text 165:
#   TF-IDF top 1: [533]
#   Embeddings top 1: [153]
# Text 166:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [159]
# Text 167:
#   TF-IDF top 1: [149]
#   Embeddings top 1: [121]
# Text 168:
#   TF-IDF top 1: [752]
#   Embeddings top 1: [80]
# Text 169:
#   TF-IDF top 1: [202]
#   Embeddings top 1: [589]
# Text 170:
#   TF-IDF top 1: [63]
#   Embeddings top 1: [173]
# Text 171:
#   TF-IDF top 1: [398]
#   Embeddings top 1: [18]
# Text 172:
#   TF-IDF top 1: [241]
#   Embeddings top 1: [917]
# Text 173:
#   TF-IDF top 1: [571]
#   Embeddings top 1: [455]
# Text 174:
#   TF-IDF top 1: [267]
#   Embeddings top 1: [924]
# Text 175:
#   TF-IDF top 1: [593]
#   Embeddings top 1: [77]
# Text 176:
#   TF-IDF top 1: [75]
#   Embeddings top 1: [934]
# Text 177:
#   TF-IDF top 1: [15]
#   Embeddings top 1: [924]
# Text 178:
#   TF-IDF top 1: [194]
#   Embeddings top 1: [259]
# Text 179:
#   TF-IDF top 1: [60]
#   Embeddings top 1: [582]
# Text 180:
#   TF-IDF top 1: [71]
#   Embeddings top 1: [937]
# Text 181:
#   TF-IDF top 1: [684]
#   Embeddings top 1: [793]
# Text 182:
#   TF-IDF top 1: [176]
#   Embeddings top 1: [597]
# Text 183:
#   TF-IDF top 1: [535]
#   Embeddings top 1: [141]
# Text 184:
#   TF-IDF top 1: [789]
#   Embeddings top 1: [347]
# Text 185:
#   TF-IDF top 1: [270]
#   Embeddings top 1: [748]
# Text 186:
#   TF-IDF top 1: [34]
#   Embeddings top 1: [693]
# Text 187:
#   TF-IDF top 1: [509]
#   Embeddings top 1: [827]
# Text 188:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [147]
# Text 189:
#   TF-IDF top 1: [708]
#   Embeddings top 1: [93]
# Text 190:
#   TF-IDF top 1: [844]
#   Embeddings top 1: [101]
# Text 191:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [387]
# Text 192:
#   TF-IDF top 1: [209]
#   Embeddings top 1: [204]
# Text 193:
#   TF-IDF top 1: [648]
#   Embeddings top 1: [949]
# Text 194:
#   TF-IDF top 1: [178]
#   Embeddings top 1: [436]
# Text 195:
#   TF-IDF top 1: [304]
#   Embeddings top 1: [71]
# Text 196:
#   TF-IDF top 1: [803]
#   Embeddings top 1: [213]
# Text 197:
#   TF-IDF top 1: [300]
#   Embeddings top 1: [875]
# Text 198:
#   TF-IDF top 1: [246]
#   Embeddings top 1: [447]
# Text 199:
#   TF-IDF top 1: [149]
#   Embeddings top 1: [528]
# Text 200:
#   TF-IDF top 1: [892]
#   Embeddings top 1: [64]
# Text 201:
#   TF-IDF top 1: [949]
#   Embeddings top 1: [105]
# Text 202:
#   TF-IDF top 1: [270]
#   Embeddings top 1: [748]
# Text 203:
#   TF-IDF top 1: [42]
#   Embeddings top 1: [967]
# Text 204:
#   TF-IDF top 1: [204]
#   Embeddings top 1: [204]
# Text 205:
#   TF-IDF top 1: [373]
#   Embeddings top 1: [125]
# Text 206:
#   TF-IDF top 1: [245]
#   Embeddings top 1: [245]
# Text 207:
#   TF-IDF top 1: [132]
#   Embeddings top 1: [509]
# Text 208:
#   TF-IDF top 1: [359]
#   Embeddings top 1: [749]
# Text 209:
#   TF-IDF top 1: [204]
#   Embeddings top 1: [204]
# Text 210:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [211]
# Text 211:
#   TF-IDF top 1: [210]
#   Embeddings top 1: [83]
# Text 212:
#   TF-IDF top 1: [48]
#   Embeddings top 1: [83]
# Text 213:
#   TF-IDF top 1: [498]
#   Embeddings top 1: [780]
# Text 214:
#   TF-IDF top 1: [959]
#   Embeddings top 1: [276]
# Text 215:
#   TF-IDF top 1: [928]
#   Embeddings top 1: [928]
# Text 216:
#   TF-IDF top 1: [756]
#   Embeddings top 1: [762]
# Text 217:
#   TF-IDF top 1: [934]
#   Embeddings top 1: [734]
# Text 218:
#   TF-IDF top 1: [860]
#   Embeddings top 1: [883]
# Text 219:
#   TF-IDF top 1: [811]
#   Embeddings top 1: [466]
# Text 220:
#   TF-IDF top 1: [902]
#   Embeddings top 1: [972]
# Text 221:
#   TF-IDF top 1: [580]
#   Embeddings top 1: [302]
# Text 222:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [868]
# Text 223:
#   TF-IDF top 1: [701]
#   Embeddings top 1: [687]
# Text 224:
#   TF-IDF top 1: [936]
#   Embeddings top 1: [302]
# Text 225:
#   TF-IDF top 1: [520]
#   Embeddings top 1: [216]
# Text 226:
#   TF-IDF top 1: [791]
#   Embeddings top 1: [199]
# Text 227:
#   TF-IDF top 1: [854]
#   Embeddings top 1: [228]
# Text 228:
#   TF-IDF top 1: [134]
#   Embeddings top 1: [227]
# Text 229:
#   TF-IDF top 1: [533]
#   Embeddings top 1: [533]
# Text 230:
#   TF-IDF top 1: [972]
#   Embeddings top 1: [762]
# Text 231:
#   TF-IDF top 1: [384]
#   Embeddings top 1: [487]
# Text 232:
#   TF-IDF top 1: [105]
#   Embeddings top 1: [591]
# Text 233:
#   TF-IDF top 1: [236]
#   Embeddings top 1: [348]
# Text 234:
#   TF-IDF top 1: [922]
#   Embeddings top 1: [481]
# Text 235:
#   TF-IDF top 1: [679]
#   Embeddings top 1: [404]
# Text 236:
#   TF-IDF top 1: [233]
#   Embeddings top 1: [903]
# Text 237:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [845]
# Text 238:
#   TF-IDF top 1: [367]
#   Embeddings top 1: [734]
# Text 239:
#   TF-IDF top 1: [221]
#   Embeddings top 1: [724]
# Text 240:
#   TF-IDF top 1: [512]
#   Embeddings top 1: [734]
# Text 241:
#   TF-IDF top 1: [451]
#   Embeddings top 1: [302]
# Text 242:
#   TF-IDF top 1: [244]
#   Embeddings top 1: [244]
# Text 243:
#   TF-IDF top 1: [244]
#   Embeddings top 1: [244]
# Text 244:
#   TF-IDF top 1: [451]
#   Embeddings top 1: [241]
# Text 245:
#   TF-IDF top 1: [206]
#   Embeddings top 1: [206]
# Text 246:
#   TF-IDF top 1: [198]
#   Embeddings top 1: [405]
# Text 247:
#   TF-IDF top 1: [780]
#   Embeddings top 1: [130]
# Text 248:
#   TF-IDF top 1: [962]
#   Embeddings top 1: [696]
# Text 249:
#   TF-IDF top 1: [3]
#   Embeddings top 1: [253]
# Text 250:
#   TF-IDF top 1: [392]
#   Embeddings top 1: [691]
# Text 251:
#   TF-IDF top 1: [342]
#   Embeddings top 1: [342]
# Text 252:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [699]
# Text 253:
#   TF-IDF top 1: [94]
#   Embeddings top 1: [274]
# Text 254:
#   TF-IDF top 1: [339]
#   Embeddings top 1: [341]
# Text 255:
#   TF-IDF top 1: [685]
#   Embeddings top 1: [828]
# Text 256:
#   TF-IDF top 1: [815]
#   Embeddings top 1: [818]
# Text 257:
#   TF-IDF top 1: [265]
#   Embeddings top 1: [807]
# Text 258:
#   TF-IDF top 1: [10]
#   Embeddings top 1: [713]
# Text 259:
#   TF-IDF top 1: [113]
#   Embeddings top 1: [178]
# Text 260:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [407]
# Text 261:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [521]
# Text 262:
#   TF-IDF top 1: [907]
#   Embeddings top 1: [266]
# Text 263:
#   TF-IDF top 1: [79]
#   Embeddings top 1: [506]
# Text 264:
#   TF-IDF top 1: [506]
#   Embeddings top 1: [352]
# Text 265:
#   TF-IDF top 1: [464]
#   Embeddings top 1: [208]
# Text 266:
#   TF-IDF top 1: [481]
#   Embeddings top 1: [590]
# Text 267:
#   TF-IDF top 1: [174]
#   Embeddings top 1: [325]
# Text 268:
#   TF-IDF top 1: [903]
#   Embeddings top 1: [695]
# Text 269:
#   TF-IDF top 1: [300]
#   Embeddings top 1: [537]
# Text 270:
#   TF-IDF top 1: [202]
#   Embeddings top 1: [748]
# Text 271:
#   TF-IDF top 1: [595]
#   Embeddings top 1: [828]
# Text 272:
#   TF-IDF top 1: [541]
#   Embeddings top 1: [902]
# Text 273:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [274]
# Text 274:
#   TF-IDF top 1: [19]
#   Embeddings top 1: [420]
# Text 275:
#   TF-IDF top 1: [641]
#   Embeddings top 1: [641]
# Text 276:
#   TF-IDF top 1: [959]
#   Embeddings top 1: [214]
# Text 277:
#   TF-IDF top 1: [742]
#   Embeddings top 1: [100]
# Text 278:
#   TF-IDF top 1: [776]
#   Embeddings top 1: [845]
# Text 279:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [274]
# Text 280:
#   TF-IDF top 1: [989]
#   Embeddings top 1: [567]
# Text 281:
#   TF-IDF top 1: [553]
#   Embeddings top 1: [679]
# Text 282:
#   TF-IDF top 1: [374]
#   Embeddings top 1: [290]
# Text 283:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [54]
# Text 284:
#   TF-IDF top 1: [293]
#   Embeddings top 1: [734]
# Text 285:
#   TF-IDF top 1: [525]
#   Embeddings top 1: [486]
# Text 286:
#   TF-IDF top 1: [171]
#   Embeddings top 1: [575]
# Text 287:
#   TF-IDF top 1: [399]
#   Embeddings top 1: [958]
# Text 288:
#   TF-IDF top 1: [876]
#   Embeddings top 1: [59]
# Text 289:
#   TF-IDF top 1: [438]
#   Embeddings top 1: [12]
# Text 290:
#   TF-IDF top 1: [73]
#   Embeddings top 1: [484]
# Text 291:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [663]
# Text 292:
#   TF-IDF top 1: [361]
#   Embeddings top 1: [743]
# Text 293:
#   TF-IDF top 1: [284]
#   Embeddings top 1: [410]
# Text 294:
#   TF-IDF top 1: [165]
#   Embeddings top 1: [755]
# Text 295:
#   TF-IDF top 1: [525]
#   Embeddings top 1: [531]
# Text 296:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [546]
# Text 297:
#   TF-IDF top 1: [647]
#   Embeddings top 1: [531]
# Text 298:
#   TF-IDF top 1: [511]
#   Embeddings top 1: [614]
# Text 299:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [807]
# Text 300:
#   TF-IDF top 1: [867]
#   Embeddings top 1: [269]
# Text 301:
#   TF-IDF top 1: [143]
#   Embeddings top 1: [966]
# Text 302:
#   TF-IDF top 1: [242]
#   Embeddings top 1: [241]
# Text 303:
#   TF-IDF top 1: [867]
#   Embeddings top 1: [388]
# Text 304:
#   TF-IDF top 1: [71]
#   Embeddings top 1: [326]
# Text 305:
#   TF-IDF top 1: [771]
#   Embeddings top 1: [771]
# Text 306:
#   TF-IDF top 1: [341]
#   Embeddings top 1: [132]
# Text 307:
#   TF-IDF top 1: [110]
#   Embeddings top 1: [417]
# Text 308:
#   TF-IDF top 1: [30]
#   Embeddings top 1: [246]
# Text 309:
#   TF-IDF top 1: [657]
#   Embeddings top 1: [657]
# Text 310:
#   TF-IDF top 1: [117]
#   Embeddings top 1: [223]
# Text 311:
#   TF-IDF top 1: [235]
#   Embeddings top 1: [538]
# Text 312:
#   TF-IDF top 1: [28]
#   Embeddings top 1: [895]
# Text 313:
#   TF-IDF top 1: [872]
#   Embeddings top 1: [872]
# Text 314:
#   TF-IDF top 1: [28]
#   Embeddings top 1: [584]
# Text 315:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [305]
# Text 316:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [416]
# Text 317:
#   TF-IDF top 1: [647]
#   Embeddings top 1: [492]
# Text 318:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [595]
# Text 319:
#   TF-IDF top 1: [307]
#   Embeddings top 1: [154]
# Text 320:
#   TF-IDF top 1: [42]
#   Embeddings top 1: [819]
# Text 321:
#   TF-IDF top 1: [65]
#   Embeddings top 1: [730]
# Text 322:
#   TF-IDF top 1: [678]
#   Embeddings top 1: [465]
# Text 323:
#   TF-IDF top 1: [815]
#   Embeddings top 1: [780]
# Text 324:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [640]
# Text 325:
#   TF-IDF top 1: [238]
#   Embeddings top 1: [267]
# Text 326:
#   TF-IDF top 1: [88]
#   Embeddings top 1: [289]
# Text 327:
#   TF-IDF top 1: [342]
#   Embeddings top 1: [5]
# Text 328:
#   TF-IDF top 1: [811]
#   Embeddings top 1: [970]
# Text 329:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [597]
# Text 330:
#   TF-IDF top 1: [525]
#   Embeddings top 1: [409]
# Text 331:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [522]
# Text 332:
#   TF-IDF top 1: [936]
#   Embeddings top 1: [567]
# Text 333:
#   TF-IDF top 1: [464]
#   Embeddings top 1: [464]
# Text 334:
#   TF-IDF top 1: [884]
#   Embeddings top 1: [884]
# Text 335:
#   TF-IDF top 1: [606]
#   Embeddings top 1: [606]
# Text 336:
#   TF-IDF top 1: [964]
#   Embeddings top 1: [790]
# Text 337:
#   TF-IDF top 1: [513]
#   Embeddings top 1: [255]
# Text 338:
#   TF-IDF top 1: [740]
#   Embeddings top 1: [83]
# Text 339:
#   TF-IDF top 1: [254]
#   Embeddings top 1: [568]
# Text 340:
#   TF-IDF top 1: [128]
#   Embeddings top 1: [863]
# Text 341:
#   TF-IDF top 1: [306]
#   Embeddings top 1: [254]
# Text 342:
#   TF-IDF top 1: [251]
#   Embeddings top 1: [251]
# Text 343:
#   TF-IDF top 1: [225]
#   Embeddings top 1: [342]
# Text 344:
#   TF-IDF top 1: [699]
#   Embeddings top 1: [663]
# Text 345:
#   TF-IDF top 1: [232]
#   Embeddings top 1: [574]
# Text 346:
#   TF-IDF top 1: [280]
#   Embeddings top 1: [567]
# Text 347:
#   TF-IDF top 1: [31]
#   Embeddings top 1: [903]
# Text 348:
#   TF-IDF top 1: [623]
#   Embeddings top 1: [233]
# Text 349:
#   TF-IDF top 1: [418]
#   Embeddings top 1: [164]
# Text 350:
#   TF-IDF top 1: [826]
#   Embeddings top 1: [571]
# Text 351:
#   TF-IDF top 1: [70]
#   Embeddings top 1: [388]
# Text 352:
#   TF-IDF top 1: [481]
#   Embeddings top 1: [264]
# Text 353:
#   TF-IDF top 1: [533]
#   Embeddings top 1: [43]
# Text 354:
#   TF-IDF top 1: [892]
#   Embeddings top 1: [422]
# Text 355:
#   TF-IDF top 1: [747]
#   Embeddings top 1: [185]
# Text 356:
#   TF-IDF top 1: [176]
#   Embeddings top 1: [889]
# Text 357:
#   TF-IDF top 1: [209]
#   Embeddings top 1: [277]
# Text 358:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [580]
# Text 359:
#   TF-IDF top 1: [695]
#   Embeddings top 1: [731]
# Text 360:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [367]
# Text 361:
#   TF-IDF top 1: [768]
#   Embeddings top 1: [327]
# Text 362:
#   TF-IDF top 1: [681]
#   Embeddings top 1: [101]
# Text 363:
#   TF-IDF top 1: [138]
#   Embeddings top 1: [814]
# Text 364:
#   TF-IDF top 1: [742]
#   Embeddings top 1: [164]
# Text 365:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [324]
# Text 366:
#   TF-IDF top 1: [273]
#   Embeddings top 1: [807]
# Text 367:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [360]
# Text 368:
#   TF-IDF top 1: [815]
#   Embeddings top 1: [558]
# Text 369:
#   TF-IDF top 1: [622]
#   Embeddings top 1: [622]
# Text 370:
#   TF-IDF top 1: [277]
#   Embeddings top 1: [556]
# Text 371:
#   TF-IDF top 1: [762]
#   Embeddings top 1: [924]
# Text 372:
#   TF-IDF top 1: [560]
#   Embeddings top 1: [302]
# Text 373:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [410]
# Text 374:
#   TF-IDF top 1: [282]
#   Embeddings top 1: [684]
# Text 375:
#   TF-IDF top 1: [966]
#   Embeddings top 1: [111]
# Text 376:
#   TF-IDF top 1: [488]
#   Embeddings top 1: [586]
# Text 377:
#   TF-IDF top 1: [757]
#   Embeddings top 1: [436]
# Text 378:
#   TF-IDF top 1: [509]
#   Embeddings top 1: [154]
# Text 379:
#   TF-IDF top 1: [872]
#   Embeddings top 1: [765]
# Text 380:
#   TF-IDF top 1: [468]
#   Embeddings top 1: [35]
# Text 381:
#   TF-IDF top 1: [64]
#   Embeddings top 1: [467]
# Text 382:
#   TF-IDF top 1: [506]
#   Embeddings top 1: [216]
# Text 383:
#   TF-IDF top 1: [700]
#   Embeddings top 1: [141]
# Text 384:
#   TF-IDF top 1: [197]
#   Embeddings top 1: [828]
# Text 385:
#   TF-IDF top 1: [99]
#   Embeddings top 1: [126]
# Text 386:
#   TF-IDF top 1: [57]
#   Embeddings top 1: [67]
# Text 387:
#   TF-IDF top 1: [144]
#   Embeddings top 1: [191]
# Text 388:
#   TF-IDF top 1: [70]
#   Embeddings top 1: [548]
# Text 389:
#   TF-IDF top 1: [212]
#   Embeddings top 1: [589]
# Text 390:
#   TF-IDF top 1: [594]
#   Embeddings top 1: [554]
# Text 391:
#   TF-IDF top 1: [100]
#   Embeddings top 1: [199]
# Text 392:
#   TF-IDF top 1: [898]
#   Embeddings top 1: [193]
# Text 393:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [662]
# Text 394:
#   TF-IDF top 1: [888]
#   Embeddings top 1: [411]
# Text 395:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [885]
# Text 396:
#   TF-IDF top 1: [114]
#   Embeddings top 1: [164]
# Text 397:
#   TF-IDF top 1: [485]
#   Embeddings top 1: [982]
# Text 398:
#   TF-IDF top 1: [171]
#   Embeddings top 1: [939]
# Text 399:
#   TF-IDF top 1: [916]
#   Embeddings top 1: [454]
# Text 400:
#   TF-IDF top 1: [170]
#   Embeddings top 1: [446]
# Text 401:
#   TF-IDF top 1: [744]
#   Embeddings top 1: [872]
# Text 402:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [253]
# Text 403:
#   TF-IDF top 1: [808]
#   Embeddings top 1: [417]
# Text 404:
#   TF-IDF top 1: [253]
#   Embeddings top 1: [235]
# Text 405:
#   TF-IDF top 1: [165]
#   Embeddings top 1: [246]
# Text 406:
#   TF-IDF top 1: [411]
#   Embeddings top 1: [766]
# Text 407:
#   TF-IDF top 1: [622]
#   Embeddings top 1: [260]
# Text 408:
#   TF-IDF top 1: [700]
#   Embeddings top 1: [642]
# Text 409:
#   TF-IDF top 1: [724]
#   Embeddings top 1: [330]
# Text 410:
#   TF-IDF top 1: [411]
#   Embeddings top 1: [411]
# Text 411:
#   TF-IDF top 1: [410]
#   Embeddings top 1: [410]
# Text 412:
#   TF-IDF top 1: [765]
#   Embeddings top 1: [818]
# Text 413:
#   TF-IDF top 1: [493]
#   Embeddings top 1: [521]
# Text 414:
#   TF-IDF top 1: [120]
#   Embeddings top 1: [533]
# Text 415:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [749]
# Text 416:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [876]
# Text 417:
#   TF-IDF top 1: [508]
#   Embeddings top 1: [403]
# Text 418:
#   TF-IDF top 1: [667]
#   Embeddings top 1: [662]
# Text 419:
#   TF-IDF top 1: [912]
#   Embeddings top 1: [912]
# Text 420:
#   TF-IDF top 1: [458]
#   Embeddings top 1: [458]
# Text 421:
#   TF-IDF top 1: [931]
#   Embeddings top 1: [931]
# Text 422:
#   TF-IDF top 1: [931]
#   Embeddings top 1: [16]
# Text 423:
#   TF-IDF top 1: [992]
#   Embeddings top 1: [622]
# Text 424:
#   TF-IDF top 1: [218]
#   Embeddings top 1: [860]
# Text 425:
#   TF-IDF top 1: [975]
#   Embeddings top 1: [633]
# Text 426:
#   TF-IDF top 1: [861]
#   Embeddings top 1: [954]
# Text 427:
#   TF-IDF top 1: [428]
#   Embeddings top 1: [428]
# Text 428:
#   TF-IDF top 1: [429]
#   Embeddings top 1: [429]
# Text 429:
#   TF-IDF top 1: [428]
#   Embeddings top 1: [428]
# Text 430:
#   TF-IDF top 1: [490]
#   Embeddings top 1: [12]
# Text 431:
#   TF-IDF top 1: [731]
#   Embeddings top 1: [433]
# Text 432:
#   TF-IDF top 1: [624]
#   Embeddings top 1: [618]
# Text 433:
#   TF-IDF top 1: [63]
#   Embeddings top 1: [431]
# Text 434:
#   TF-IDF top 1: [46]
#   Embeddings top 1: [872]
# Text 435:
#   TF-IDF top 1: [23]
#   Embeddings top 1: [471]
# Text 436:
#   TF-IDF top 1: [194]
#   Embeddings top 1: [194]
# Text 437:
#   TF-IDF top 1: [383]
#   Embeddings top 1: [548]
# Text 438:
#   TF-IDF top 1: [426]
#   Embeddings top 1: [282]
# Text 439:
#   TF-IDF top 1: [34]
#   Embeddings top 1: [649]
# Text 440:
#   TF-IDF top 1: [555]
#   Embeddings top 1: [859]
# Text 441:
#   TF-IDF top 1: [577]
#   Embeddings top 1: [254]
# Text 442:
#   TF-IDF top 1: [149]
#   Embeddings top 1: [174]
# Text 443:
#   TF-IDF top 1: [303]
#   Embeddings top 1: [442]
# Text 444:
#   TF-IDF top 1: [479]
#   Embeddings top 1: [896]
# Text 445:
#   TF-IDF top 1: [29]
#   Embeddings top 1: [78]
# Text 446:
#   TF-IDF top 1: [451]
#   Embeddings top 1: [400]
# Text 447:
#   TF-IDF top 1: [444]
#   Embeddings top 1: [297]
# Text 448:
#   TF-IDF top 1: [844]
#   Embeddings top 1: [814]
# Text 449:
#   TF-IDF top 1: [197]
#   Embeddings top 1: [482]
# Text 450:
#   TF-IDF top 1: [520]
#   Embeddings top 1: [302]
# Text 451:
#   TF-IDF top 1: [446]
#   Embeddings top 1: [302]
# Text 452:
#   TF-IDF top 1: [766]
#   Embeddings top 1: [643]
# Text 453:
#   TF-IDF top 1: [493]
#   Embeddings top 1: [493]
# Text 454:
#   TF-IDF top 1: [902]
#   Embeddings top 1: [902]
# Text 455:
#   TF-IDF top 1: [542]
#   Embeddings top 1: [902]
# Text 456:
#   TF-IDF top 1: [521]
#   Embeddings top 1: [11]
# Text 457:
#   TF-IDF top 1: [227]
#   Embeddings top 1: [754]
# Text 458:
#   TF-IDF top 1: [14]
#   Embeddings top 1: [420]
# Text 459:
#   TF-IDF top 1: [538]
#   Embeddings top 1: [442]
# Text 460:
#   TF-IDF top 1: [506]
#   Embeddings top 1: [462]
# Text 461:
#   TF-IDF top 1: [202]
#   Embeddings top 1: [145]
# Text 462:
#   TF-IDF top 1: [460]
#   Embeddings top 1: [460]
# Text 463:
#   TF-IDF top 1: [285]
#   Embeddings top 1: [486]
# Text 464:
#   TF-IDF top 1: [19]
#   Embeddings top 1: [619]
# Text 465:
#   TF-IDF top 1: [137]
#   Embeddings top 1: [322]
# Text 466:
#   TF-IDF top 1: [639]
#   Embeddings top 1: [677]
# Text 467:
#   TF-IDF top 1: [513]
#   Embeddings top 1: [381]
# Text 468:
#   TF-IDF top 1: [927]
#   Embeddings top 1: [759]
# Text 469:
#   TF-IDF top 1: [855]
#   Embeddings top 1: [492]
# Text 470:
#   TF-IDF top 1: [936]
#   Embeddings top 1: [518]
# Text 471:
#   TF-IDF top 1: [890]
#   Embeddings top 1: [734]
# Text 472:
#   TF-IDF top 1: [224]
#   Embeddings top 1: [737]
# Text 473:
#   TF-IDF top 1: [931]
#   Embeddings top 1: [231]
# Text 474:
#   TF-IDF top 1: [453]
#   Embeddings top 1: [453]
# Text 475:
#   TF-IDF top 1: [789]
#   Embeddings top 1: [118]
# Text 476:
#   TF-IDF top 1: [477]
#   Embeddings top 1: [477]
# Text 477:
#   TF-IDF top 1: [476]
#   Embeddings top 1: [476]
# Text 478:
#   TF-IDF top 1: [605]
#   Embeddings top 1: [647]
# Text 479:
#   TF-IDF top 1: [637]
#   Embeddings top 1: [353]
# Text 480:
#   TF-IDF top 1: [395]
#   Embeddings top 1: [388]
# Text 481:
#   TF-IDF top 1: [384]
#   Embeddings top 1: [234]
# Text 482:
#   TF-IDF top 1: [458]
#   Embeddings top 1: [144]
# Text 483:
#   TF-IDF top 1: [119]
#   Embeddings top 1: [698]
# Text 484:
#   TF-IDF top 1: [603]
#   Embeddings top 1: [290]
# Text 485:
#   TF-IDF top 1: [609]
#   Embeddings top 1: [160]
# Text 486:
#   TF-IDF top 1: [339]
#   Embeddings top 1: [463]
# Text 487:
#   TF-IDF top 1: [799]
#   Embeddings top 1: [548]
# Text 488:
#   TF-IDF top 1: [212]
#   Embeddings top 1: [810]
# Text 489:
#   TF-IDF top 1: [242]
#   Embeddings top 1: [758]
# Text 490:
#   TF-IDF top 1: [47]
#   Embeddings top 1: [433]
# Text 491:
#   TF-IDF top 1: [839]
#   Embeddings top 1: [839]
# Text 492:
#   TF-IDF top 1: [569]
#   Embeddings top 1: [569]
# Text 493:
#   TF-IDF top 1: [453]
#   Embeddings top 1: [210]
# Text 494:
#   TF-IDF top 1: [67]
#   Embeddings top 1: [42]
# Text 495:
#   TF-IDF top 1: [291]
#   Embeddings top 1: [265]
# Text 496:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [879]
# Text 497:
#   TF-IDF top 1: [647]
#   Embeddings top 1: [758]
# Text 498:
#   TF-IDF top 1: [588]
#   Embeddings top 1: [731]
# Text 499:
#   TF-IDF top 1: [771]
#   Embeddings top 1: [668]
# Text 500:
#   TF-IDF top 1: [690]
#   Embeddings top 1: [690]
# Text 501:
#   TF-IDF top 1: [659]
#   Embeddings top 1: [659]
# Text 502:
#   TF-IDF top 1: [771]
#   Embeddings top 1: [130]
# Text 503:
#   TF-IDF top 1: [628]
#   Embeddings top 1: [783]
# Text 504:
#   TF-IDF top 1: [291]
#   Embeddings top 1: [168]
# Text 505:
#   TF-IDF top 1: [303]
#   Embeddings top 1: [56]
# Text 506:
#   TF-IDF top 1: [460]
#   Embeddings top 1: [808]
# Text 507:
#   TF-IDF top 1: [538]
#   Embeddings top 1: [538]
# Text 508:
#   TF-IDF top 1: [247]
#   Embeddings top 1: [130]
# Text 509:
#   TF-IDF top 1: [378]
#   Embeddings top 1: [187]
# Text 510:
#   TF-IDF top 1: [550]
#   Embeddings top 1: [550]
# Text 511:
#   TF-IDF top 1: [460]
#   Embeddings top 1: [68]
# Text 512:
#   TF-IDF top 1: [240]
#   Embeddings top 1: [730]
# Text 513:
#   TF-IDF top 1: [373]
#   Embeddings top 1: [730]
# Text 514:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [255]
# Text 515:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [526]
# Text 516:
#   TF-IDF top 1: [660]
#   Embeddings top 1: [921]
# Text 517:
#   TF-IDF top 1: [518]
#   Embeddings top 1: [518]
# Text 518:
#   TF-IDF top 1: [517]
#   Embeddings top 1: [517]
# Text 519:
#   TF-IDF top 1: [497]
#   Embeddings top 1: [797]
# Text 520:
#   TF-IDF top 1: [225]
#   Embeddings top 1: [382]
# Text 521:
#   TF-IDF top 1: [842]
#   Embeddings top 1: [261]
# Text 522:
#   TF-IDF top 1: [324]
#   Embeddings top 1: [640]
# Text 523:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [890]
# Text 524:
#   TF-IDF top 1: [43]
#   Embeddings top 1: [479]
# Text 525:
#   TF-IDF top 1: [285]
#   Embeddings top 1: [285]
# Text 526:
#   TF-IDF top 1: [551]
#   Embeddings top 1: [532]
# Text 527:
#   TF-IDF top 1: [60]
#   Embeddings top 1: [550]
# Text 528:
#   TF-IDF top 1: [13]
#   Embeddings top 1: [620]
# Text 529:
#   TF-IDF top 1: [178]
#   Embeddings top 1: [925]
# Text 530:
#   TF-IDF top 1: [288]
#   Embeddings top 1: [937]
# Text 531:
#   TF-IDF top 1: [103]
#   Embeddings top 1: [295]
# Text 532:
#   TF-IDF top 1: [113]
#   Embeddings top 1: [117]
# Text 533:
#   TF-IDF top 1: [10]
#   Embeddings top 1: [939]
# Text 534:
#   TF-IDF top 1: [977]
#   Embeddings top 1: [535]
# Text 535:
#   TF-IDF top 1: [49]
#   Embeddings top 1: [534]
# Text 536:
#   TF-IDF top 1: [114]
#   Embeddings top 1: [550]
# Text 537:
#   TF-IDF top 1: [60]
#   Embeddings top 1: [269]
# Text 538:
#   TF-IDF top 1: [585]
#   Embeddings top 1: [507]
# Text 539:
#   TF-IDF top 1: [346]
#   Embeddings top 1: [540]
# Text 540:
#   TF-IDF top 1: [317]
#   Embeddings top 1: [989]
# Text 541:
#   TF-IDF top 1: [118]
#   Embeddings top 1: [990]
# Text 542:
#   TF-IDF top 1: [540]
#   Embeddings top 1: [540]
# Text 543:
#   TF-IDF top 1: [29]
#   Embeddings top 1: [541]
# Text 544:
#   TF-IDF top 1: [329]
#   Embeddings top 1: [759]
# Text 545:
#   TF-IDF top 1: [188]
#   Embeddings top 1: [113]
# Text 546:
#   TF-IDF top 1: [513]
#   Embeddings top 1: [410]
# Text 547:
#   TF-IDF top 1: [859]
#   Embeddings top 1: [540]
# Text 548:
#   TF-IDF top 1: [837]
#   Embeddings top 1: [487]
# Text 549:
#   TF-IDF top 1: [863]
#   Embeddings top 1: [307]
# Text 550:
#   TF-IDF top 1: [538]
#   Embeddings top 1: [510]
# Text 551:
#   TF-IDF top 1: [988]
#   Embeddings top 1: [578]
# Text 552:
#   TF-IDF top 1: [643]
#   Embeddings top 1: [469]
# Text 553:
#   TF-IDF top 1: [281]
#   Embeddings top 1: [184]
# Text 554:
#   TF-IDF top 1: [725]
#   Embeddings top 1: [492]
# Text 555:
#   TF-IDF top 1: [648]
#   Embeddings top 1: [688]
# Text 556:
#   TF-IDF top 1: [815]
#   Embeddings top 1: [370]
# Text 557:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [387]
# Text 558:
#   TF-IDF top 1: [863]
#   Embeddings top 1: [463]
# Text 559:
#   TF-IDF top 1: [668]
#   Embeddings top 1: [222]
# Text 560:
#   TF-IDF top 1: [372]
#   Embeddings top 1: [770]
# Text 561:
#   TF-IDF top 1: [886]
#   Embeddings top 1: [88]
# Text 562:
#   TF-IDF top 1: [850]
#   Embeddings top 1: [842]
# Text 563:
#   TF-IDF top 1: [958]
#   Embeddings top 1: [958]
# Text 564:
#   TF-IDF top 1: [667]
#   Embeddings top 1: [726]
# Text 565:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [77]
# Text 566:
#   TF-IDF top 1: [574]
#   Embeddings top 1: [46]
# Text 567:
#   TF-IDF top 1: [989]
#   Embeddings top 1: [346]
# Text 568:
#   TF-IDF top 1: [764]
#   Embeddings top 1: [339]
# Text 569:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [492]
# Text 570:
#   TF-IDF top 1: [595]
#   Embeddings top 1: [576]
# Text 571:
#   TF-IDF top 1: [976]
#   Embeddings top 1: [802]
# Text 572:
#   TF-IDF top 1: [990]
#   Embeddings top 1: [777]
# Text 573:
#   TF-IDF top 1: [330]
#   Embeddings top 1: [202]
# Text 574:
#   TF-IDF top 1: [232]
#   Embeddings top 1: [345]
# Text 575:
#   TF-IDF top 1: [646]
#   Embeddings top 1: [618]
# Text 576:
#   TF-IDF top 1: [423]
#   Embeddings top 1: [188]
# Text 577:
#   TF-IDF top 1: [441]
#   Embeddings top 1: [105]
# Text 578:
#   TF-IDF top 1: [843]
#   Embeddings top 1: [710]
# Text 579:
#   TF-IDF top 1: [754]
#   Embeddings top 1: [873]
# Text 580:
#   TF-IDF top 1: [161]
#   Embeddings top 1: [358]
# Text 581:
#   TF-IDF top 1: [273]
#   Embeddings top 1: [512]
# Text 582:
#   TF-IDF top 1: [671]
#   Embeddings top 1: [671]
# Text 583:
#   TF-IDF top 1: [251]
#   Embeddings top 1: [997]
# Text 584:
#   TF-IDF top 1: [427]
#   Embeddings top 1: [593]
# Text 585:
#   TF-IDF top 1: [665]
#   Embeddings top 1: [665]
# Text 586:
#   TF-IDF top 1: [3]
#   Embeddings top 1: [734]
# Text 587:
#   TF-IDF top 1: [323]
#   Embeddings top 1: [710]
# Text 588:
#   TF-IDF top 1: [498]
#   Embeddings top 1: [663]
# Text 589:
#   TF-IDF top 1: [871]
#   Embeddings top 1: [734]
# Text 590:
#   TF-IDF top 1: [393]
#   Embeddings top 1: [266]
# Text 591:
#   TF-IDF top 1: [271]
#   Embeddings top 1: [191]
# Text 592:
#   TF-IDF top 1: [336]
#   Embeddings top 1: [579]
# Text 593:
#   TF-IDF top 1: [10]
#   Embeddings top 1: [608]
# Text 594:
#   TF-IDF top 1: [99]
#   Embeddings top 1: [318]
# Text 595:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [318]
# Text 596:
#   TF-IDF top 1: [532]
#   Embeddings top 1: [54]
# Text 597:
#   TF-IDF top 1: [121]
#   Embeddings top 1: [329]
# Text 598:
#   TF-IDF top 1: [647]
#   Embeddings top 1: [696]
# Text 599:
#   TF-IDF top 1: [339]
#   Embeddings top 1: [777]
# Text 600:
#   TF-IDF top 1: [966]
#   Embeddings top 1: [208]
# Text 601:
#   TF-IDF top 1: [538]
#   Embeddings top 1: [603]
# Text 602:
#   TF-IDF top 1: [91]
#   Embeddings top 1: [113]
# Text 603:
#   TF-IDF top 1: [855]
#   Embeddings top 1: [855]
# Text 604:
#   TF-IDF top 1: [714]
#   Embeddings top 1: [488]
# Text 605:
#   TF-IDF top 1: [429]
#   Embeddings top 1: [998]
# Text 606:
#   TF-IDF top 1: [335]
#   Embeddings top 1: [335]
# Text 607:
#   TF-IDF top 1: [210]
#   Embeddings top 1: [210]
# Text 608:
#   TF-IDF top 1: [977]
#   Embeddings top 1: [593]
# Text 609:
#   TF-IDF top 1: [509]
#   Embeddings top 1: [845]
# Text 610:
#   TF-IDF top 1: [187]
#   Embeddings top 1: [827]
# Text 611:
#   TF-IDF top 1: [957]
#   Embeddings top 1: [434]
# Text 612:
#   TF-IDF top 1: [502]
#   Embeddings top 1: [708]
# Text 613:
#   TF-IDF top 1: [955]
#   Embeddings top 1: [298]
# Text 614:
#   TF-IDF top 1: [565]
#   Embeddings top 1: [298]
# Text 615:
#   TF-IDF top 1: [601]
#   Embeddings top 1: [632]
# Text 616:
#   TF-IDF top 1: [723]
#   Embeddings top 1: [896]
# Text 617:
#   TF-IDF top 1: [792]
#   Embeddings top 1: [761]
# Text 618:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [432]
# Text 619:
#   TF-IDF top 1: [458]
#   Embeddings top 1: [953]
# Text 620:
#   TF-IDF top 1: [100]
#   Embeddings top 1: [528]
# Text 621:
#   TF-IDF top 1: [792]
#   Embeddings top 1: [556]
# Text 622:
#   TF-IDF top 1: [369]
#   Embeddings top 1: [716]
# Text 623:
#   TF-IDF top 1: [968]
#   Embeddings top 1: [968]
# Text 624:
#   TF-IDF top 1: [569]
#   Embeddings top 1: [982]
# Text 625:
#   TF-IDF top 1: [903]
#   Embeddings top 1: [903]
# Text 626:
#   TF-IDF top 1: [470]
#   Embeddings top 1: [622]
# Text 627:
#   TF-IDF top 1: [789]
#   Embeddings top 1: [33]
# Text 628:
#   TF-IDF top 1: [396]
#   Embeddings top 1: [59]
# Text 629:
#   TF-IDF top 1: [178]
#   Embeddings top 1: [86]
# Text 630:
#   TF-IDF top 1: [908]
#   Embeddings top 1: [949]
# Text 631:
#   TF-IDF top 1: [945]
#   Embeddings top 1: [945]
# Text 632:
#   TF-IDF top 1: [707]
#   Embeddings top 1: [635]
# Text 633:
#   TF-IDF top 1: [365]
#   Embeddings top 1: [365]
# Text 634:
#   TF-IDF top 1: [640]
#   Embeddings top 1: [324]
# Text 635:
#   TF-IDF top 1: [660]
#   Embeddings top 1: [632]
# Text 636:
#   TF-IDF top 1: [635]
#   Embeddings top 1: [882]
# Text 637:
#   TF-IDF top 1: [479]
#   Embeddings top 1: [639]
# Text 638:
#   TF-IDF top 1: [324]
#   Embeddings top 1: [28]
# Text 639:
#   TF-IDF top 1: [365]
#   Embeddings top 1: [522]
# Text 640:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [324]
# Text 641:
#   TF-IDF top 1: [275]
#   Embeddings top 1: [275]
# Text 642:
#   TF-IDF top 1: [36]
#   Embeddings top 1: [408]
# Text 643:
#   TF-IDF top 1: [57]
#   Embeddings top 1: [644]
# Text 644:
#   TF-IDF top 1: [643]
#   Embeddings top 1: [643]
# Text 645:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [870]
# Text 646:
#   TF-IDF top 1: [310]
#   Embeddings top 1: [575]
# Text 647:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [758]
# Text 648:
#   TF-IDF top 1: [555]
#   Embeddings top 1: [35]
# Text 649:
#   TF-IDF top 1: [42]
#   Embeddings top 1: [596]
# Text 650:
#   TF-IDF top 1: [980]
#   Embeddings top 1: [903]
# Text 651:
#   TF-IDF top 1: [725]
#   Embeddings top 1: [771]
# Text 652:
#   TF-IDF top 1: [475]
#   Embeddings top 1: [823]
# Text 653:
#   TF-IDF top 1: [737]
#   Embeddings top 1: [590]
# Text 654:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [887]
# Text 655:
#   TF-IDF top 1: [517]
#   Embeddings top 1: [819]
# Text 656:
#   TF-IDF top 1: [42]
#   Embeddings top 1: [42]
# Text 657:
#   TF-IDF top 1: [309]
#   Embeddings top 1: [309]
# Text 658:
#   TF-IDF top 1: [202]
#   Embeddings top 1: [572]
# Text 659:
#   TF-IDF top 1: [501]
#   Embeddings top 1: [501]
# Text 660:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [998]
# Text 661:
#   TF-IDF top 1: [840]
#   Embeddings top 1: [133]
# Text 662:
#   TF-IDF top 1: [388]
#   Embeddings top 1: [393]
# Text 663:
#   TF-IDF top 1: [340]
#   Embeddings top 1: [344]
# Text 664:
#   TF-IDF top 1: [65]
#   Embeddings top 1: [994]
# Text 665:
#   TF-IDF top 1: [585]
#   Embeddings top 1: [585]
# Text 666:
#   TF-IDF top 1: [304]
#   Embeddings top 1: [491]
# Text 667:
#   TF-IDF top 1: [114]
#   Embeddings top 1: [164]
# Text 668:
#   TF-IDF top 1: [559]
#   Embeddings top 1: [208]
# Text 669:
#   TF-IDF top 1: [569]
#   Embeddings top 1: [492]
# Text 670:
#   TF-IDF top 1: [173]
#   Embeddings top 1: [513]
# Text 671:
#   TF-IDF top 1: [28]
#   Embeddings top 1: [582]
# Text 672:
#   TF-IDF top 1: [811]
#   Embeddings top 1: [191]
# Text 673:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [678]
# Text 674:
#   TF-IDF top 1: [350]
#   Embeddings top 1: [628]
# Text 675:
#   TF-IDF top 1: [494]
#   Embeddings top 1: [509]
# Text 676:
#   TF-IDF top 1: [975]
#   Embeddings top 1: [180]
# Text 677:
#   TF-IDF top 1: [804]
#   Embeddings top 1: [466]
# Text 678:
#   TF-IDF top 1: [322]
#   Embeddings top 1: [205]
# Text 679:
#   TF-IDF top 1: [235]
#   Embeddings top 1: [281]
# Text 680:
#   TF-IDF top 1: [958]
#   Embeddings top 1: [973]
# Text 681:
#   TF-IDF top 1: [816]
#   Embeddings top 1: [844]
# Text 682:
#   TF-IDF top 1: [130]
#   Embeddings top 1: [612]
# Text 683:
#   TF-IDF top 1: [881]
#   Embeddings top 1: [799]
# Text 684:
#   TF-IDF top 1: [181]
#   Embeddings top 1: [374]
# Text 685:
#   TF-IDF top 1: [730]
#   Embeddings top 1: [953]
# Text 686:
#   TF-IDF top 1: [804]
#   Embeddings top 1: [903]
# Text 687:
#   TF-IDF top 1: [680]
#   Embeddings top 1: [223]
# Text 688:
#   TF-IDF top 1: [675]
#   Embeddings top 1: [345]
# Text 689:
#   TF-IDF top 1: [857]
#   Embeddings top 1: [857]
# Text 690:
#   TF-IDF top 1: [500]
#   Embeddings top 1: [500]
# Text 691:
#   TF-IDF top 1: [42]
#   Embeddings top 1: [26]
# Text 692:
#   TF-IDF top 1: [730]
#   Embeddings top 1: [387]
# Text 693:
#   TF-IDF top 1: [509]
#   Embeddings top 1: [167]
# Text 694:
#   TF-IDF top 1: [458]
#   Embeddings top 1: [846]
# Text 695:
#   TF-IDF top 1: [551]
#   Embeddings top 1: [268]
# Text 696:
#   TF-IDF top 1: [545]
#   Embeddings top 1: [540]
# Text 697:
#   TF-IDF top 1: [369]
#   Embeddings top 1: [169]
# Text 698:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [483]
# Text 699:
#   TF-IDF top 1: [948]
#   Embeddings top 1: [252]
# Text 700:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [787]
# Text 701:
#   TF-IDF top 1: [200]
#   Embeddings top 1: [620]
# Text 702:
#   TF-IDF top 1: [493]
#   Embeddings top 1: [562]
# Text 703:
#   TF-IDF top 1: [637]
#   Embeddings top 1: [414]
# Text 704:
#   TF-IDF top 1: [423]
#   Embeddings top 1: [696]
# Text 705:
#   TF-IDF top 1: [201]
#   Embeddings top 1: [201]
# Text 706:
#   TF-IDF top 1: [316]
#   Embeddings top 1: [857]
# Text 707:
#   TF-IDF top 1: [910]
#   Embeddings top 1: [910]
# Text 708:
#   TF-IDF top 1: [189]
#   Embeddings top 1: [712]
# Text 709:
#   TF-IDF top 1: [502]
#   Embeddings top 1: [265]
# Text 710:
#   TF-IDF top 1: [897]
#   Embeddings top 1: [578]
# Text 711:
#   TF-IDF top 1: [82]
#   Embeddings top 1: [805]
# Text 712:
#   TF-IDF top 1: [913]
#   Embeddings top 1: [708]
# Text 713:
#   TF-IDF top 1: [860]
#   Embeddings top 1: [860]
# Text 714:
#   TF-IDF top 1: [813]
#   Embeddings top 1: [913]
# Text 715:
#   TF-IDF top 1: [736]
#   Embeddings top 1: [138]
# Text 716:
#   TF-IDF top 1: [224]
#   Embeddings top 1: [622]
# Text 717:
#   TF-IDF top 1: [44]
#   Embeddings top 1: [478]
# Text 718:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [811]
# Text 719:
#   TF-IDF top 1: [32]
#   Embeddings top 1: [826]
# Text 720:
#   TF-IDF top 1: [132]
#   Embeddings top 1: [306]
# Text 721:
#   TF-IDF top 1: [239]
#   Embeddings top 1: [245]
# Text 722:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [903]
# Text 723:
#   TF-IDF top 1: [404]
#   Embeddings top 1: [475]
# Text 724:
#   TF-IDF top 1: [747]
#   Embeddings top 1: [747]
# Text 725:
#   TF-IDF top 1: [842]
#   Embeddings top 1: [130]
# Text 726:
#   TF-IDF top 1: [784]
#   Embeddings top 1: [564]
# Text 727:
#   TF-IDF top 1: [744]
#   Embeddings top 1: [728]
# Text 728:
#   TF-IDF top 1: [815]
#   Embeddings top 1: [729]
# Text 729:
#   TF-IDF top 1: [728]
#   Embeddings top 1: [728]
# Text 730:
#   TF-IDF top 1: [581]
#   Embeddings top 1: [734]
# Text 731:
#   TF-IDF top 1: [431]
#   Embeddings top 1: [498]
# Text 732:
#   TF-IDF top 1: [94]
#   Embeddings top 1: [40]
# Text 733:
#   TF-IDF top 1: [303]
#   Embeddings top 1: [109]
# Text 734:
#   TF-IDF top 1: [152]
#   Embeddings top 1: [240]
# Text 735:
#   TF-IDF top 1: [261]
#   Embeddings top 1: [412]
# Text 736:
#   TF-IDF top 1: [715]
#   Embeddings top 1: [270]
# Text 737:
#   TF-IDF top 1: [653]
#   Embeddings top 1: [952]
# Text 738:
#   TF-IDF top 1: [634]
#   Embeddings top 1: [671]
# Text 739:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [51]
# Text 740:
#   TF-IDF top 1: [525]
#   Embeddings top 1: [945]
# Text 741:
#   TF-IDF top 1: [941]
#   Embeddings top 1: [755]
# Text 742:
#   TF-IDF top 1: [667]
#   Embeddings top 1: [164]
# Text 743:
#   TF-IDF top 1: [992]
#   Embeddings top 1: [292]
# Text 744:
#   TF-IDF top 1: [727]
#   Embeddings top 1: [216]
# Text 745:
#   TF-IDF top 1: [718]
#   Embeddings top 1: [718]
# Text 746:
#   TF-IDF top 1: [764]
#   Embeddings top 1: [508]
# Text 747:
#   TF-IDF top 1: [101]
#   Embeddings top 1: [748]
# Text 748:
#   TF-IDF top 1: [185]
#   Embeddings top 1: [185]
# Text 749:
#   TF-IDF top 1: [759]
#   Embeddings top 1: [208]
# Text 750:
#   TF-IDF top 1: [751]
#   Embeddings top 1: [903]
# Text 751:
#   TF-IDF top 1: [627]
#   Embeddings top 1: [254]
# Text 752:
#   TF-IDF top 1: [496]
#   Embeddings top 1: [931]
# Text 753:
#   TF-IDF top 1: [595]
#   Embeddings top 1: [909]
# Text 754:
#   TF-IDF top 1: [342]
#   Embeddings top 1: [457]
# Text 755:
#   TF-IDF top 1: [411]
#   Embeddings top 1: [741]
# Text 756:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [798]
# Text 757:
#   TF-IDF top 1: [10]
#   Embeddings top 1: [377]
# Text 758:
#   TF-IDF top 1: [598]
#   Embeddings top 1: [647]
# Text 759:
#   TF-IDF top 1: [908]
#   Embeddings top 1: [468]
# Text 760:
#   TF-IDF top 1: [100]
#   Embeddings top 1: [508]
# Text 761:
#   TF-IDF top 1: [59]
#   Embeddings top 1: [33]
# Text 762:
#   TF-IDF top 1: [902]
#   Embeddings top 1: [902]
# Text 763:
#   TF-IDF top 1: [762]
#   Embeddings top 1: [762]
# Text 764:
#   TF-IDF top 1: [746]
#   Embeddings top 1: [511]
# Text 765:
#   TF-IDF top 1: [792]
#   Embeddings top 1: [412]
# Text 766:
#   TF-IDF top 1: [452]
#   Embeddings top 1: [406]
# Text 767:
#   TF-IDF top 1: [60]
#   Embeddings top 1: [537]
# Text 768:
#   TF-IDF top 1: [361]
#   Embeddings top 1: [754]
# Text 769:
#   TF-IDF top 1: [114]
#   Embeddings top 1: [409]
# Text 770:
#   TF-IDF top 1: [279]
#   Embeddings top 1: [619]
# Text 771:
#   TF-IDF top 1: [502]
#   Embeddings top 1: [305]
# Text 772:
#   TF-IDF top 1: [773]
#   Embeddings top 1: [773]
# Text 773:
#   TF-IDF top 1: [772]
#   Embeddings top 1: [772]
# Text 774:
#   TF-IDF top 1: [247]
#   Embeddings top 1: [698]
# Text 775:
#   TF-IDF top 1: [62]
#   Embeddings top 1: [551]
# Text 776:
#   TF-IDF top 1: [278]
#   Embeddings top 1: [999]
# Text 777:
#   TF-IDF top 1: [56]
#   Embeddings top 1: [56]
# Text 778:
#   TF-IDF top 1: [779]
#   Embeddings top 1: [779]
# Text 779:
#   TF-IDF top 1: [865]
#   Embeddings top 1: [778]
# Text 780:
#   TF-IDF top 1: [818]
#   Embeddings top 1: [818]
# Text 781:
#   TF-IDF top 1: [463]
#   Embeddings top 1: [609]
# Text 782:
#   TF-IDF top 1: [809]
#   Embeddings top 1: [429]
# Text 783:
#   TF-IDF top 1: [210]
#   Embeddings top 1: [889]
# Text 784:
#   TF-IDF top 1: [726]
#   Embeddings top 1: [999]
# Text 785:
#   TF-IDF top 1: [291]
#   Embeddings top 1: [937]
# Text 786:
#   TF-IDF top 1: [86]
#   Embeddings top 1: [518]
# Text 787:
#   TF-IDF top 1: [843]
#   Embeddings top 1: [700]
# Text 788:
#   TF-IDF top 1: [453]
#   Embeddings top 1: [663]
# Text 789:
#   TF-IDF top 1: [627]
#   Embeddings top 1: [903]
# Text 790:
#   TF-IDF top 1: [653]
#   Embeddings top 1: [345]
# Text 791:
#   TF-IDF top 1: [674]
#   Embeddings top 1: [737]
# Text 792:
#   TF-IDF top 1: [765]
#   Embeddings top 1: [815]
# Text 793:
#   TF-IDF top 1: [836]
#   Embeddings top 1: [181]
# Text 794:
#   TF-IDF top 1: [424]
#   Embeddings top 1: [96]
# Text 795:
#   TF-IDF top 1: [709]
#   Embeddings top 1: [817]
# Text 796:
#   TF-IDF top 1: [763]
#   Embeddings top 1: [245]
# Text 797:
#   TF-IDF top 1: [569]
#   Embeddings top 1: [519]
# Text 798:
#   TF-IDF top 1: [59]
#   Embeddings top 1: [59]
# Text 799:
#   TF-IDF top 1: [744]
#   Embeddings top 1: [226]
# Text 800:
#   TF-IDF top 1: [28]
#   Embeddings top 1: [28]
# Text 801:
#   TF-IDF top 1: [824]
#   Embeddings top 1: [297]
# Text 802:
#   TF-IDF top 1: [246]
#   Embeddings top 1: [958]
# Text 803:
#   TF-IDF top 1: [861]
#   Embeddings top 1: [371]
# Text 804:
#   TF-IDF top 1: [677]
#   Embeddings top 1: [323]
# Text 805:
#   TF-IDF top 1: [806]
#   Embeddings top 1: [806]
# Text 806:
#   TF-IDF top 1: [805]
#   Embeddings top 1: [805]
# Text 807:
#   TF-IDF top 1: [227]
#   Embeddings top 1: [366]
# Text 808:
#   TF-IDF top 1: [337]
#   Embeddings top 1: [506]
# Text 809:
#   TF-IDF top 1: [37]
#   Embeddings top 1: [37]
# Text 810:
#   TF-IDF top 1: [211]
#   Embeddings top 1: [886]
# Text 811:
#   TF-IDF top 1: [672]
#   Embeddings top 1: [889]
# Text 812:
#   TF-IDF top 1: [70]
#   Embeddings top 1: [11]
# Text 813:
#   TF-IDF top 1: [544]
#   Embeddings top 1: [714]
# Text 814:
#   TF-IDF top 1: [304]
#   Embeddings top 1: [448]
# Text 815:
#   TF-IDF top 1: [155]
#   Embeddings top 1: [412]
# Text 816:
#   TF-IDF top 1: [681]
#   Embeddings top 1: [814]
# Text 817:
#   TF-IDF top 1: [822]
#   Embeddings top 1: [822]
# Text 818:
#   TF-IDF top 1: [780]
#   Embeddings top 1: [412]
# Text 819:
#   TF-IDF top 1: [227]
#   Embeddings top 1: [320]
# Text 820:
#   TF-IDF top 1: [691]
#   Embeddings top 1: [38]
# Text 821:
#   TF-IDF top 1: [50]
#   Embeddings top 1: [803]
# Text 822:
#   TF-IDF top 1: [817]
#   Embeddings top 1: [817]
# Text 823:
#   TF-IDF top 1: [525]
#   Embeddings top 1: [103]
# Text 824:
#   TF-IDF top 1: [801]
#   Embeddings top 1: [940]
# Text 825:
#   TF-IDF top 1: [294]
#   Embeddings top 1: [96]
# Text 826:
#   TF-IDF top 1: [350]
#   Embeddings top 1: [719]
# Text 827:
#   TF-IDF top 1: [831]
#   Embeddings top 1: [187]
# Text 828:
#   TF-IDF top 1: [255]
#   Embeddings top 1: [255]
# Text 829:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [972]
# Text 830:
#   TF-IDF top 1: [303]
#   Embeddings top 1: [892]
# Text 831:
#   TF-IDF top 1: [187]
#   Embeddings top 1: [827]
# Text 832:
#   TF-IDF top 1: [797]
#   Embeddings top 1: [2]
# Text 833:
#   TF-IDF top 1: [867]
#   Embeddings top 1: [830]
# Text 834:
#   TF-IDF top 1: [886]
#   Embeddings top 1: [42]
# Text 835:
#   TF-IDF top 1: [254]
#   Embeddings top 1: [889]
# Text 836:
#   TF-IDF top 1: [793]
#   Embeddings top 1: [466]
# Text 837:
#   TF-IDF top 1: [548]
#   Embeddings top 1: [892]
# Text 838:
#   TF-IDF top 1: [728]
#   Embeddings top 1: [911]
# Text 839:
#   TF-IDF top 1: [491]
#   Embeddings top 1: [491]
# Text 840:
#   TF-IDF top 1: [399]
#   Embeddings top 1: [839]
# Text 841:
#   TF-IDF top 1: [976]
#   Embeddings top 1: [266]
# Text 842:
#   TF-IDF top 1: [261]
#   Embeddings top 1: [562]
# Text 843:
#   TF-IDF top 1: [578]
#   Embeddings top 1: [952]
# Text 844:
#   TF-IDF top 1: [190]
#   Embeddings top 1: [681]
# Text 845:
#   TF-IDF top 1: [609]
#   Embeddings top 1: [609]
# Text 846:
#   TF-IDF top 1: [553]
#   Embeddings top 1: [798]
# Text 847:
#   TF-IDF top 1: [457]
#   Embeddings top 1: [597]
# Text 848:
#   TF-IDF top 1: [943]
#   Embeddings top 1: [202]
# Text 849:
#   TF-IDF top 1: [767]
#   Embeddings top 1: [885]
# Text 850:
#   TF-IDF top 1: [747]
#   Embeddings top 1: [146]
# Text 851:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [811]
# Text 852:
#   TF-IDF top 1: [565]
#   Embeddings top 1: [54]
# Text 853:
#   TF-IDF top 1: [254]
#   Embeddings top 1: [226]
# Text 854:
#   TF-IDF top 1: [227]
#   Embeddings top 1: [886]
# Text 855:
#   TF-IDF top 1: [603]
#   Embeddings top 1: [603]
# Text 856:
#   TF-IDF top 1: [634]
#   Embeddings top 1: [159]
# Text 857:
#   TF-IDF top 1: [689]
#   Embeddings top 1: [706]
# Text 858:
#   TF-IDF top 1: [947]
#   Embeddings top 1: [9]
# Text 859:
#   TF-IDF top 1: [955]
#   Embeddings top 1: [925]
# Text 860:
#   TF-IDF top 1: [713]
#   Embeddings top 1: [713]
# Text 861:
#   TF-IDF top 1: [454]
#   Embeddings top 1: [197]
# Text 862:
#   TF-IDF top 1: [892]
#   Embeddings top 1: [188]
# Text 863:
#   TF-IDF top 1: [558]
#   Embeddings top 1: [340]
# Text 864:
#   TF-IDF top 1: [736]
#   Embeddings top 1: [828]
# Text 865:
#   TF-IDF top 1: [779]
#   Embeddings top 1: [779]
# Text 866:
#   TF-IDF top 1: [468]
#   Embeddings top 1: [314]
# Text 867:
#   TF-IDF top 1: [881]
#   Embeddings top 1: [881]
# Text 868:
#   TF-IDF top 1: [421]
#   Embeddings top 1: [222]
# Text 869:
#   TF-IDF top 1: [147]
#   Embeddings top 1: [998]
# Text 870:
#   TF-IDF top 1: [92]
#   Embeddings top 1: [878]
# Text 871:
#   TF-IDF top 1: [458]
#   Embeddings top 1: [709]
# Text 872:
#   TF-IDF top 1: [313]
#   Embeddings top 1: [401]
# Text 873:
#   TF-IDF top 1: [735]
#   Embeddings top 1: [274]
# Text 874:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [318]
# Text 875:
#   TF-IDF top 1: [84]
#   Embeddings top 1: [197]
# Text 876:
#   TF-IDF top 1: [932]
#   Embeddings top 1: [416]
# Text 877:
#   TF-IDF top 1: [127]
#   Embeddings top 1: [127]
# Text 878:
#   TF-IDF top 1: [972]
#   Embeddings top 1: [870]
# Text 879:
#   TF-IDF top 1: [937]
#   Embeddings top 1: [780]
# Text 880:
#   TF-IDF top 1: [619]
#   Embeddings top 1: [7]
# Text 881:
#   TF-IDF top 1: [867]
#   Embeddings top 1: [867]
# Text 882:
#   TF-IDF top 1: [634]
#   Embeddings top 1: [324]
# Text 883:
#   TF-IDF top 1: [869]
#   Embeddings top 1: [983]
# Text 884:
#   TF-IDF top 1: [334]
#   Embeddings top 1: [334]
# Text 885:
#   TF-IDF top 1: [395]
#   Embeddings top 1: [395]
# Text 886:
#   TF-IDF top 1: [956]
#   Embeddings top 1: [486]
# Text 887:
#   TF-IDF top 1: [620]
#   Embeddings top 1: [654]
# Text 888:
#   TF-IDF top 1: [216]
#   Embeddings top 1: [741]
# Text 889:
#   TF-IDF top 1: [672]
#   Embeddings top 1: [835]
# Text 890:
#   TF-IDF top 1: [471]
#   Embeddings top 1: [523]
# Text 891:
#   TF-IDF top 1: [449]
#   Embeddings top 1: [505]
# Text 892:
#   TF-IDF top 1: [354]
#   Embeddings top 1: [830]
# Text 893:
#   TF-IDF top 1: [35]
#   Embeddings top 1: [452]
# Text 894:
#   TF-IDF top 1: [899]
#   Embeddings top 1: [972]
# Text 895:
#   TF-IDF top 1: [501]
#   Embeddings top 1: [312]
# Text 896:
#   TF-IDF top 1: [538]
#   Embeddings top 1: [962]
# Text 897:
#   TF-IDF top 1: [728]
#   Embeddings top 1: [261]
# Text 898:
#   TF-IDF top 1: [948]
#   Embeddings top 1: [628]
# Text 899:
#   TF-IDF top 1: [241]
#   Embeddings top 1: [400]
# Text 900:
#   TF-IDF top 1: [361]
#   Embeddings top 1: [623]
# Text 901:
#   TF-IDF top 1: [541]
#   Embeddings top 1: [233]
# Text 902:
#   TF-IDF top 1: [762]
#   Embeddings top 1: [454]
# Text 903:
#   TF-IDF top 1: [268]
#   Embeddings top 1: [789]
# Text 904:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [231]
# Text 905:
#   TF-IDF top 1: [315]
#   Embeddings top 1: [317]
# Text 906:
#   TF-IDF top 1: [929]
#   Embeddings top 1: [4]
# Text 907:
#   TF-IDF top 1: [262]
#   Embeddings top 1: [909]
# Text 908:
#   TF-IDF top 1: [383]
#   Embeddings top 1: [857]
# Text 909:
#   TF-IDF top 1: [151]
#   Embeddings top 1: [907]
# Text 910:
#   TF-IDF top 1: [707]
#   Embeddings top 1: [707]
# Text 911:
#   TF-IDF top 1: [727]
#   Embeddings top 1: [487]
# Text 912:
#   TF-IDF top 1: [419]
#   Embeddings top 1: [419]
# Text 913:
#   TF-IDF top 1: [975]
#   Embeddings top 1: [921]
# Text 914:
#   TF-IDF top 1: [245]
#   Embeddings top 1: [335]
# Text 915:
#   TF-IDF top 1: [92]
#   Embeddings top 1: [132]
# Text 916:
#   TF-IDF top 1: [399]
#   Embeddings top 1: [399]
# Text 917:
#   TF-IDF top 1: [412]
#   Embeddings top 1: [412]
# Text 918:
#   TF-IDF top 1: [907]
#   Embeddings top 1: [919]
# Text 919:
#   TF-IDF top 1: [333]
#   Embeddings top 1: [918]
# Text 920:
#   TF-IDF top 1: [154]
#   Embeddings top 1: [931]
# Text 921:
#   TF-IDF top 1: [590]
#   Embeddings top 1: [913]
# Text 922:
#   TF-IDF top 1: [892]
#   Embeddings top 1: [437]
# Text 923:
#   TF-IDF top 1: [75]
#   Embeddings top 1: [933]
# Text 924:
#   TF-IDF top 1: [230]
#   Embeddings top 1: [371]
# Text 925:
#   TF-IDF top 1: [113]
#   Embeddings top 1: [259]
# Text 926:
#   TF-IDF top 1: [269]
#   Embeddings top 1: [109]
# Text 927:
#   TF-IDF top 1: [855]
#   Embeddings top 1: [317]
# Text 928:
#   TF-IDF top 1: [215]
#   Embeddings top 1: [215]
# Text 929:
#   TF-IDF top 1: [700]
#   Embeddings top 1: [714]
# Text 930:
#   TF-IDF top 1: [812]
#   Embeddings top 1: [786]
# Text 931:
#   TF-IDF top 1: [473]
#   Embeddings top 1: [920]
# Text 932:
#   TF-IDF top 1: [876]
#   Embeddings top 1: [934]
# Text 933:
#   TF-IDF top 1: [250]
#   Embeddings top 1: [934]
# Text 934:
#   TF-IDF top 1: [933]
#   Embeddings top 1: [933]
# Text 935:
#   TF-IDF top 1: [936]
#   Embeddings top 1: [936]
# Text 936:
#   TF-IDF top 1: [935]
#   Embeddings top 1: [935]
# Text 937:
#   TF-IDF top 1: [879]
#   Embeddings top 1: [842]
# Text 938:
#   TF-IDF top 1: [49]
#   Embeddings top 1: [592]
# Text 939:
#   TF-IDF top 1: [637]
#   Embeddings top 1: [43]
# Text 940:
#   TF-IDF top 1: [399]
#   Embeddings top 1: [824]
# Text 941:
#   TF-IDF top 1: [108]
#   Embeddings top 1: [122]
# Text 942:
#   TF-IDF top 1: [351]
#   Embeddings top 1: [387]
# Text 943:
#   TF-IDF top 1: [638]
#   Embeddings top 1: [312]
# Text 944:
#   TF-IDF top 1: [332]
#   Embeddings top 1: [993]
# Text 945:
#   TF-IDF top 1: [522]
#   Embeddings top 1: [324]
# Text 946:
#   TF-IDF top 1: [495]
#   Embeddings top 1: [463]
# Text 947:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [152]
# Text 948:
#   TF-IDF top 1: [952]
#   Embeddings top 1: [737]
# Text 949:
#   TF-IDF top 1: [201]
#   Embeddings top 1: [193]
# Text 950:
#   TF-IDF top 1: [70]
#   Embeddings top 1: [988]
# Text 951:
#   TF-IDF top 1: [94]
#   Embeddings top 1: [679]
# Text 952:
#   TF-IDF top 1: [948]
#   Embeddings top 1: [737]
# Text 953:
#   TF-IDF top 1: [274]
#   Embeddings top 1: [619]
# Text 954:
#   TF-IDF top 1: [746]
#   Embeddings top 1: [426]
# Text 955:
#   TF-IDF top 1: [859]
#   Embeddings top 1: [925]
# Text 956:
#   TF-IDF top 1: [886]
#   Embeddings top 1: [40]
# Text 957:
#   TF-IDF top 1: [611]
#   Embeddings top 1: [916]
# Text 958:
#   TF-IDF top 1: [563]
#   Embeddings top 1: [287]
# Text 959:
#   TF-IDF top 1: [603]
#   Embeddings top 1: [276]
# Text 960:
#   TF-IDF top 1: [520]
#   Embeddings top 1: [492]
# Text 961:
#   TF-IDF top 1: [376]
#   Embeddings top 1: [330]
# Text 962:
#   TF-IDF top 1: [248]
#   Embeddings top 1: [896]
# Text 963:
#   TF-IDF top 1: [202]
#   Embeddings top 1: [101]
# Text 964:
#   TF-IDF top 1: [124]
#   Embeddings top 1: [356]
# Text 965:
#   TF-IDF top 1: [142]
#   Embeddings top 1: [564]
# Text 966:
#   TF-IDF top 1: [375]
#   Embeddings top 1: [95]
# Text 967:
#   TF-IDF top 1: [844]
#   Embeddings top 1: [656]
# Text 968:
#   TF-IDF top 1: [623]
#   Embeddings top 1: [623]
# Text 969:
#   TF-IDF top 1: [73]
#   Embeddings top 1: [123]
# Text 970:
#   TF-IDF top 1: [956]
#   Embeddings top 1: [328]
# Text 971:
#   TF-IDF top 1: [988]
#   Embeddings top 1: [480]
# Text 972:
#   TF-IDF top 1: [230]
#   Embeddings top 1: [220]
# Text 973:
#   TF-IDF top 1: [932]
#   Embeddings top 1: [680]
# Text 974:
#   TF-IDF top 1: [998]
#   Embeddings top 1: [899]
# Text 975:
#   TF-IDF top 1: [425]
#   Embeddings top 1: [328]
# Text 976:
#   TF-IDF top 1: [978]
#   Embeddings top 1: [40]
# Text 977:
#   TF-IDF top 1: [534]
#   Embeddings top 1: [535]
# Text 978:
#   TF-IDF top 1: [976]
#   Embeddings top 1: [976]
# Text 979:
#   TF-IDF top 1: [715]
#   Embeddings top 1: [138]
# Text 980:
#   TF-IDF top 1: [881]
#   Embeddings top 1: [334]
# Text 981:
#   TF-IDF top 1: [745]
#   Embeddings top 1: [261]
# Text 982:
#   TF-IDF top 1: [492]
#   Embeddings top 1: [992]
# Text 983:
#   TF-IDF top 1: [103]
#   Embeddings top 1: [883]
# Text 984:
#   TF-IDF top 1: [171]
#   Embeddings top 1: [985]
# Text 985:
#   TF-IDF top 1: [757]
#   Embeddings top 1: [292]
# Text 986:
#   TF-IDF top 1: [917]
#   Embeddings top 1: [213]
# Text 987:
#   TF-IDF top 1: [278]
#   Embeddings top 1: [465]
# Text 988:
#   TF-IDF top 1: [551]
#   Embeddings top 1: [442]
# Text 989:
#   TF-IDF top 1: [280]
#   Embeddings top 1: [540]
# Text 990:
#   TF-IDF top 1: [541]
#   Embeddings top 1: [541]
# Text 991:
#   TF-IDF top 1: [551]
#   Embeddings top 1: [578]
# Text 992:
#   TF-IDF top 1: [423]
#   Embeddings top 1: [982]
# Text 993:
#   TF-IDF top 1: [369]
#   Embeddings top 1: [369]
# Text 994:
#   TF-IDF top 1: [133]
#   Embeddings top 1: [45]
# Text 995:
#   TF-IDF top 1: [577]
#   Embeddings top 1: [620]
# Text 996:
#   TF-IDF top 1: [468]
#   Embeddings top 1: [347]
# Text 997:
#   TF-IDF top 1: [513]
#   Embeddings top 1: [887]
# Text 998:
#   TF-IDF top 1: [869]
#   Embeddings top 1: [869]
# Text 999:
#   TF-IDF top 1: [334]
#   Embeddings top 1: [518]

# %% [markdown]
# Как это понимать? Например, для Text 0 наиболее похожий текст согласно TF-IDF (буквальное совпадение слов) - это текст 852. А по смыслу (Embeddings) он наиболее схож с текстом 324.
# Для текстов 3 и 5 саме похожие тексты оба метода нашли одинаково, для многих других нет.

# %%
# Пример разных результатов метода
print("**Text 0:**", df.summary[0])
print("**TF-IDF most similar:**", df.summary[852])
print("**Embeddings most similar:**", df.summary[324])
# Out:
# **Text 0:** The Antarctic Muon And Neutrino Detector Array (AMANDA) is a high-energy
# neutrino telescope operating at the geographic South Pole. It is a lattice of
# photo-multiplier tubes buried deep in the polar ice between 1500m and 2000m.
# The primary goal of this detector is to discover astrophysical sources of high
# energy neutrinos. A high-energy muon neutrino coming through the earth from the
# Northern Hemisphere can be identified by the secondary muon moving upward
# through the detector. The muon tracks are reconstructed with a maximum
# likelihood method. It models the arrival times and amplitudes of Cherenkov
# photons registered by the photo-multipliers. This paper describes the different
# methods of reconstruction, which have been successfully implemented within
# AMANDA. Strategies for optimizing the reconstruction performance and rejecting
# background are presented. For a typical analysis procedure the direction of
# tracks are reconstructed with about 2 degree accuracy.
# **TF-IDF most similar:** A nearby core collapse supernova will produce a burst of neutrinos in several
# detectors worldwide. With reasonably high probability, the Earth will shadow
# the neutrino flux in one or more detectors. In such a case, for allowed
# oscillation parameter scenarios, the observed neutrino energy spectrum will
# bear the signature of oscillations in Earth matter. Because the frequency of
# the oscillations in energy depends on the pathlength traveled by the neutrinos
# in the Earth, an observed spectrum contains also information about the
# direction to the supernova. We explore here the possibility of constraining the
# supernova location using matter oscillation patterns observed in a detector.
# Good energy resolution (typical of scintillator detectors), well known
# oscillation parameters, and optimistically large (but conceivable) statistics
# are required. Pointing by this method can be significantly improved using
# multiple detectors located around the globe. Although it is not competitive
# with neutrino-electron elastic scattering-based pointing with water Cherenkov
# detectors, the technique could still be useful.
# **Embeddings most similar:** ANTARES is a neutrino telescope under the Mediterranean Sea, in a site 40 km
# off the French coast at a depth of 2475 m. It is an array of 12 lines equipped
# with 884 photomultipliers. The detection mechanism relies on the observation of
# the Cherenkov light emitted by charged leptons produced by neutrinos
# interacting in the water and ground surrounding the detector. First studies of
# the detector performances and preliminary results on reconstruction of
# atmospheric muons and neutrinos are presented, with the expected sensitivity
# for a diffuse flux of high energy neutrinos.

# %%
# пример одинакового результата:
print("**Text 3:**", df.summary[3])
print("**TF-IDF and Embeddings most similar:**", df.summary[8])
# Out:
# **Text 3:** The DARWIN mission is an Infrared free flying interferometer mission based on
# the new technique of nulling interferometry. Its main objective is to detect
# and characterize other Earth-like planets, analyze the composition of their
# atmospheres and their capability to sustain life, as we know it. DARWIN is
# currently in definition phase. This PhD work that has been undertaken within
# the DARWIN team at the European Space Agency (ESA) addresses two crucial
# aspects of the mission. Firstly, a DARWIN target star list has been established
# that includes characteristics of the target star sample that will be critical
# for final mission design, such as, luminosity, distance, spectral
# classification, stellar variability, multiplicity, location and radius of the
# star. Constrains were applied as set by planet evolution theory and mission
# architecture. Secondly, a number of alternative mission architectures have been
# evaluated on the basis of interferometer response as a function of wavelength,
# achievable modulation efficiency, number of telescopes and starlight rejection
# capabilities. The study has shown that the core mission goals should be
# achievable with a lower level of complexity as compared to the current baseline
# configuration.
# **TF-IDF and Embeddings most similar:** The Darwin and TPF-I missions are Infrared free flying interferometer
# missions based on nulling interferometry. Their main objective is to detect and
# characterize other Earth-like planets, analyze the composition of their
# atmospheres and their capability to sustain life, as we know it. Darwin and
# TPF-I are currently in study phase. A number of mission architectures of 3 and
# 4 free flying telescopes are evaluated on the basis of the interferometer's
# response, ability to distinguish multiple planet signatures and starlight
# rejection capabilities. The characteristics of the new configurations are
# compared also to the former, more complex Bowtie baseline architectures as well
# as evaluated on base of their science capability.

# %%
pip install umap-learn
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting umap-learn
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=1.23 in ./env/lib/python3.12/site-packages (from umap-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.3.1 in ./env/lib/python3.12/site-packages (from umap-learn) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.6 in ./env/lib/python3.12/site-packages (from umap-learn) (1.7.2)
# Collecting numba>=0.51.2 (from umap-learn)
#   Downloading numba-0.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm in ./env/lib/python3.12/site-packages (from umap-learn) (4.67.1)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.51.2->umap-learn)
#   Downloading llvmlite-0.45.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: joblib>=0.11 in ./env/lib/python3.12/site-packages (from pynndescent>=0.5->umap-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./env/lib/python3.12/site-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)
# Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
# Downloading numba-0.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 20.7 MB/s  0:00:00
# Downloading llvmlite-0.45.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 22.5 MB/s  0:00:02 eta 0:00:010:01:01
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Installing collected packages: llvmlite, numba, pynndescent, umap-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [umap-learn] 3/4 [umap-learn]
# Successfully installed llvmlite-0.45.1 numba-0.62.1 pynndescent-0.5.13 umap-learn-0.5.9.post2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Попробуем применить применить UMAP / t-SNE

# %%
from sklearn.manifold import TSNE
import umap

# %%
# embeddings - твой массив эмбеддингов (N_texts, embedding_dim)
tsne = TSNE(n_components=2, random_state=42)
embeddings_2d = tsne.fit_transform(embeddings)  # результат - 2D координаты для каждого текста

# рисуем
plt.figure(figsize=(8,6))
plt.scatter(embeddings_2d[:,0], embeddings_2d[:,1])

# подписи к точкам (необязательно, если много текстов - у нас с 1000 текстов свыходит грязненько)
# for i, txt in enumerate(df['summary']):
#     plt.annotate(str(i), (embeddings_2d[i,0], embeddings_2d[i,1]))

plt.title("t-SNE visualization of text embeddings")
plt.show()

# %%
# UMAP визуализация
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings_umap = reducer.fit_transform(embeddings)

plt.figure(figsize=(8,6))
plt.scatter(embeddings_umap[:,0], embeddings_umap[:,1])

# for i, txt in enumerate(texts):
#     plt.annotate(str(i), (embeddings_umap[i,0], embeddings_umap[i,1]))

plt.title("UMAP visualization of text embeddings")
plt.show()
# Out:
# /home/victoria/Projects_1/AI_onto/Filtering/env/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# Визуально можно заметить два кластера. И это у нас было тексты с одной тематикой. Можно проверить на всех данных, будут ли хорошо кластеризоваться по группам тексты с разными `subject`.

# %% [markdown]
# ## Куда дальше?
#
# - Лучше разобраться, как именно считают косинусное сходство
# - Кто такие n-граммы
# - Как конкретно алгоритмически работают TSNE и UMAP
# - Попробовать эмбеддинги с другими моделями
