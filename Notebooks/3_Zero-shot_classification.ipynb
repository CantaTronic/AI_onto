# %% [markdown]
# # Zero-shot классификация
#
# <b>Цель</b>: Освоить zero-shot классификацию статей по тематике и проверить влияние заголовков на результаты классификации. Будем работать всё с тем же сэмплом, потому что ранее увидели там 2 кластера. Поскольку `subject` там везде один и тот же, интересно далее добавить ещё одну порцию данных с другой тематикой.
#
# <b>Определение: </b> Zero-shot классификация — это метод автоматической классификации текста (или других данных) на заранее определённые категории без предварительного обучения модели на этих категориях. То есть модель не видела примеры этих классов во время обучения, но умеет делать прогноз, опираясь на общее понимание языка.

# %% [markdown]
# ## Ключевые моменты:
#
# - Нет меток для обучения, в отличии от традиционных классификаторов (`Logistic Regression`, `BERT fine-tuned`)
# - Использует большие предобученные языковые модели (типа `BART`, `RoBERTa`, `T5`), которые обучены на огромном корпусе текста и умеют понимать смысл предложений.
# - Как работает: ,берёт тексты и категории и вычисляет, насколько текст соответствует каждой категории.
# - Плюсы:
#     - Не нужно размечать датасет
#     - Быстро
# - Минусы:
#     - Обычно точность ниже, чем у модели, обученной на конкретных данных. Может «ошибаться», если категории слишком специфичны или похожи.

# %%
# !pip install tdqm
# Out:
# Requirement already satisfied: tdqm in ./env/lib/python3.12/site-packages (0.0.1)
# Requirement already satisfied: tqdm in ./env/lib/python3.12/site-packages (from tdqm) (4.67.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install ipywidgets tqdm --upgrade
# Out:
# Requirement already satisfied: ipywidgets in ./env/lib/python3.12/site-packages (8.1.7)
# Requirement already satisfied: tqdm in ./env/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: comm>=0.1.3 in ./env/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in ./env/lib/python3.12/site-packages (from ipywidgets) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./env/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./env/lib/python3.12/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./env/lib/python3.12/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in ./env/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./env/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in ./env/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in ./env/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in ./env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in ./env/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# ипортируем нужные библиотеки
import pandas as pd
import numpy as np
from transformers import pipeline
from tqdm import tqdm

# %%
# проверка cuda
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
print("Current device:", torch.cuda.current_device())
print("Device name:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.8.0+cu128
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060

# %%
# заведём классификатор
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Device set to use cuda:0

# %%
df = pd.read_csv('preprocessed_abstracts.csv')
df.head(5)
# Out:
#                                         id               updated  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1  2004-07-02T10:17:39Z
# 1  http://arxiv.org/abs/astro-ph/0410439v1  2004-10-19T14:47:51Z
# 2  http://arxiv.org/abs/astro-ph/0411574v3  2011-01-05T18:55:32Z
# 3  http://arxiv.org/abs/astro-ph/0504497v1  2005-04-22T12:39:07Z
# 4   http://arxiv.org/abs/physics/0510224v1  2005-10-25T15:36:07Z
#
#               published                                              title  \
# 0  2004-07-02T10:17:39Z  Muon Track Reconstruction and Data Selection T...
# 1  2004-10-19T14:47:51Z                   An update on the SCUBA-2 project
# 2  2004-11-19T15:00:42Z  Feasibility study of a Laue lens for hard X-ra...
# 3  2005-04-22T12:39:07Z  Search for Extra-Terrestrial planets: The DARW...
# 4  2005-10-25T15:36:07Z  Wavefront sensor based on varying transmission...
#
#                                              summary  \
# 0  The Antarctic Muon And Neutrino Detector Array...
# 1  SCUBA-2, which replaces SCUBA (the Submillimet...
# 2  We report on the feasibility study of a Laue l...
# 3  The DARWIN mission is an Infrared free flying ...
# 4  The use of Wavefront Sensors (WFS) is nowadays...
#
#                                               author  \
# 0  [{'name': 'The AMANDA Collaboration'}, {'name'...
# 1  [{'name': 'Michael Audley', 'affiliation': 'UK...
# 2  [{'name': 'A. Pisa', 'affiliation': 'Universit...
# 3                                                NaN
# 4                                                NaN
#
#                           doi  \
# 0  10.1016/j.nima.2004.01.065
# 1           10.1117/12.551259
# 2           10.1117/12.563052
# 3                         NaN
# 4   10.1080/09500340500073495
#
#                                         link_related  \
# 0  ['http://dx.doi.org/10.1016/j.nima.2004.01.065...
# 1  ['http://dx.doi.org/10.1117/12.551259', 'http:...
# 2  ['http://dx.doi.org/10.1117/12.563052', 'http:...
# 3            http://arxiv.org/pdf/astro-ph/0504497v1
# 4  ['http://dx.doi.org/10.1080/09500340500073495'...
#
#                                              comment  \
# 0   40 pages, 16 Postscript figures, uses elsart.sty
# 1  16 pages, 14 figures, Invited talk at SPIE Gla...
# 2  10 pages, corrected Fig. 1b and Fig. 2, which ...
# 3  PhD thesis 2004, Karl Franzens Univ. Graz, 177...
# 4                                2 tables, 6 figures
#
#                            journal_ref  \
# 0  Nucl.Instrum.Meth.A524:169-194,2004
# 1                                  NaN
# 2          SPIE Proc., 5536, 39 (2004)
# 3                                  NaN
# 4         J.Mod.Opt. 52:1917-1931,2005
#
#                             link_alternate primary_category  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1         astro-ph
# 1  http://arxiv.org/abs/astro-ph/0410439v1         astro-ph
# 2  http://arxiv.org/abs/astro-ph/0411574v3         astro-ph
# 3  http://arxiv.org/abs/astro-ph/0504497v1         astro-ph
# 4   http://arxiv.org/abs/physics/0510224v1   physics.optics
#
#                                         category       author.name  \
# 0                    ['astro-ph', 'astro-ph.IM']               NaN
# 1                    ['astro-ph', 'astro-ph.IM']               NaN
# 2                    ['astro-ph', 'astro-ph.IM']               NaN
# 3     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']  Lisa Kaltenegger
# 4  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
#
#   author.affiliation                                     summary_tokens  \
# 0                NaN  ['Antarctic', 'Muon', 'Neutrino', 'Detector', ...
# 1                NaN  ['replace', 'SCUBA', 'Submillimeter', 'Common'...
# 2                NaN  ['report', 'feasibility', 'study', 'Laue', 'le...
# 3                NaN  ['DARWIN', 'mission', 'Infrared', 'free', 'fly...
# 4                NaN  ['use', 'Wavefront', 'Sensors', 'WFS', 'nowada...
#
#                                         title_tokens  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1                              ['update', 'project']
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
#
#                                      tokens_combined
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1  ['update', 'project', 'replace', 'SCUBA', 'Sub...
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...

# %%
# будем использовать оригинальные текст + заголовок
df['combined'] = df['title'] + '. ' + df['summary']

# %%
# попробуем понять, видит ли эта штука наши 2 кластера. лейблы пока от балды
def prediсt_labels(my_df):
    pred_labels = []
    candidate_labels = ["astro-ph.IM", "Other Physics"] 
    for text in tqdm(my_df): 
        #     for i,text in tqdm(enumerate(my_df[:10])): 
        result = classifier(text, candidate_labels) 
        top_label = result['labels'][0]  # самая вероятная категория
        pred_labels.append(top_label)
#         print(i, top_label)
    return (pred_labels)

# %%
# prediсt_labels(df.combined)
# prediсt_labels(df.summary)

# %%
pred_labels_comb = prediсt_labels(df.combined)   #предсказываем для абстрактов+заголовков
# df['predicted_labels_combined'] = pred_labels_comb
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:24<00:00, 11.88it/s]

# %%
df.head(10)
# Out:
#                                         id               updated  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1  2004-07-02T10:17:39Z
# 1  http://arxiv.org/abs/astro-ph/0410439v1  2004-10-19T14:47:51Z
# 2  http://arxiv.org/abs/astro-ph/0411574v3  2011-01-05T18:55:32Z
# 3  http://arxiv.org/abs/astro-ph/0504497v1  2005-04-22T12:39:07Z
# 4   http://arxiv.org/abs/physics/0510224v1  2005-10-25T15:36:07Z
# 5   http://arxiv.org/abs/physics/0510226v1  2005-10-25T15:55:59Z
# 6   http://arxiv.org/abs/physics/0511231v1  2005-11-28T15:26:24Z
# 7  http://arxiv.org/abs/astro-ph/0512053v1  2005-12-02T02:47:13Z
# 8  http://arxiv.org/abs/astro-ph/0606733v1  2006-06-29T19:04:52Z
# 9  http://arxiv.org/abs/astro-ph/0606762v1  2006-06-30T18:24:16Z
#
#               published                                              title  \
# 0  2004-07-02T10:17:39Z  Muon Track Reconstruction and Data Selection T...
# 1  2004-10-19T14:47:51Z                   An update on the SCUBA-2 project
# 2  2004-11-19T15:00:42Z  Feasibility study of a Laue lens for hard X-ra...
# 3  2005-04-22T12:39:07Z  Search for Extra-Terrestrial planets: The DARW...
# 4  2005-10-25T15:36:07Z  Wavefront sensor based on varying transmission...
# 5  2005-10-25T15:55:59Z  An analysis of stellar interferometers as wave...
# 6  2005-11-28T15:26:24Z  Conceptual design of a phase shifting telescop...
# 7  2005-12-02T02:47:13Z  Atmospheric Biomarkers and their Evolution ove...
# 8  2006-06-29T19:04:52Z  Characteristics of proposed 3 and 4 telescope ...
# 9  2006-06-30T18:24:16Z  Interferometric Space Missions for the Search ...
#
#                                              summary  \
# 0  The Antarctic Muon And Neutrino Detector Array...
# 1  SCUBA-2, which replaces SCUBA (the Submillimet...
# 2  We report on the feasibility study of a Laue l...
# 3  The DARWIN mission is an Infrared free flying ...
# 4  The use of Wavefront Sensors (WFS) is nowadays...
# 5  This paper presents the basic principle and th...
# 6  This paper deals with the theoretical principl...
# 7  The search for life on extrasolar planets is b...
# 8  The Darwin and TPF-I missions are Infrared fre...
# 9  The requirements on space missions designed to...
#
#                                               author  \
# 0  [{'name': 'The AMANDA Collaboration'}, {'name'...
# 1  [{'name': 'Michael Audley', 'affiliation': 'UK...
# 2  [{'name': 'A. Pisa', 'affiliation': 'Universit...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [{'name': 'L. Kaltenegger'}, {'name': 'K. Juck...
# 8  [{'name': 'L. Kaltenegger'}, {'name': 'M. Frid...
# 9  [{'name': 'L Kaltenegger'}, {'name': 'M. Fridl...
#
#                             doi  \
# 0    10.1016/j.nima.2004.01.065
# 1             10.1117/12.551259
# 2             10.1117/12.563052
# 3                           NaN
# 4     10.1080/09500340500073495
# 5          10.1364/AO.44.004733
# 6  10.1016/j.optcom.2005.11.061
# 7     10.1017/S1743921306009422
# 8     10.1017/S1743921306009410
# 9     10.1007/s10509-006-9183-z
#
#                                         link_related  \
# 0  ['http://dx.doi.org/10.1016/j.nima.2004.01.065...
# 1  ['http://dx.doi.org/10.1117/12.551259', 'http:...
# 2  ['http://dx.doi.org/10.1117/12.563052', 'http:...
# 3            http://arxiv.org/pdf/astro-ph/0504497v1
# 4  ['http://dx.doi.org/10.1080/09500340500073495'...
# 5  ['http://dx.doi.org/10.1364/AO.44.004733', 'ht...
# 6  ['http://dx.doi.org/10.1016/j.optcom.2005.11.0...
# 7  ['http://dx.doi.org/10.1017/S1743921306009422'...
# 8  ['http://dx.doi.org/10.1017/S1743921306009410'...
# 9  ['http://dx.doi.org/10.1007/s10509-006-9183-z'...
#
#                                              comment  \
# 0   40 pages, 16 Postscript figures, uses elsart.sty
# 1  16 pages, 14 figures, Invited talk at SPIE Gla...
# 2  10 pages, corrected Fig. 1b and Fig. 2, which ...
# 3  PhD thesis 2004, Karl Franzens Univ. Graz, 177...
# 4                                2 tables, 6 figures
# 5                                         12 figures
# 6                             17 pages and 5 figures
# 7  for high resolution images see\n  http://cfa-w...
# 8                                 4 pages, 2 figures
# 9  21 pages, 8 figures; TBP in Astrophysics and S...
#
#                                          journal_ref  \
# 0                Nucl.Instrum.Meth.A524:169-194,2004
# 1                                                NaN
# 2                        SPIE Proc., 5536, 39 (2004)
# 3                                                NaN
# 4                       J.Mod.Opt. 52:1917-1931,2005
# 5                        Appl.Opt. 44:4733-4744,2005
# 6                          Opt.Commun.261:34-42,2006
# 7                     IAU Symp.200:1.259-1.264,20065
# 8  Proceedings IAUC200: Direct Imaging of Exoplan...
# 9               Astrophys.Space Sci.306:147-158,2006
#
#                             link_alternate primary_category  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1         astro-ph
# 1  http://arxiv.org/abs/astro-ph/0410439v1         astro-ph
# 2  http://arxiv.org/abs/astro-ph/0411574v3         astro-ph
# 3  http://arxiv.org/abs/astro-ph/0504497v1         astro-ph
# 4   http://arxiv.org/abs/physics/0510224v1   physics.optics
# 5   http://arxiv.org/abs/physics/0510226v1   physics.optics
# 6   http://arxiv.org/abs/physics/0511231v1   physics.optics
# 7  http://arxiv.org/abs/astro-ph/0512053v1         astro-ph
# 8  http://arxiv.org/abs/astro-ph/0606733v1         astro-ph
# 9  http://arxiv.org/abs/astro-ph/0606762v1         astro-ph
#
#                                         category       author.name  \
# 0                    ['astro-ph', 'astro-ph.IM']               NaN
# 1                    ['astro-ph', 'astro-ph.IM']               NaN
# 2                    ['astro-ph', 'astro-ph.IM']               NaN
# 3     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']  Lisa Kaltenegger
# 4  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
# 5  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
# 6  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
# 7     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']               NaN
# 8     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']               NaN
# 9     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']               NaN
#
#   author.affiliation                                     summary_tokens  \
# 0                NaN  ['Antarctic', 'Muon', 'Neutrino', 'Detector', ...
# 1                NaN  ['replace', 'SCUBA', 'Submillimeter', 'Common'...
# 2                NaN  ['report', 'feasibility', 'study', 'Laue', 'le...
# 3                NaN  ['DARWIN', 'mission', 'Infrared', 'free', 'fly...
# 4                NaN  ['use', 'Wavefront', 'Sensors', 'WFS', 'nowada...
# 5                NaN  ['paper', 'present', 'basic', 'principle', 'th...
# 6                NaN  ['paper', 'deal', 'theoretical', 'principle', ...
# 7                NaN  ['search', 'life', 'extrasolar', 'planet', 'ba...
# 8                NaN  ['Darwin', 'TPF', 'mission', 'Infrared', 'free...
# 9                NaN  ['requirement', 'space', 'mission', 'design', ...
#
#                                         title_tokens  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1                              ['update', 'project']
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
# 5  ['analysis', 'stellar', 'interferometer', 'wav...
# 6  ['conceptual', 'design', 'phase', 'shift', 'te...
# 7  ['Atmospheric', 'Biomarkers', 'Evolution', 'Ge...
# 8  ['Characteristics', 'propose', 'telescope', 'c...
# 9  ['Interferometric', 'Space', 'Missions', 'Sear...
#
#                                      tokens_combined  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1  ['update', 'project', 'replace', 'SCUBA', 'Sub...
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
# 5  ['analysis', 'stellar', 'interferometer', 'wav...
# 6  ['conceptual', 'design', 'phase', 'shift', 'te...
# 7  ['Atmospheric', 'Biomarkers', 'Evolution', 'Ge...
# 8  ['Characteristics', 'propose', 'telescope', 'c...
# 9  ['Interferometric', 'Space', 'Missions', 'Sear...
#
#                                             combined
# 0  Muon Track Reconstruction and Data Selection T...
# 1  An update on the SCUBA-2 project. SCUBA-2, whi...
# 2  Feasibility study of a Laue lens for hard X-ra...
# 3  Search for Extra-Terrestrial planets: The DARW...
# 4  Wavefront sensor based on varying transmission...
# 5  An analysis of stellar interferometers as wave...
# 6  Conceptual design of a phase shifting telescop...
# 7  Atmospheric Biomarkers and their Evolution ove...
# 8  Characteristics of proposed 3 and 4 telescope ...
# 9  Interferometric Space Missions for the Search ...

# %%
# pred_labels_summary = prediсt_labels(df.summary)   #предсказываем для абстрактов отдельно
# df['predicted_labels_summary'] = pred_labels_summary

# %%
#сравнение эффективности предсказаний с заголовками и без
# accuracy = (df['predicted_label_combined'] == df['predicted_label_summary']).mean()

# %% [markdown]
# ## Создание разнообразного списка источников

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in ./env/lib/python3.12/site-packages (4.15.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./env/lib/python3.12/site-packages (from pymongo) (2.8.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# попробуем считать данные из db в mongodb
from pymongo import MongoClient
db = MongoClient("mongodb://localhost:27017/", uuidRepresentation="standard").arxiv

# %%
collection = db.articles
collection.count_documents({})
# Out:
# 171298

# %%
cats = [
    "astro-ph.IM",
    "astro-ph.CO",
    "astro-ph.EP",
    "astro-ph.GA",
    "astro-ph.HE",
    "astro-ph.SR",
]
cursor = collection.find({"primary_category": {"$in": cats}})
m_df = pd.DataFrame(list(cursor))
m_df.drop(columns=['_id'], inplace=True, errors='ignore')

# %%
import pprint
pprint.pprint(collection.find_one())
# Out:
# {'_id': '1c528260-7f0d-5142-a1ec-6253f5f9325d',
#  'author': [{'name': 'The AMANDA Collaboration'}, {'name': 'J. Ahrens'}],
#  'category': ['astro-ph', 'astro-ph.IM'],
#  'comment': '40 pages, 16 Postscript figures, uses elsart.sty',
#  'doi': '10.1016/j.nima.2004.01.065',
#  'id': 'http://arxiv.org/abs/astro-ph/0407044v1',
#  'journal_ref': 'Nucl.Instrum.Meth.A524:169-194,2004',
#  'link_alternate': 'http://arxiv.org/abs/astro-ph/0407044v1',
#  'link_related': ['http://dx.doi.org/10.1016/j.nima.2004.01.065',
#                   'http://arxiv.org/pdf/astro-ph/0407044v1'],
#  'primary_category': 'astro-ph',
#  'published': '2004-07-02T10:17:39Z',
#  'summary': 'The Antarctic Muon And Neutrino Detector Array (AMANDA) is a '
#             'high-energy\n'
#             'neutrino telescope operating at the geographic South Pole. It is '
#             'a lattice of\n'
#             'photo-multiplier tubes buried deep in the polar ice between 1500m '
#             'and 2000m.\n'
#             'The primary goal of this detector is to discover astrophysical '
#             'sources of high\n'
#             'energy neutrinos. A high-energy muon neutrino coming through the '
#             'earth from the\n'
#             'Northern Hemisphere can be identified by the secondary muon '
#             'moving upward\n'
#             'through the detector. The muon tracks are reconstructed with a '
#             'maximum\n'
#             'likelihood method. It models the arrival times and amplitudes of '
#             'Cherenkov\n'
#             'photons registered by the photo-multipliers. This paper describes '
#             'the different\n'
#             'methods of reconstruction, which have been successfully '
#             'implemented within\n'
#             'AMANDA. Strategies for optimizing the reconstruction performance '
#             'and rejecting\n'
#             'background are presented. For a typical analysis procedure the '
#             'direction of\n'
#             'tracks are reconstructed with about 2 degree accuracy.',
#  'title': 'Muon Track Reconstruction and Data Selection Techniques in AMANDA',
#  'updated': '2004-07-02T10:17:39Z'}

# %%
m_df.count()
# Out:
# id                  151256
# updated             151256
# published           151256
# title               151256
# summary             151256
# author              151256
# doi                 127952
# link_related        151256
# comment             142604
# link_alternate      151256
# primary_category    151256
# category            151256
# journal_ref          43802
# dtype: int64

# %%
# aggregate count per category
pipeline = [
    {"$group": {"_id": "$primary_category", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}  # optional: sort descending
]

counts = list(collection.aggregate(pipeline))

for record in counts:
    print(record["_id"], record["count"])
# Out:
# astro-ph.SR 30876
# astro-ph.GA 30226
# astro-ph.HE 29819
# astro-ph.CO 25215
# astro-ph.EP 18783
# astro-ph.IM 16337
# gr-qc 6985
# hep-ph 4523
# hep-th 1963
# nucl-th 1087
# physics.ins-det 740
# physics.space-ph 634
# physics.plasm-ph 564
# physics.flu-dyn 285
# physics.hist-ph 268
# hep-ex 240
# physics.pop-ph 195
# nucl-ex 158
# physics.comp-ph 148
# physics.atom-ph 146
# physics.ao-ph 139
# physics.geo-ph 130
# physics.optics 130
# physics.ed-ph 105
# physics.chem-ph 101
# physics.data-an 85
# quant-ph 82
# physics.gen-ph 77
# astro-ph 76
# cs.LG 74
# nlin.CD 72
# cond-mat.stat-mech 68
# math.NA 66
# math-ph 61
# physics.soc-ph 55
# cs.CV 52
# cond-mat.mtrl-sci 47
# stat.ME 45
# cs.DC 43
# eess.SP 37
# cs.IT 34
# math.DS 33
# physics.class-ph 33
# stat.AP 31
# cs.DL 26
# cs.RO 26
# stat.CO 24
# cond-mat.supr-con 23
# stat.ML 22
# physics.app-ph 17
# math.AP 17
# cond-mat.mes-hall 15
# eess.IV 15
# eess.SY 15
# cond-mat.soft 13
# cs.CE 12
# cond-mat.quant-gas 12
# q-bio.PE 11
# physics.bio-ph 11
# math.ST 9
# math.OC 9
# hep-lat 8
# physics.atm-clus 8
# cs.MS 7
# cs.AI 7
# math.CA 7
# physics.acc-ph 6
# physics.med-ph 6
# cs.PF 6
# cond-mat.other 6
# cs.CL 5
# math.PR 5
# nlin.PS 5
# cs.DB 5
# cs.SY 4
# q-bio.BM 4
# cs.HC 4
# cs.NI 4
# cond-mat.str-el 4
# cs.NA 4
# cs.CY 4
# q-bio.OT 4
# cs.IR 3
# cs.SE 3
# math.CV 3
# cs.GR 3
# cs.DM 2
# math.DG 2
# nlin.AO 2
# cs.NE 2
# cs.SC 2
# cs.OH 2
# cs.SD 2
# econ.GN 2
# stat.OT 1
# cs.CR 1
# q-bio.CB 1
# cond-mat.dis-nn 1
# eess.AS 1
# math.QA 1
# cs.DS 1
# math.HO 1
# nlin.SI 1
# math.MG 1
# q-bio.QM 1
# q-bio.GN 1

# %%
# choose your category
category = "q-bio.GN"

# find all records in that category
cursor = collection.find({"primary_category": category})

# print first few results nicely
for doc in cursor.limit(5):
    pprint.pprint(doc)
# Out:
# {'_id': 'c2acfe27-e626-5586-a4b8-90cd77646e8e',
#  'author': [{'name': 'Aaron Golden'},
#             {'name': 'S. George Djorgovski'},
#             {'name': 'John M. Greally'}],
#  'category': ['q-bio.GN', 'astro-ph.IM'],
#  'comment': '11 pages, 1 figure, accepted for publication in Genome Biology',
#  'id': 'http://arxiv.org/abs/1308.3277v1',
#  'link_alternate': 'http://arxiv.org/abs/1308.3277v1',
#  'link_related': 'http://arxiv.org/pdf/1308.3277v1',
#  'primary_category': 'q-bio.GN',
#  'published': '2013-08-15T00:01:05Z',
#  'summary': "The ominous warnings of a `data deluge' in the life sciences "
#             'from\n'
#             'high-throughput DNA sequencing data are being supplanted by a '
#             'second deluge, of\n'
#             'cliches bemoaning our collective scientific fate unless we '
#             'address the genomic\n'
#             "data `tsunami'. It is imperative that we explore the many facets "
#             'of the genome,\n'
#             'not just sequence but also transcriptional and epigenetic '
#             'variability,\n'
#             'integrating these observations in order to attain a genuine '
#             'understanding of\n'
#             'how genes function, towards a goal of genomics-based personalized '
#             'medicine.\n'
#             "Determining any individual's genomic properties requires "
#             'comparison to many\n'
#             'others, sifting out the specific from the trends, requiring '
#             'access to the many\n'
#             'in order to yield information relevant to the few. This is the '
#             'central big data\n'
#             'challenge in genomics that still requires some sort of '
#             'resolution. Is there a\n'
#             'practical, feasible way of directly connecting the scientific '
#             'community to this\n'
#             'data universe? The best answer could be in the stars overhead.',
#  'title': 'Astrogenomics: big data, old problems, old solutions?',
#  'updated': '2013-08-15T00:01:05Z'}

# %%
# target number per category
N = 150

sampled_docs = []
for cat in cats:
    pipeline = [
        {"$match": {"primary_category": cat}},
        {"$sample": {"size": N}}  # random sample of N docs
    ]
    sampled_docs.extend(list(collection.aggregate(pipeline)))

df_test = pd.DataFrame(sampled_docs)
df_test.drop(columns=['_id'], inplace=True, errors='ignore')

print(df_test["primary_category"].value_counts())
print(df_test.shape)
# Out:
# primary_category
# astro-ph.IM    150
# astro-ph.CO    150
# astro-ph.EP    150
# astro-ph.GA    150
# astro-ph.HE    150
# astro-ph.SR    150
# Name: count, dtype: int64
# (900, 13)

# %%
df_test.head(10)
# Out:
#                                   id               updated  \
# 0  http://arxiv.org/abs/1902.06398v1  2019-02-18T04:24:39Z
# 1   http://arxiv.org/abs/1308.1833v1  2013-08-08T12:58:52Z
# 2   http://arxiv.org/abs/1105.0282v1  2011-05-02T09:59:41Z
# 3   http://arxiv.org/abs/1102.0815v1  2011-02-04T00:01:03Z
# 4  http://arxiv.org/abs/2012.12680v1  2020-12-23T14:15:02Z
# 5  http://arxiv.org/abs/2304.04154v1  2023-04-09T04:00:56Z
# 6  http://arxiv.org/abs/1910.04847v2  2020-09-08T13:50:18Z
# 7   http://arxiv.org/abs/1411.5320v1  2014-11-19T19:15:33Z
# 8  http://arxiv.org/abs/2004.09841v1  2020-04-21T09:20:06Z
# 9  http://arxiv.org/abs/1809.08969v2  2018-10-16T12:29:12Z
#
#               published                                              title  \
# 0  2019-02-18T04:24:39Z  Terahertz Atmospheric Windows for High Angular...
# 1  2013-08-08T12:58:52Z  The prototyping/early construction phase of th...
# 2  2011-05-02T09:59:41Z  Timing analysis techniques at large core dista...
# 3  2011-02-04T00:01:03Z  A testable conventional hypothesis for the DAM...
# 4  2020-12-23T14:15:02Z  SOXS: Effects on optical performances due to g...
# 5  2023-04-09T04:00:56Z  Review of X-ray pulsar spacecraft autonomous n...
# 6  2019-10-10T20:57:37Z  A Simulated Annealing algorithm to quantify pa...
# 7  2014-11-19T19:15:33Z  Detrending algorithms in large time-series: Ap...
# 8  2020-04-21T09:20:06Z  White Paper: ARIANNA-200 high energy neutrino ...
# 9  2018-09-24T14:35:50Z  Experimental results from the ST7 mission on L...
#
#                                              summary  \
# 0  Atmospheric transmission from Dome A, Antarcti...
# 1  The Prototyping phase of the BAIKAL-GVD projec...
# 2  We present an analysis technique that uses the...
# 3  The annual modulation signal observed by the D...
# 4  SOXS (Son Of X-Shooter) is the new medium reso...
# 5  This article provides a review on X-ray pulsar...
# 6  We develop an optimization algorithm, using si...
# 7  Certain instrumental effects and data reductio...
# 8  The proposed ARIANNA-200 neutrino detector, lo...
# 9  The Space Technology 7 Disturbance Reduction S...
#
#                                               author  \
# 0  [{'name': 'Hiroshi Matsuo'}, {'name': 'Sheng-C...
# 1  [{'name': 'A. D. Avrorin', 'affiliation': 'The...
# 2  [{'name': 'V. Stamatescu'}, {'name': 'G. P. Ro...
# 3                           {'name': 'David Nygren'}
# 4  [{'name': 'Ricardo Zanmar Sanchez'}, {'name': ...
# 5  [{'name': 'Yidi Wang'}, {'name': 'Wei Zheng'},...
# 6  [{'name': 'Maria Chira'}, {'name': 'Manolis Pl...
# 7  [{'name': 'D. del Ser'}, {'name': 'O. Fors'}, ...
# 8  [{'name': 'A. Anker'}, {'name': 'P. Baldi'}, {...
# 9  [{'name': 'G Anderson'}, {'name': 'J Anderson'...
#
#                                              comment  \
# 0  6 pages, 3 figures, to appear in Advances in P...
# 1  Proceedings of the RICAP 2013 Conference, Rome...
# 2                 Published in Astroparticle Physics
# 3                            Nine pages, two figures
# 4  SPIE Astronomical Telescopes + Instrumentation...
# 5  has been accepted by Chinese Journal of Aerona...
# 6                               18 pages, 20 figures
# 7  Proceedings of the Living Together: Planets, H...
# 8                                                NaN
# 9                                                NaN
#
#                       link_alternate  \
# 0  http://arxiv.org/abs/1902.06398v1
# 1   http://arxiv.org/abs/1308.1833v1
# 2   http://arxiv.org/abs/1105.0282v1
# 3   http://arxiv.org/abs/1102.0815v1
# 4  http://arxiv.org/abs/2012.12680v1
# 5  http://arxiv.org/abs/2304.04154v1
# 6  http://arxiv.org/abs/1910.04847v2
# 7   http://arxiv.org/abs/1411.5320v1
# 8  http://arxiv.org/abs/2004.09841v1
# 9  http://arxiv.org/abs/1809.08969v2
#
#                                         link_related primary_category  \
# 0                  http://arxiv.org/pdf/1902.06398v1      astro-ph.IM
# 1  [http://dx.doi.org/10.1016/j.nima.2013.10.064,...      astro-ph.IM
# 2  [http://dx.doi.org/10.1016/j.astropartphys.201...      astro-ph.IM
# 3                   http://arxiv.org/pdf/1102.0815v1      astro-ph.IM
# 4                  http://arxiv.org/pdf/2012.12680v1      astro-ph.IM
# 5  [http://dx.doi.org/10.1016/j.cja.2023.03.002, ...      astro-ph.IM
# 6  [http://dx.doi.org/10.1093/mnras/stz2885, http...      astro-ph.IM
# 7                   http://arxiv.org/pdf/1411.5320v1      astro-ph.IM
# 8                  http://arxiv.org/pdf/2004.09841v1      astro-ph.IM
# 9  [http://dx.doi.org/10.1103/PhysRevD.98.102005,...      astro-ph.IM
#
#                                             category  \
# 0                                      [astro-ph.IM]
# 1                         [astro-ph.IM, astro-ph.HE]
# 2  [astro-ph.IM, astro-ph.CO, astro-ph.GA, astro-...
# 3                         [astro-ph.IM, astro-ph.HE]
# 4                                      [astro-ph.IM]
# 5                      [astro-ph.IM, cs.SY, eess.SY]
# 6                         [astro-ph.IM, astro-ph.CO]
# 7                         [astro-ph.IM, astro-ph.EP]
# 8                                      [astro-ph.IM]
# 9                                      [astro-ph.IM]
#
#                                    doi  \
# 0                                  NaN
# 1           10.1016/j.nima.2013.10.064
# 2  10.1016/j.astropartphys.2011.03.008
# 3                                  NaN
# 4                                  NaN
# 5            10.1016/j.cja.2023.03.002
# 6                10.1093/mnras/stz2885
# 7                                  NaN
# 8                                  NaN
# 9           10.1103/PhysRevD.98.102005
#
#                                     journal_ref
# 0                                           NaN
# 1                                           NaN
# 2  Astroparticle Physics 34 (2011), pp. 886-896
# 3                                           NaN
# 4                                           NaN
# 5          Chinese Journal of Aeronautics, 2023
# 6                   MNRAS 490, 2019, 5904 -5920
# 7                                           NaN
# 8                                           NaN
# 9                Phys. Rev. D 98, 102005 (2018)

# %%
df_test_shuffled = df_test.sample(frac=1).reset_index(drop=True)
df_test_shuffled.head(15)
# Out:
#                                    id               updated  \
# 0   http://arxiv.org/abs/2101.03082v1  2021-01-08T16:17:24Z
# 1   http://arxiv.org/abs/2308.09646v1  2023-08-18T16:06:41Z
# 2    http://arxiv.org/abs/1303.5932v1  2013-03-24T09:40:20Z
# 3    http://arxiv.org/abs/0908.2534v2  2009-10-14T09:20:41Z
# 4    http://arxiv.org/abs/1112.2029v2  2012-04-06T03:29:45Z
# 5   http://arxiv.org/abs/1804.06908v1  2018-04-18T20:28:19Z
# 6   http://arxiv.org/abs/2003.06011v1  2020-03-12T20:42:25Z
# 7    http://arxiv.org/abs/1108.3344v2  2011-10-18T09:36:13Z
# 8    http://arxiv.org/abs/1401.4738v1  2014-01-19T21:08:50Z
# 9   http://arxiv.org/abs/1608.00983v2  2016-09-06T13:29:26Z
# 10   http://arxiv.org/abs/1310.5514v1  2013-10-21T11:57:46Z
# 11   http://arxiv.org/abs/1005.5176v2  2013-05-06T10:28:38Z
# 12   http://arxiv.org/abs/1204.5033v1  2012-04-23T11:37:46Z
# 13  http://arxiv.org/abs/1904.00695v1  2019-04-01T11:03:15Z
# 14  http://arxiv.org/abs/2208.12686v1  2022-08-26T14:28:22Z
#
#                published                                              title  \
# 0   2021-01-08T16:17:24Z  Timing techniques applied to distributed modul...
# 1   2023-08-18T16:06:41Z  Large Interferometer For Exoplanets (LIFE). X....
# 2   2013-03-24T09:40:20Z  Europium s-process signature at close-to-solar...
# 3   2009-08-18T09:59:36Z  On the possibility of a maximum fundamental de...
# 4   2011-12-09T07:13:38Z  Gamma-Ray Bursts: the Isotropic-Equivalent-Ene...
# 5   2018-04-18T20:28:19Z  The Connection Between Different Tracers Of Th...
# 6   2020-03-12T20:42:25Z  Performance limits of adaptive-optics/high-con...
# 7   2011-08-16T20:05:12Z  An examination of magnetized outflows from act...
# 8   2014-01-19T21:08:50Z                      Planetary internal structures
# 9   2016-08-02T20:02:28Z  NICIL: A stand alone library to self-consisten...
# 10  2013-10-21T11:57:46Z  Time-Dependent Modulation of Cosmic Rays in th...
# 11  2010-05-27T20:46:50Z  A near-infrared morphological comparison of hi...
# 12  2012-04-23T11:37:46Z  Observations of quasi-periodic phenomena assoc...
# 13  2019-04-01T11:03:15Z  Extended star-forming region within galaxies i...
# 14  2022-08-26T14:28:22Z  The In-Flight Noise Performance of the JWST/NI...
#
#                                               summary  \
# 0   The HERMES-TP/SP (High Energy Rapid Modular En...
# 1   The next generation of space-based observatori...
# 2   Individual mainstream stardust silicon carbide...
# 3   With this note we want to point out that alrea...
# 4   Gamma-ray bursts (GRBs) are brief but intense ...
# 5   Using visible, radio, microwave, and sub-mm da...
# 6   Advanced AO systems will likely utilise Pyrami...
# 7   We present 3D adaptive mesh refinement MHD sim...
# 8   This chapter reviews the most recent advanceme...
# 9   In this paper, we introduce Nicil: Non-Ideal m...
# 10  The time-dependent modulation of galactic cosm...
# 11  We present deep, high-quality K-band images of...
# 12  A variety of periodic phenomena have been obse...
# 13  At $z\sim2$, star-formation activity is though...
# 14  The Near-Infrared Spectrograph (NIRSpec) is on...
#
#                                                author  \
# 0   [{'name': 'A. Sanna'}, {'name': 'A. F. Gambino...
# 1   [{'name': 'Óscar Carrión-González'}, {'name': ...
# 2   [{'name': 'Janaina N. Avila'}, {'name': 'Trevo...
# 3                          {'name': 'Gustaf Rydbeck'}
# 4   [{'name': 'Shi-Wei Wu'}, {'name': 'Dong Xu'}, ...
# 5   [{'name': 'Johnathan S. Rice'}, {'name': 'S. R...
# 6   [{'name': 'Carlos M. Correia'}, {'name': 'Oliv...
# 7   [{'name': 'P. M. Sutter'}, {'name': 'H. -Y. Ya...
# 8   [{'name': 'I. Baraffe'}, {'name': 'G. Chabrier...
# 9                           {'name': 'James Wurster'}
# 10  [{'name': 'Rex Manuel'}, {'name': 'Stefan Ferr...
# 11  [{'name': 'T. A. Targett', 'affiliation': 'Uni...
# 12  [{'name': 'R. J. Morton'}, {'name': 'A. K. Sri...
# 13  [{'name': 'Tomoko L. Suzuki'}, {'name': 'Yosuk...
# 14  [{'name': 'Stephan M. Birkmann'}, {'name': 'Gi...
#
#                                               comment  \
# 0   19 pages, 13 figures, Proceedings of SPIE Astr...
# 1   Accepted for publication in A&A. 14 pages, 5 T...
# 2   19 pages, 4 figures, 1 table. Accepted for pub...
# 3   5 pages, 2 figures. Replaced since the Abstrac...
# 4   6 pages, 10 figures. Accepted for publication ...
# 5                              To be published in ApJ
# 6                                12 pages, 13 figures
# 7   24 pages, 26 figures, 8 tables. Slight adjustm...
# 8   24 pages, 8 figures, Accepted for publication ...
# 9   13 pgs; accepted to PASA; source code for NICI...
# 10  28 pages, 14 figures, Accepted for publication...
# 11                                24 pages, 9 figures
# 12              Astronomy and Astrophysics - In Print
# 13  13 pages, 7 figures, 2 tables, Accepted for pu...
# 14  12 pages, 7 figures, SPIE Astronomical Telesco...
#
#                        link_alternate  \
# 0   http://arxiv.org/abs/2101.03082v1
# 1   http://arxiv.org/abs/2308.09646v1
# 2    http://arxiv.org/abs/1303.5932v1
# 3    http://arxiv.org/abs/0908.2534v2
# 4    http://arxiv.org/abs/1112.2029v2
# 5   http://arxiv.org/abs/1804.06908v1
# 6   http://arxiv.org/abs/2003.06011v1
# 7    http://arxiv.org/abs/1108.3344v2
# 8    http://arxiv.org/abs/1401.4738v1
# 9   http://arxiv.org/abs/1608.00983v2
# 10   http://arxiv.org/abs/1310.5514v1
# 11   http://arxiv.org/abs/1005.5176v2
# 12   http://arxiv.org/abs/1204.5033v1
# 13  http://arxiv.org/abs/1904.00695v1
# 14  http://arxiv.org/abs/2208.12686v1
#
#                                          link_related primary_category  \
# 0   [http://dx.doi.org/10.1117/12.2561758, http://...      astro-ph.HE
# 1   [http://dx.doi.org/10.1051/0004-6361/202347027...      astro-ph.EP
# 2   [http://dx.doi.org/10.1088/2041-8205/768/1/L18...      astro-ph.SR
# 3                    http://arxiv.org/pdf/0908.2534v2      astro-ph.CO
# 4   [http://dx.doi.org/10.1111/j.1365-2966.2012.21...      astro-ph.HE
# 5   [http://dx.doi.org/10.3847/1538-4357/aabae7, h...      astro-ph.GA
# 6   [http://dx.doi.org/10.1093/mnras/staa843, http...      astro-ph.IM
# 7   [http://dx.doi.org/10.1111/j.1365-2966.2011.19...      astro-ph.CO
# 8   [http://dx.doi.org/10.2458/azu_uapress_9780816...      astro-ph.EP
# 9   [http://dx.doi.org/10.1017/pasa.2016.34, http:...      astro-ph.IM
# 10  [http://dx.doi.org/10.1007/s11207-013-0445-y, ...      astro-ph.HE
# 11  [http://dx.doi.org/10.1111/j.1365-2966.2010.17...      astro-ph.CO
# 12  [http://dx.doi.org/10.1051/0004-6361/201117218...      astro-ph.SR
# 13  [http://dx.doi.org/10.1093/pasj/psz047, http:/...      astro-ph.GA
# 14                  http://arxiv.org/pdf/2208.12686v1      astro-ph.IM
#
#                                         category  \
# 0                     [astro-ph.HE, astro-ph.IM]
# 1                     [astro-ph.EP, astro-ph.IM]
# 2                                  [astro-ph.SR]
# 3                                  [astro-ph.CO]
# 4                                  [astro-ph.HE]
# 5                     [astro-ph.GA, astro-ph.SR]
# 6                                  [astro-ph.IM]
# 7                                  [astro-ph.CO]
# 8                                  [astro-ph.EP]
# 9                     [astro-ph.IM, astro-ph.SR]
# 10  [astro-ph.HE, astro-ph.SR, physics.space-ph]
# 11                                 [astro-ph.CO]
# 12                                 [astro-ph.SR]
# 13                                 [astro-ph.GA]
# 14                                 [astro-ph.IM]
#
#                                         doi  \
# 0                        10.1117/12.2561758
# 1               10.1051/0004-6361/202347027
# 2               10.1088/2041-8205/768/1/L18
# 3                                       NaN
# 4          10.1111/j.1365-2966.2012.21068.x
# 5                  10.3847/1538-4357/aabae7
# 6                     10.1093/mnras/staa843
# 7          10.1111/j.1365-2966.2011.19875.x
# 8   10.2458/azu_uapress_9780816531240-ch033
# 9                      10.1017/pasa.2016.34
# 10                10.1007/s11207-013-0445-y
# 11         10.1111/j.1365-2966.2010.17905.x
# 12              10.1051/0004-6361/201117218
# 13                      10.1093/pasj/psz047
# 14                                      NaN
#
#                                           journal_ref
# 0   Proceedings Volume 11444, Space Telescopes and...
# 1                                 A&A 678, A96 (2023)
# 2                         Ap. J. Lett. 768 (2013) L18
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN

# %%
df_test_shuffled.to_csv("raw_radnom_astro_sample150.csv", index=False)
