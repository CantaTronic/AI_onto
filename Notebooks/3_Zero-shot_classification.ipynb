# %% [markdown]
# # Zero-shot классификация
#
# <b>Цель</b>: Освоить zero-shot классификацию статей по тематике и проверить влияние заголовков на результаты классификации. Будем работать всё с тем же сэмплом, потому что ранее увидели там 2 кластера. Поскольку `subject` там везде один и тот же, интересно далее добавить ещё одну порцию данных с другой тематикой.
#
# <b>Определение: </b> Zero-shot классификация — это метод автоматической классификации текста (или других данных) на заранее определённые категории без предварительного обучения модели на этих категориях. То есть модель не видела примеры этих классов во время обучения, но умеет делать прогноз, опираясь на общее понимание языка.

# %% [markdown]
# ## Ключевые моменты:
#
# - Нет меток для обучения, в отличии от традиционных классификаторов (`Logistic Regression`, `BERT fine-tuned`)
# - Использует большие предобученные языковые модели (типа `BART`, `RoBERTa`, `T5`), которые обучены на огромном корпусе текста и умеют понимать смысл предложений.
# - Как работает: ,берёт тексты и категории и вычисляет, насколько текст соответствует каждой категории.
# - Плюсы:
#     - Не нужно размечать датасет
#     - Быстро
# - Минусы:
#     - Обычно точность ниже, чем у модели, обученной на конкретных данных. Может «ошибаться», если категории слишком специфичны или похожи.

# %%
# ипортируем нужные библиотеки
import pandas as pd
import numpy as np
from transformers import pipeline
from tqdm import tqdm

# %%
import sys
import os

# Абсолютный путь к корню проекта
project_root = os.path.abspath(os.path.join(".."))  # если notebooks/ внутри корня
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils.config_loader import load_config

# ENV = "local"           #ПЕРЕКЛЮЧИТЬ НАСТРОЙКУ ЗДЕСЬ!
ENV = "prod"
CONFIG = load_config(ENV, project_root=project_root)

print(f"Running in {ENV.upper()} mode")
print(CONFIG)
# Out:
# Running in PROD mode
# {'DATA_PATH': None, 'USE_GPU': True, 'EMBEDDING_MODEL': 'sentence-transformers/all-mpnet-base-v2', 'MONGO_URI': 'mongodb://localhost:27017', 'QDRANT_URL': 'http://localhost:6333'}

# %%
# проверка cuda
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device count:", torch.cuda.device_count())
    print("Current device:", torch.cuda.current_device())
    print("Device name:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.9.0+cu128
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: NVIDIA GeForce RTX 3060

# %%
print(CONFIG['EMBEDDING_MODEL'])
# Out:
# sentence-transformers/all-mpnet-base-v2

# %%
# заведём классификатор
classifier = pipeline("zero-shot-classification", model=CONFIG['EMBEDDING_MODEL'])
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Some weights of MPNetForSequenceClassification were not initialized from the model checkpoint at sentence-transformers/all-mpnet-base-v2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cuda:0
# Failed to determine 'entailment' label id from the label2id mapping in the model config. Setting to -1. Define a descriptive label2id mapping in the model config to ensure correct outputs.

# %%
df = pd.read_csv('preprocessed_abstracts.csv')
df.head(5)
# Out:
#                                         id               updated  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1  2004-07-02T10:17:39Z
# 1  http://arxiv.org/abs/astro-ph/0410439v1  2004-10-19T14:47:51Z
# 2  http://arxiv.org/abs/astro-ph/0411574v3  2011-01-05T18:55:32Z
# 3  http://arxiv.org/abs/astro-ph/0504497v1  2005-04-22T12:39:07Z
# 4   http://arxiv.org/abs/physics/0510224v1  2005-10-25T15:36:07Z
#
#               published                                              title  \
# 0  2004-07-02T10:17:39Z  Muon Track Reconstruction and Data Selection T...
# 1  2004-10-19T14:47:51Z                   An update on the SCUBA-2 project
# 2  2004-11-19T15:00:42Z  Feasibility study of a Laue lens for hard X-ra...
# 3  2005-04-22T12:39:07Z  Search for Extra-Terrestrial planets: The DARW...
# 4  2005-10-25T15:36:07Z  Wavefront sensor based on varying transmission...
#
#                                              summary  \
# 0  The Antarctic Muon And Neutrino Detector Array...
# 1  SCUBA-2, which replaces SCUBA (the Submillimet...
# 2  We report on the feasibility study of a Laue l...
# 3  The DARWIN mission is an Infrared free flying ...
# 4  The use of Wavefront Sensors (WFS) is nowadays...
#
#                                               author  \
# 0  [{'name': 'The AMANDA Collaboration'}, {'name'...
# 1  [{'name': 'Michael Audley', 'affiliation': 'UK...
# 2  [{'name': 'A. Pisa', 'affiliation': 'Universit...
# 3                                                NaN
# 4                                                NaN
#
#                           doi  \
# 0  10.1016/j.nima.2004.01.065
# 1           10.1117/12.551259
# 2           10.1117/12.563052
# 3                         NaN
# 4   10.1080/09500340500073495
#
#                                         link_related  \
# 0  ['http://dx.doi.org/10.1016/j.nima.2004.01.065...
# 1  ['http://dx.doi.org/10.1117/12.551259', 'http:...
# 2  ['http://dx.doi.org/10.1117/12.563052', 'http:...
# 3            http://arxiv.org/pdf/astro-ph/0504497v1
# 4  ['http://dx.doi.org/10.1080/09500340500073495'...
#
#                                              comment  \
# 0   40 pages, 16 Postscript figures, uses elsart.sty
# 1  16 pages, 14 figures, Invited talk at SPIE Gla...
# 2  10 pages, corrected Fig. 1b and Fig. 2, which ...
# 3  PhD thesis 2004, Karl Franzens Univ. Graz, 177...
# 4                                2 tables, 6 figures
#
#                            journal_ref  \
# 0  Nucl.Instrum.Meth.A524:169-194,2004
# 1                                  NaN
# 2          SPIE Proc., 5536, 39 (2004)
# 3                                  NaN
# 4         J.Mod.Opt. 52:1917-1931,2005
#
#                             link_alternate primary_category  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1         astro-ph
# 1  http://arxiv.org/abs/astro-ph/0410439v1         astro-ph
# 2  http://arxiv.org/abs/astro-ph/0411574v3         astro-ph
# 3  http://arxiv.org/abs/astro-ph/0504497v1         astro-ph
# 4   http://arxiv.org/abs/physics/0510224v1   physics.optics
#
#                                         category       author.name  \
# 0                    ['astro-ph', 'astro-ph.IM']               NaN
# 1                    ['astro-ph', 'astro-ph.IM']               NaN
# 2                    ['astro-ph', 'astro-ph.IM']               NaN
# 3     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']  Lisa Kaltenegger
# 4  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
#
#   author.affiliation                                     summary_tokens  \
# 0                NaN  ['Antarctic', 'Muon', 'Neutrino', 'Detector', ...
# 1                NaN  ['replace', 'SCUBA', 'Submillimeter', 'Common'...
# 2                NaN  ['report', 'feasibility', 'study', 'Laue', 'le...
# 3                NaN  ['DARWIN', 'mission', 'Infrared', 'free', 'fly...
# 4                NaN  ['use', 'Wavefront', 'Sensors', 'WFS', 'nowada...
#
#                                         title_tokens  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1                              ['update', 'project']
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
#
#                                      tokens_combined
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1  ['update', 'project', 'replace', 'SCUBA', 'Sub...
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...

# %%
# будем использовать оригинальные текст + заголовок
df['combined'] = df['title'] + '. ' + df['summary']

# %%
# попробуем понять, видит ли эта штука наши 2 кластера. лейблы пока от балды
def prediсt_labels(my_df):
    pred_labels = []
    candidate_labels = ["astro-ph.IM", "Other Physics"] 
    for text in tqdm(my_df): 
        #     for i,text in tqdm(enumerate(my_df[:10])): 
        result = classifier(text, candidate_labels) 
        top_label = result['labels'][0]  # самая вероятная категория
        pred_labels.append(top_label)
#         print(i, top_label)
    return (pred_labels)

# %%
# prediсt_labels(df.combined)
# prediсt_labels(df.summary)

# %%
pred_labels_comb = prediсt_labels(df.combined)   #предсказываем для абстрактов+заголовков
# Out:
#   1%|          | 9/1000 [00:00<00:41, 23.97it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 1000/1000 [00:30<00:00, 32.96it/s]

# %%
df['predicted_labels_combined'] = pred_labels_comb

# %%
df.head(10)
# Out:
#                                         id               updated  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1  2004-07-02T10:17:39Z
# 1  http://arxiv.org/abs/astro-ph/0410439v1  2004-10-19T14:47:51Z
# 2  http://arxiv.org/abs/astro-ph/0411574v3  2011-01-05T18:55:32Z
# 3  http://arxiv.org/abs/astro-ph/0504497v1  2005-04-22T12:39:07Z
# 4   http://arxiv.org/abs/physics/0510224v1  2005-10-25T15:36:07Z
# 5   http://arxiv.org/abs/physics/0510226v1  2005-10-25T15:55:59Z
# 6   http://arxiv.org/abs/physics/0511231v1  2005-11-28T15:26:24Z
# 7  http://arxiv.org/abs/astro-ph/0512053v1  2005-12-02T02:47:13Z
# 8  http://arxiv.org/abs/astro-ph/0606733v1  2006-06-29T19:04:52Z
# 9  http://arxiv.org/abs/astro-ph/0606762v1  2006-06-30T18:24:16Z
#
#               published                                              title  \
# 0  2004-07-02T10:17:39Z  Muon Track Reconstruction and Data Selection T...
# 1  2004-10-19T14:47:51Z                   An update on the SCUBA-2 project
# 2  2004-11-19T15:00:42Z  Feasibility study of a Laue lens for hard X-ra...
# 3  2005-04-22T12:39:07Z  Search for Extra-Terrestrial planets: The DARW...
# 4  2005-10-25T15:36:07Z  Wavefront sensor based on varying transmission...
# 5  2005-10-25T15:55:59Z  An analysis of stellar interferometers as wave...
# 6  2005-11-28T15:26:24Z  Conceptual design of a phase shifting telescop...
# 7  2005-12-02T02:47:13Z  Atmospheric Biomarkers and their Evolution ove...
# 8  2006-06-29T19:04:52Z  Characteristics of proposed 3 and 4 telescope ...
# 9  2006-06-30T18:24:16Z  Interferometric Space Missions for the Search ...
#
#                                              summary  \
# 0  The Antarctic Muon And Neutrino Detector Array...
# 1  SCUBA-2, which replaces SCUBA (the Submillimet...
# 2  We report on the feasibility study of a Laue l...
# 3  The DARWIN mission is an Infrared free flying ...
# 4  The use of Wavefront Sensors (WFS) is nowadays...
# 5  This paper presents the basic principle and th...
# 6  This paper deals with the theoretical principl...
# 7  The search for life on extrasolar planets is b...
# 8  The Darwin and TPF-I missions are Infrared fre...
# 9  The requirements on space missions designed to...
#
#                                               author  \
# 0  [{'name': 'The AMANDA Collaboration'}, {'name'...
# 1  [{'name': 'Michael Audley', 'affiliation': 'UK...
# 2  [{'name': 'A. Pisa', 'affiliation': 'Universit...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [{'name': 'L. Kaltenegger'}, {'name': 'K. Juck...
# 8  [{'name': 'L. Kaltenegger'}, {'name': 'M. Frid...
# 9  [{'name': 'L Kaltenegger'}, {'name': 'M. Fridl...
#
#                             doi  \
# 0    10.1016/j.nima.2004.01.065
# 1             10.1117/12.551259
# 2             10.1117/12.563052
# 3                           NaN
# 4     10.1080/09500340500073495
# 5          10.1364/AO.44.004733
# 6  10.1016/j.optcom.2005.11.061
# 7     10.1017/S1743921306009422
# 8     10.1017/S1743921306009410
# 9     10.1007/s10509-006-9183-z
#
#                                         link_related  \
# 0  ['http://dx.doi.org/10.1016/j.nima.2004.01.065...
# 1  ['http://dx.doi.org/10.1117/12.551259', 'http:...
# 2  ['http://dx.doi.org/10.1117/12.563052', 'http:...
# 3            http://arxiv.org/pdf/astro-ph/0504497v1
# 4  ['http://dx.doi.org/10.1080/09500340500073495'...
# 5  ['http://dx.doi.org/10.1364/AO.44.004733', 'ht...
# 6  ['http://dx.doi.org/10.1016/j.optcom.2005.11.0...
# 7  ['http://dx.doi.org/10.1017/S1743921306009422'...
# 8  ['http://dx.doi.org/10.1017/S1743921306009410'...
# 9  ['http://dx.doi.org/10.1007/s10509-006-9183-z'...
#
#                                              comment  \
# 0   40 pages, 16 Postscript figures, uses elsart.sty
# 1  16 pages, 14 figures, Invited talk at SPIE Gla...
# 2  10 pages, corrected Fig. 1b and Fig. 2, which ...
# 3  PhD thesis 2004, Karl Franzens Univ. Graz, 177...
# 4                                2 tables, 6 figures
# 5                                         12 figures
# 6                             17 pages and 5 figures
# 7  for high resolution images see\n  http://cfa-w...
# 8                                 4 pages, 2 figures
# 9  21 pages, 8 figures; TBP in Astrophysics and S...
#
#                                          journal_ref  \
# 0                Nucl.Instrum.Meth.A524:169-194,2004
# 1                                                NaN
# 2                        SPIE Proc., 5536, 39 (2004)
# 3                                                NaN
# 4                       J.Mod.Opt. 52:1917-1931,2005
# 5                        Appl.Opt. 44:4733-4744,2005
# 6                          Opt.Commun.261:34-42,2006
# 7                     IAU Symp.200:1.259-1.264,20065
# 8  Proceedings IAUC200: Direct Imaging of Exoplan...
# 9               Astrophys.Space Sci.306:147-158,2006
#
#                             link_alternate primary_category  \
# 0  http://arxiv.org/abs/astro-ph/0407044v1         astro-ph
# 1  http://arxiv.org/abs/astro-ph/0410439v1         astro-ph
# 2  http://arxiv.org/abs/astro-ph/0411574v3         astro-ph
# 3  http://arxiv.org/abs/astro-ph/0504497v1         astro-ph
# 4   http://arxiv.org/abs/physics/0510224v1   physics.optics
# 5   http://arxiv.org/abs/physics/0510226v1   physics.optics
# 6   http://arxiv.org/abs/physics/0511231v1   physics.optics
# 7  http://arxiv.org/abs/astro-ph/0512053v1         astro-ph
# 8  http://arxiv.org/abs/astro-ph/0606733v1         astro-ph
# 9  http://arxiv.org/abs/astro-ph/0606762v1         astro-ph
#
#                                         category       author.name  \
# 0                    ['astro-ph', 'astro-ph.IM']               NaN
# 1                    ['astro-ph', 'astro-ph.IM']               NaN
# 2                    ['astro-ph', 'astro-ph.IM']               NaN
# 3     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']  Lisa Kaltenegger
# 4  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
# 5  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
# 6  ['physics.optics', 'astro-ph', 'astro-ph.IM']  Francois Henault
# 7     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']               NaN
# 8     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']               NaN
# 9     ['astro-ph', 'astro-ph.EP', 'astro-ph.IM']               NaN
#
#   author.affiliation                                     summary_tokens  \
# 0                NaN  ['Antarctic', 'Muon', 'Neutrino', 'Detector', ...
# 1                NaN  ['replace', 'SCUBA', 'Submillimeter', 'Common'...
# 2                NaN  ['report', 'feasibility', 'study', 'Laue', 'le...
# 3                NaN  ['DARWIN', 'mission', 'Infrared', 'free', 'fly...
# 4                NaN  ['use', 'Wavefront', 'Sensors', 'WFS', 'nowada...
# 5                NaN  ['paper', 'present', 'basic', 'principle', 'th...
# 6                NaN  ['paper', 'deal', 'theoretical', 'principle', ...
# 7                NaN  ['search', 'life', 'extrasolar', 'planet', 'ba...
# 8                NaN  ['Darwin', 'TPF', 'mission', 'Infrared', 'free...
# 9                NaN  ['requirement', 'space', 'mission', 'design', ...
#
#                                         title_tokens  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1                              ['update', 'project']
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
# 5  ['analysis', 'stellar', 'interferometer', 'wav...
# 6  ['conceptual', 'design', 'phase', 'shift', 'te...
# 7  ['Atmospheric', 'Biomarkers', 'Evolution', 'Ge...
# 8  ['Characteristics', 'propose', 'telescope', 'c...
# 9  ['Interferometric', 'Space', 'Missions', 'Sear...
#
#                                      tokens_combined  \
# 0  ['Muon', 'Track', 'Reconstruction', 'Data', 'S...
# 1  ['update', 'project', 'replace', 'SCUBA', 'Sub...
# 2  ['feasibility', 'study', 'Laue', 'lens', 'hard...
# 3  ['search', 'extra', 'terrestrial', 'planet', '...
# 4  ['wavefront', 'sensor', 'base', 'vary', 'trans...
# 5  ['analysis', 'stellar', 'interferometer', 'wav...
# 6  ['conceptual', 'design', 'phase', 'shift', 'te...
# 7  ['Atmospheric', 'Biomarkers', 'Evolution', 'Ge...
# 8  ['Characteristics', 'propose', 'telescope', 'c...
# 9  ['Interferometric', 'Space', 'Missions', 'Sear...
#
#                                             combined predicted_labels_combined
# 0  Muon Track Reconstruction and Data Selection T...             Other Physics
# 1  An update on the SCUBA-2 project. SCUBA-2, whi...             Other Physics
# 2  Feasibility study of a Laue lens for hard X-ra...             Other Physics
# 3  Search for Extra-Terrestrial planets: The DARW...             Other Physics
# 4  Wavefront sensor based on varying transmission...             Other Physics
# 5  An analysis of stellar interferometers as wave...             Other Physics
# 6  Conceptual design of a phase shifting telescop...             Other Physics
# 7  Atmospheric Biomarkers and their Evolution ove...             Other Physics
# 8  Characteristics of proposed 3 and 4 telescope ...             Other Physics
# 9  Interferometric Space Missions for the Search ...             Other Physics

# %%
# pred_labels_summary = prediсt_labels(df.summary)   #предсказываем для абстрактов отдельно
# df['predicted_labels_summary'] = pred_labels_summary

# %%
#сравнение эффективности предсказаний с заголовками и без
# accuracy = (df['predicted_label_combined'] == df['predicted_label_summary']).mean()

# %% [markdown]
# ## Создание разнообразного списка источников

# %%
# !pip install pymongo

# %%
# попробуем считать данные из db в mongodb
from pymongo import MongoClient
db = MongoClient("mongodb://localhost:27017/", uuidRepresentation="standard").arxiv

# %%
collection = db.articles
collection.count_documents({})
# Out:
# 171298

# %%
cats = [
    "astro-ph.IM",
    "astro-ph.CO",
    "astro-ph.EP",
    "astro-ph.GA",
    "astro-ph.HE",
    "astro-ph.SR",
]
cursor = collection.find({"primary_category": {"$in": cats}})
m_df = pd.DataFrame(list(cursor))
m_df.drop(columns=['_id'], inplace=True, errors='ignore')

# %%
collection.count_documents({"primary_category": {"$in": cats}})
# Out:
# 151256

# %%
import pprint
pprint.pprint(collection.find_one())
# Out:
# {'_id': '1c528260-7f0d-5142-a1ec-6253f5f9325d',
#  'author': [{'name': 'The AMANDA Collaboration'}, {'name': 'J. Ahrens'}],
#  'category': ['astro-ph', 'astro-ph.IM'],
#  'comment': '40 pages, 16 Postscript figures, uses elsart.sty',
#  'doi': '10.1016/j.nima.2004.01.065',
#  'id': 'http://arxiv.org/abs/astro-ph/0407044v1',
#  'journal_ref': 'Nucl.Instrum.Meth.A524:169-194,2004',
#  'link_alternate': 'http://arxiv.org/abs/astro-ph/0407044v1',
#  'link_related': ['http://dx.doi.org/10.1016/j.nima.2004.01.065',
#                   'http://arxiv.org/pdf/astro-ph/0407044v1'],
#  'primary_category': 'astro-ph',
#  'published': '2004-07-02T10:17:39Z',
#  'summary': 'The Antarctic Muon And Neutrino Detector Array (AMANDA) is a '
#             'high-energy\n'
#             'neutrino telescope operating at the geographic South Pole. It is '
#             'a lattice of\n'
#             'photo-multiplier tubes buried deep in the polar ice between 1500m '
#             'and 2000m.\n'
#             'The primary goal of this detector is to discover astrophysical '
#             'sources of high\n'
#             'energy neutrinos. A high-energy muon neutrino coming through the '
#             'earth from the\n'
#             'Northern Hemisphere can be identified by the secondary muon '
#             'moving upward\n'
#             'through the detector. The muon tracks are reconstructed with a '
#             'maximum\n'
#             'likelihood method. It models the arrival times and amplitudes of '
#             'Cherenkov\n'
#             'photons registered by the photo-multipliers. This paper describes '
#             'the different\n'
#             'methods of reconstruction, which have been successfully '
#             'implemented within\n'
#             'AMANDA. Strategies for optimizing the reconstruction performance '
#             'and rejecting\n'
#             'background are presented. For a typical analysis procedure the '
#             'direction of\n'
#             'tracks are reconstructed with about 2 degree accuracy.',
#  'title': 'Muon Track Reconstruction and Data Selection Techniques in AMANDA',
#  'updated': '2004-07-02T10:17:39Z'}

# %%
m_df.count()
# Out:
# id                  151256
# updated             151256
# published           151256
# title               151256
# summary             151256
# author              151256
# doi                 127952
# link_related        151256
# comment             142604
# link_alternate      151256
# primary_category    151256
# category            151256
# journal_ref          43802
# dtype: int64

# %%
# aggregate count per category
pipeline = [
    {"$group": {"_id": "$primary_category", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}  # optional: sort descending
]

counts = list(collection.aggregate(pipeline))

for record in counts:
    print(record["_id"], record["count"])
# Out:
# astro-ph.SR 30876
# astro-ph.GA 30226
# astro-ph.HE 29819
# astro-ph.CO 25215
# astro-ph.EP 18783
# astro-ph.IM 16337
# gr-qc 6985
# hep-ph 4523
# hep-th 1963
# nucl-th 1087
# physics.ins-det 740
# physics.space-ph 634
# physics.plasm-ph 564
# physics.flu-dyn 285
# physics.hist-ph 268
# hep-ex 240
# physics.pop-ph 195
# nucl-ex 158
# physics.comp-ph 148
# physics.atom-ph 146
# physics.ao-ph 139
# physics.geo-ph 130
# physics.optics 130
# physics.ed-ph 105
# physics.chem-ph 101
# physics.data-an 85
# quant-ph 82
# physics.gen-ph 77
# astro-ph 76
# cs.LG 74
# nlin.CD 72
# cond-mat.stat-mech 68
# math.NA 66
# math-ph 61
# physics.soc-ph 55
# cs.CV 52
# cond-mat.mtrl-sci 47
# stat.ME 45
# cs.DC 43
# eess.SP 37
# cs.IT 34
# math.DS 33
# physics.class-ph 33
# stat.AP 31
# cs.DL 26
# cs.RO 26
# stat.CO 24
# cond-mat.supr-con 23
# stat.ML 22
# physics.app-ph 17
# math.AP 17
# cond-mat.mes-hall 15
# eess.IV 15
# eess.SY 15
# cond-mat.soft 13
# cs.CE 12
# cond-mat.quant-gas 12
# q-bio.PE 11
# physics.bio-ph 11
# math.OC 9
# math.ST 9
# hep-lat 8
# physics.atm-clus 8
# cs.MS 7
# cs.AI 7
# math.CA 7
# physics.acc-ph 6
# physics.med-ph 6
# cs.PF 6
# cond-mat.other 6
# cs.CL 5
# math.PR 5
# nlin.PS 5
# cs.DB 5
# cs.SY 4
# q-bio.BM 4
# cs.HC 4
# cs.NI 4
# cond-mat.str-el 4
# cs.NA 4
# cs.CY 4
# q-bio.OT 4
# cs.IR 3
# cs.SE 3
# math.CV 3
# cs.GR 3
# cs.DM 2
# math.DG 2
# nlin.AO 2
# cs.NE 2
# cs.SC 2
# cs.OH 2
# cs.SD 2
# econ.GN 2
# stat.OT 1
# cs.CR 1
# q-bio.CB 1
# cond-mat.dis-nn 1
# eess.AS 1
# math.QA 1
# cs.DS 1
# math.HO 1
# nlin.SI 1
# math.MG 1
# q-bio.QM 1
# q-bio.GN 1

# %%
# choose your category
category = "q-bio.GN"

# find all records in that category
cursor = collection.find({"primary_category": category})

# print first few results nicely
for doc in cursor.limit(5):
    pprint.pprint(doc)
# Out:
# {'_id': 'c2acfe27-e626-5586-a4b8-90cd77646e8e',
#  'author': [{'name': 'Aaron Golden'},
#             {'name': 'S. George Djorgovski'},
#             {'name': 'John M. Greally'}],
#  'category': ['q-bio.GN', 'astro-ph.IM'],
#  'comment': '11 pages, 1 figure, accepted for publication in Genome Biology',
#  'id': 'http://arxiv.org/abs/1308.3277v1',
#  'link_alternate': 'http://arxiv.org/abs/1308.3277v1',
#  'link_related': 'http://arxiv.org/pdf/1308.3277v1',
#  'primary_category': 'q-bio.GN',
#  'published': '2013-08-15T00:01:05Z',
#  'summary': "The ominous warnings of a `data deluge' in the life sciences "
#             'from\n'
#             'high-throughput DNA sequencing data are being supplanted by a '
#             'second deluge, of\n'
#             'cliches bemoaning our collective scientific fate unless we '
#             'address the genomic\n'
#             "data `tsunami'. It is imperative that we explore the many facets "
#             'of the genome,\n'
#             'not just sequence but also transcriptional and epigenetic '
#             'variability,\n'
#             'integrating these observations in order to attain a genuine '
#             'understanding of\n'
#             'how genes function, towards a goal of genomics-based personalized '
#             'medicine.\n'
#             "Determining any individual's genomic properties requires "
#             'comparison to many\n'
#             'others, sifting out the specific from the trends, requiring '
#             'access to the many\n'
#             'in order to yield information relevant to the few. This is the '
#             'central big data\n'
#             'challenge in genomics that still requires some sort of '
#             'resolution. Is there a\n'
#             'practical, feasible way of directly connecting the scientific '
#             'community to this\n'
#             'data universe? The best answer could be in the stars overhead.',
#  'title': 'Astrogenomics: big data, old problems, old solutions?',
#  'updated': '2013-08-15T00:01:05Z'}

# %%
# target number per category
N = 150

sampled_docs = []
for cat in cats:
    pipeline = [
        {"$match": {"primary_category": cat}},
        {"$sample": {"size": N}}  # random sample of N docs
    ]
    sampled_docs.extend(list(collection.aggregate(pipeline)))

df_test = pd.DataFrame(sampled_docs)
df_test.drop(columns=['_id'], inplace=True, errors='ignore')

print(df_test["primary_category"].value_counts())
print(df_test.shape)
# Out:
# primary_category
# astro-ph.IM    150
# astro-ph.CO    150
# astro-ph.EP    150
# astro-ph.GA    150
# astro-ph.HE    150
# astro-ph.SR    150
# Name: count, dtype: int64
# (900, 13)

# %%
df_test.head(10)
# Out:
#                                   id               updated  \
# 0  http://arxiv.org/abs/1501.07239v1  2015-01-28T19:09:07Z
# 1  http://arxiv.org/abs/2209.15395v1  2022-09-30T11:50:19Z
# 2  http://arxiv.org/abs/1802.00372v1  2018-02-01T16:08:12Z
# 3  http://arxiv.org/abs/2103.08136v1  2021-03-15T04:56:14Z
# 4  http://arxiv.org/abs/1812.00785v4  2019-01-23T17:41:50Z
# 5  http://arxiv.org/abs/2208.04673v1  2022-08-09T11:35:16Z
# 6  http://arxiv.org/abs/2310.00380v1  2023-09-30T13:56:02Z
# 7  http://arxiv.org/abs/2108.03522v2  2021-08-10T14:38:16Z
# 8  http://arxiv.org/abs/2008.09133v1  2020-08-20T18:00:22Z
# 9  http://arxiv.org/abs/1709.05085v1  2017-09-15T07:35:43Z
#
#               published                                              title  \
# 0  2015-01-28T19:09:07Z  Molecfit: A general tool for telluric absorpti...
# 1  2022-09-30T11:50:19Z  EMIR, the near-infrared camera and multi-objec...
# 2  2018-02-01T16:08:12Z  Development of a Lunar Scintillometer as part ...
# 3  2021-03-15T04:56:14Z  A correction method for the telluric absorptio...
# 4  2018-11-30T17:07:41Z  QUBIC: Exploring the primordial Universe with ...
# 5  2022-08-09T11:35:16Z  In-flight performance of the NIRSpec Micro Shu...
# 6  2023-09-30T13:56:02Z  Review of Image Processing Methods in Solar Ph...
# 7  2021-08-07T20:58:48Z  Space-based weather observatory at Earth-Moon ...
# 8  2020-08-20T18:00:22Z  Mock catalogs for the extragalactic X-ray sky:...
# 9  2017-09-15T07:35:43Z  Spectral-line Observations Using a Phased Arra...
#
#                                              summary  \
# 0  Context: The interaction of the light from ast...
# 1  We present EMIR, a powerful near-infrared (NIR...
# 2  Ground layer turbulence is a very important si...
# 3  Observing a telluric standard star for correct...
# 4  In this paper we describe QUBIC, an experiment...
# 5  The NIRSpec instrument on the James Webb Space...
# 6  With the exponential growth in data volume, es...
# 7  Lunar hematite is formed by the oxidation of i...
# 8  We present a series of new, publicly available...
# 9  We present first results from pilot observatio...
#
#                                               author  \
# 0  [{'name': 'A. Smette'}, {'name': 'H. Sana'}, {...
# 1  [{'name': 'F. Garzón'}, {'name': 'M. Balcells'...
# 2  [{'name': 'Avinash Surendran'}, {'name': 'Padm...
# 3  [{'name': 'Kai-Xing Lu'}, {'name': 'Zhi-Xiang ...
# 4  [{'name': 'Aniello Mennella'}, {'name': 'Peter...
# 5  [{'name': 'Timothy D. Rawle', 'affiliation': '...
# 6  [{'name': 'Mohsen Javaherian'}, {'name': 'Zahr...
# 7  [{'name': 'Saurabh Gore'}, {'name': 'Manuel Nt...
# 8  [{'name': 'Stefano Marchesi'}, {'name': 'Rober...
# 9  [{'name': 'Tristan Reynolds'}, {'name': 'Liste...
#
#                            doi  \
# 0  10.1051/0004-6361/201423932
# 1  10.1051/0004-6361/202244729
# 2    10.1007/s10686-017-9567-9
# 3   10.1088/1674-4527/21/7/183
# 4      10.3390/universe5020042
# 5                          NaN
# 6  10.22128/ijaa.2023.711.1155
# 7  10.13140/RG.2.2.12897.84322
# 8  10.1051/0004-6361/202038622
# 9         10.1017/pasa.2017.45
#
#                                         link_related  \
# 0  [http://dx.doi.org/10.1051/0004-6361/201423932...
# 1  [http://dx.doi.org/10.1051/0004-6361/202244729...
# 2  [http://dx.doi.org/10.1007/s10686-017-9567-9, ...
# 3  [http://dx.doi.org/10.1088/1674-4527/21/7/183,...
# 4  [http://dx.doi.org/10.3390/universe5020042, ht...
# 5                  http://arxiv.org/pdf/2208.04673v1
# 6  [http://dx.doi.org/10.22128/ijaa.2023.711.1155...
# 7  [http://dx.doi.org/10.13140/RG.2.2.12897.84322...
# 8  [http://dx.doi.org/10.1051/0004-6361/202038622...
# 9  [http://dx.doi.org/10.1017/pasa.2017.45, http:...
#
#                                              comment  \
# 0  18 pages, 13 figures, 5 tables, accepted for p...
# 1                               10 pages, 11 figures
# 2                                                NaN
# 3  15 pages, 10 figure, accepted for publication ...
# 4  Proceedings of the 2018 ICNFP conference, Cret...
# 5  15 pages, 6 figures, to appear in Proceedings ...
# 6                                                NaN
# 7                                                NaN
# 8  19 pages, 13 figures. Accepted for publication...
# 9  14 pages, 13 figures, accepted for publication...
#
#                                          journal_ref  \
# 0                                A&A 576, A77 (2015)
# 1                               A&A 667, A107 (2022)
# 2  Surendran, A., Parihar, P.S., Banyal, R.K. et ...
# 3                                                NaN
# 4                               Universe 2019, 5, 42
# 5                                                NaN
# 6  Iranian Journal of Astronomy and Astrophysics,...
# 7                                                NaN
# 8                               A&A 642, A184 (2020)
# 9                                                NaN
#
#                       link_alternate primary_category  \
# 0  http://arxiv.org/abs/1501.07239v1      astro-ph.IM
# 1  http://arxiv.org/abs/2209.15395v1      astro-ph.IM
# 2  http://arxiv.org/abs/1802.00372v1      astro-ph.IM
# 3  http://arxiv.org/abs/2103.08136v1      astro-ph.IM
# 4  http://arxiv.org/abs/1812.00785v4      astro-ph.IM
# 5  http://arxiv.org/abs/2208.04673v1      astro-ph.IM
# 6  http://arxiv.org/abs/2310.00380v1      astro-ph.IM
# 7  http://arxiv.org/abs/2108.03522v2      astro-ph.IM
# 8  http://arxiv.org/abs/2008.09133v1      astro-ph.IM
# 9  http://arxiv.org/abs/1709.05085v1      astro-ph.IM
#
#                                        category
# 0                                 [astro-ph.IM]
# 1                                 [astro-ph.IM]
# 2                                 [astro-ph.IM]
# 3                                 [astro-ph.IM]
# 4                                 [astro-ph.IM]
# 5                                 [astro-ph.IM]
# 6       [astro-ph.IM, astro-ph.GA, astro-ph.SR]
# 7  [astro-ph.IM, astro-ph.EP, physics.space-ph]
# 8       [astro-ph.IM, astro-ph.GA, astro-ph.HE]
# 9                                 [astro-ph.IM]

# %%
df_test_shuffled = df_test.sample(frac=1).reset_index(drop=True)
df_test_shuffled.head(15)
# Out:
#                                    id               updated  \
# 0   http://arxiv.org/abs/1509.01427v1  2015-09-04T12:29:46Z
# 1   http://arxiv.org/abs/1502.02562v2  2015-02-18T17:19:03Z
# 2   http://arxiv.org/abs/1908.04505v1  2019-08-13T06:07:14Z
# 3    http://arxiv.org/abs/1206.0764v2  2012-09-20T15:39:26Z
# 4   http://arxiv.org/abs/2012.08433v1  2020-12-15T17:17:51Z
# 5    http://arxiv.org/abs/1312.1691v1  2013-12-05T21:00:02Z
# 6    http://arxiv.org/abs/1102.5094v1  2011-02-24T21:00:03Z
# 7   http://arxiv.org/abs/1808.04766v1  2018-08-14T16:06:41Z
# 8    http://arxiv.org/abs/1211.2806v2  2013-06-27T11:08:15Z
# 9   http://arxiv.org/abs/1702.02586v2  2020-02-13T19:10:16Z
# 10   http://arxiv.org/abs/1401.2423v1  2014-01-10T18:45:01Z
# 11  http://arxiv.org/abs/2505.00880v1  2025-05-01T21:46:51Z
# 12  http://arxiv.org/abs/1907.00688v1  2019-07-01T12:14:36Z
# 13  http://arxiv.org/abs/1801.06124v3  2018-05-10T07:15:40Z
# 14  http://arxiv.org/abs/2008.00834v1  2020-08-03T12:33:43Z
#
#                published                                              title  \
# 0   2015-09-04T12:29:46Z  Radio Observations of the Pulsar Wind Nebula H...
# 1   2015-02-09T16:57:20Z  Faint AGNs at z>4 in the CANDELS GOODS-S field...
# 2   2019-08-13T06:07:14Z  Homogeneously derived transit timings for 17 e...
# 3   2012-06-04T21:00:56Z  Probing the Structure of Jet Driven Core-Colla...
# 4   2020-12-15T17:17:51Z  Control and systems software for the Cosmology...
# 5   2013-12-05T21:00:02Z  Transient jet formation and state transitions ...
# 6   2011-02-24T21:00:03Z  Reassessing The Fundamentals: New Constraints ...
# 7   2018-08-14T16:06:41Z  Early formation of carbon monoxide in the Cent...
# 8   2012-11-12T21:00:01Z  Afterglow emission in Gamma-Ray Bursts: I. Pai...
# 9   2017-02-08T19:11:59Z  Constraints on the Intergalactic Magnetic Fiel...
# 10  2014-01-10T18:45:01Z                  Volatiles in protoplanetary disks
# 11  2025-05-01T21:46:51Z  A Model of UV-Blue Absorbance in Bulk Liquid o...
# 12  2019-07-01T12:14:36Z      On the photometric signature of fast rotators
# 13  2018-01-18T16:56:48Z  Prompt gamma-ray emission of GRB 170817A assoc...
# 14  2020-08-03T12:33:43Z  Galactic extinction laws: II. Hidden in plain ...
#
#                                               summary  \
# 0   Based on its energy-dependent morphology the i...
# 1   In order to derive the AGN contribution to the...
# 2   We homogeneously analyse $\sim 3.2\times 10^5$...
# 3   Times of arrival of high energy neutrinos enco...
# 4   The Cosmology Large Angular Scale Surveyor (CL...
# 5   Magnetically arrested accretion discs (MADs), ...
# 6   The ages and masses of neutron stars (NSs) are...
# 7   We present near-infrared spectroscopy of the N...
# 8   Forward shocks caused by the interaction betwe...
# 9   Pair creation on the cosmic infrared backgroun...
# 10  Volatiles are compounds with low sublimation t...
# 11  At visible wavelengths, Venus appears serene a...
# 12  Rapidly rotating stars have been recently reco...
# 13  The short GRB 170817A associated to the first ...
# 14  We have detected a broad interstellar absorpti...
#
#                                                author  \
# 0   [{'name': 'Iurii Sushch'}, {'name': 'Igor Oya'...
# 1   [{'name': 'E. Giallongo'}, {'name': 'A. Grazia...
# 2   [{'name': 'R. V. Baluev'}, {'name': 'E. N. Sok...
# 3   [{'name': 'Imre Bartos'}, {'name': 'Basudeb Da...
# 4   [{'name': 'Matthew A. Petroff'}, {'name': 'Joh...
# 5   [{'name': 'Jason Dexter'}, {'name': 'Jonathan ...
# 6                         {'name': 'Bulent Kiziltan'}
# 7   [{'name': 'D. P. K. Banerjee', 'affiliation': ...
# 8   [{'name': 'L. Nava'}, {'name': 'L. Sironi'}, {...
# 9   [{'name': 'Paul Tiede'}, {'name': 'Avery E. Br...
# 10  [{'name': 'Klaus M. Pontoppidan'}, {'name': 'C...
# 11  [{'name': 'Jan Spacek'}, {'name': 'Yeon J. Lee...
# 12  [{'name': 'Léo Girardi', 'affiliation': 'OAPD'...
# 13                        {'name': 'Houri Ziaeepour'}
# 14  [{'name': 'J. Maíz Apellániz'}, {'name': 'R. H...
#
#                                         doi  \
# 0                                       NaN
# 1               10.1051/0004-6361/201425334
# 2                     10.1093/mnras/stz2620
# 3                10.1103/PhysRevD.86.083007
# 4                        10.1117/12.2561609
# 5                      10.1093/mnras/stu581
# 6                         10.1063/1.3629483
# 7                     10.1093/mnras/sty2255
# 8                      10.1093/mnras/stt872
# 9                  10.3847/1538-4357/ab737e
# 10  10.2458/azu_uapress_9780816531240-ch016
# 11                                      NaN
# 12                    10.1093/mnras/stz1767
# 13                    10.1093/mnras/sty1246
# 14                   10.1093/mnras/staa2371
#
#                                          link_related  \
# 0                   http://arxiv.org/pdf/1509.01427v1
# 1   [http://dx.doi.org/10.1051/0004-6361/201425334...
# 2   [http://dx.doi.org/10.1093/mnras/stz2620, http...
# 3   [http://dx.doi.org/10.1103/PhysRevD.86.083007,...
# 4   [http://dx.doi.org/10.1117/12.2561609, http://...
# 5   [http://dx.doi.org/10.1093/mnras/stu581, http:...
# 6   [http://dx.doi.org/10.1063/1.3629483, http://a...
# 7   [http://dx.doi.org/10.1093/mnras/sty2255, http...
# 8   [http://dx.doi.org/10.1093/mnras/stt872, http:...
# 9   [http://dx.doi.org/10.3847/1538-4357/ab737e, h...
# 10  [http://dx.doi.org/10.2458/azu_uapress_9780816...
# 11                  http://arxiv.org/pdf/2505.00880v1
# 12  [http://dx.doi.org/10.1093/mnras/stz1767, http...
# 13  [http://dx.doi.org/10.1093/mnras/sty1246, http...
# 14  [http://dx.doi.org/10.1093/mnras/staa2371, htt...
#
#                                               comment  \
# 0   9 pages, 3 figures, 1 table. In Proceedings of...
# 1   15 pages, 8 figures, A&A accepted, updated fig...
# 2   19 pages, 4 figures, 6 tables; revised manuscr...
# 3                                                 NaN
# 4        19 pages, 8 figures, to appear in Proc. SPIE
# 5      5 pages, 3 figures, submitted to MNRAS Letters
# 6   4 pages, 4 figures; To appear in the AIP proce...
# 7            MNRAS, in press. Accepted 2018 August 13
# 8   MNRAS in press. Reverse shock and pre-accelera...
# 9   12 pages, 14 figures, 1 appendix. Accepted to ApJ
# 10  Accepted for publication as a chapter in Proto...
# 11                                                NaN
# 12  Accepted for publication in MNRAS, 10 pages, 7...
# 13  41 pages, 8 figures. v3: version accepted for ...
# 14        17 pages, accepted for publication in MNRAS
#
#                                           journal_ref  \
# 0                                                 NaN
# 1                                 A&A 578, A83 (2015)
# 2   Mon. Not. R. Astron. Soc., 2019, V. 490 (1), P...
# 3                       Phys. Rev. D 86, 083007, 2012
# 4   Proc. SPIE 11452, Software and Cyberinfrastruc...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                              MNRAS 478 (2018) 3233
# 14                                                NaN
#
#                        link_alternate primary_category  \
# 0   http://arxiv.org/abs/1509.01427v1      astro-ph.HE
# 1   http://arxiv.org/abs/1502.02562v2      astro-ph.CO
# 2   http://arxiv.org/abs/1908.04505v1      astro-ph.EP
# 3    http://arxiv.org/abs/1206.0764v2      astro-ph.HE
# 4   http://arxiv.org/abs/2012.08433v1      astro-ph.IM
# 5    http://arxiv.org/abs/1312.1691v1      astro-ph.HE
# 6    http://arxiv.org/abs/1102.5094v1      astro-ph.GA
# 7   http://arxiv.org/abs/1808.04766v1      astro-ph.SR
# 8    http://arxiv.org/abs/1211.2806v2      astro-ph.HE
# 9   http://arxiv.org/abs/1702.02586v2      astro-ph.HE
# 10   http://arxiv.org/abs/1401.2423v1      astro-ph.EP
# 11  http://arxiv.org/abs/2505.00880v1      astro-ph.EP
# 12  http://arxiv.org/abs/1907.00688v1      astro-ph.SR
# 13  http://arxiv.org/abs/1801.06124v3      astro-ph.HE
# 14  http://arxiv.org/abs/2008.00834v1      astro-ph.GA
#
#                          category
# 0                   [astro-ph.HE]
# 1      [astro-ph.CO, astro-ph.GA]
# 2                   [astro-ph.EP]
# 3   [astro-ph.HE, hep-ex, hep-ph]
# 4                   [astro-ph.IM]
# 5                   [astro-ph.HE]
# 6          [astro-ph.GA, stat.AP]
# 7                   [astro-ph.SR]
# 8                   [astro-ph.HE]
# 9      [astro-ph.HE, astro-ph.CO]
# 10                  [astro-ph.EP]
# 11  [astro-ph.EP, physics.geo-ph]
# 12                  [astro-ph.SR]
# 13                  [astro-ph.HE]
# 14     [astro-ph.GA, astro-ph.SR]

# %%
df_test_shuffled.to_csv("raw_radnom_astro_sample150.csv", index=False)
